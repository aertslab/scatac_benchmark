# %% [markdown]
# # Freemuxlet results
#
# scATAC-seq samples

# %%
import pandas as pd
import seaborn as sns
#import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# %%
import os
wdir = '/lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_rerun_all_with_hydrop'
os.chdir( wdir )

# %%
f_nrd = 'fmx_out/genotype_concordance_nrd.txt'
f_nvar = 'fmx_out/genotype_concordance_nvar.txt'

nrd = pd.read_csv(f_nrd, sep='\t', header=0, index_col=0)
nvar = pd.read_csv(f_nvar, sep='\t', header=0, index_col=0)

# %%
# the non-reference discordance rate computed by VCFtools
nrd.round(1)
# Out:
#                      Broad_1.CLUST0  Broad_1.CLUST1  Broad_2.CLUST0  \
# Broad_1.CLUST0                  0.0            70.5            70.7
# Broad_1.CLUST1                 70.5             0.0             0.4
# Broad_2.CLUST0                 70.7             0.4             0.0
# Broad_2.CLUST1                  0.4            70.7            70.6
# Broad_mito_1.CLUST0            70.7             0.6             0.6
# Broad_mito_1.CLUST1             0.6            70.8            70.7
# Broad_mito_2.CLUST0            70.7             0.7             0.7
# Broad_mito_2.CLUST1             0.7            70.8            70.8
# CNAG_1.CLUST0                  69.9             0.8             0.8
# CNAG_1.CLUST1                   0.7            70.0            70.1
# CNAG_2.CLUST0                  70.2             0.7             0.7
# CNAG_2.CLUST1                   0.8            70.2            70.4
# Sanger_1.CLUST0                 0.6            70.5            70.5
# Sanger_1.CLUST1                70.4             0.6             0.6
# Sanger_2.CLUST0                70.2             0.7             0.8
# Sanger_2.CLUST1                 0.6            70.3            70.4
# Stanford_1.CLUST0              70.5             0.4             0.6
# Stanford_1.CLUST1               0.7            70.4            70.3
# Stanford_2.CLUST0               0.6            70.3            70.2
# Stanford_2.CLUST1              70.2             0.4             0.5
# VIB_1.CLUST0                   70.4             0.5             0.6
# VIB_1.CLUST1                    0.5            70.5            70.4
# VIB_2.CLUST0                    0.9            70.1            70.3
# VIB_2.CLUST1                   70.2             0.4             0.4
# VIB_Hydrop_1.CLUST0             0.9            68.7            68.6
# VIB_Hydrop_1.CLUST1            68.3             2.0             2.1
# VIB_Hydrop_2.CLUST0             1.2            68.6            68.4
# VIB_Hydrop_2.CLUST1            67.9             3.2             3.1
# s3atac.CLUST0                  69.8             1.4             1.3
# s3atac.CLUST1                   0.6            69.9            69.8
#
#                      Broad_2.CLUST1  Broad_mito_1.CLUST0  Broad_mito_1.CLUST1  \
# Broad_1.CLUST0                  0.4                 70.7                  0.6
# Broad_1.CLUST1                 70.7                  0.6                 70.8
# Broad_2.CLUST0                 70.6                  0.6                 70.7
# Broad_2.CLUST1                  0.0                 70.8                  0.6
# Broad_mito_1.CLUST0            70.8                  0.0                 70.6
# Broad_mito_1.CLUST1             0.6                 70.6                  0.0
# Broad_mito_2.CLUST0            70.7                  0.6                 70.6
# Broad_mito_2.CLUST1             0.6                 70.6                  0.8
# CNAG_1.CLUST0                  70.1                  0.9                 70.2
# CNAG_1.CLUST1                   0.7                 70.1                  0.9
# CNAG_2.CLUST0                  70.3                  0.8                 70.5
# CNAG_2.CLUST1                   0.8                 70.5                  1.0
# Sanger_1.CLUST0                 0.5                 70.4                  0.8
# Sanger_1.CLUST1                70.4                  1.0                 70.4
# Sanger_2.CLUST0                70.3                  1.4                 70.0
# Sanger_2.CLUST1                 0.6                 70.1                  0.9
# Stanford_1.CLUST0              70.4                  0.8                 70.8
# Stanford_1.CLUST1               0.7                 70.7                  1.0
# Stanford_2.CLUST0               0.5                 70.6                  0.6
# Stanford_2.CLUST1              70.3                  0.6                 70.6
# VIB_1.CLUST0                   70.4                  0.7                 70.6
# VIB_1.CLUST1                    0.4                 70.6                  0.5
# VIB_2.CLUST0                    0.8                 70.3                  1.3
# VIB_2.CLUST1                   70.4                  0.7                 70.4
# VIB_Hydrop_1.CLUST0             1.0                 68.6                  1.0
# VIB_Hydrop_1.CLUST1            68.2                  1.9                 68.4
# VIB_Hydrop_2.CLUST0             1.1                 68.7                  1.2
# VIB_Hydrop_2.CLUST1            67.8                  3.0                 68.1
# s3atac.CLUST0                  69.7                  1.1                 69.8
# s3atac.CLUST1                   0.6                 70.0                  0.4
#
#                      Broad_mito_2.CLUST0  Broad_mito_2.CLUST1  CNAG_1.CLUST0  \
# Broad_1.CLUST0                      70.7                  0.7           69.9
# Broad_1.CLUST1                       0.7                 70.8            0.8
# Broad_2.CLUST0                       0.7                 70.8            0.8
# Broad_2.CLUST1                      70.7                  0.6           70.1
# Broad_mito_1.CLUST0                  0.6                 70.6            0.9
# Broad_mito_1.CLUST1                 70.6                  0.8           70.2
# Broad_mito_2.CLUST0                  0.0                 70.5            0.9
# Broad_mito_2.CLUST1                 70.5                  0.0           70.2
# CNAG_1.CLUST0                        0.9                 70.2            0.0
# CNAG_1.CLUST1                       70.1                  0.9           69.8
# CNAG_2.CLUST0                        0.7                 70.5            1.0
# CNAG_2.CLUST1                       70.5                  1.0           69.8
# Sanger_1.CLUST0                     70.3                  0.8           69.7
# Sanger_1.CLUST1                      1.0                 70.4            1.0
# Sanger_2.CLUST0                      1.5                 69.9            1.3
# Sanger_2.CLUST1                     70.0                  0.9           69.6
# Stanford_1.CLUST0                    0.8                 70.7            0.9
# Stanford_1.CLUST1                   70.6                  1.1           70.0
# Stanford_2.CLUST0                   70.5                  0.7           70.3
# Stanford_2.CLUST1                    0.7                 70.5            0.6
# VIB_1.CLUST0                         0.7                 70.7            0.9
# VIB_1.CLUST1                        70.6                  0.7           69.9
# VIB_2.CLUST0                        70.3                  1.3           69.8
# VIB_2.CLUST1                         0.7                 70.4            0.9
# VIB_Hydrop_1.CLUST0                 68.6                  1.0           68.2
# VIB_Hydrop_1.CLUST1                  1.9                 68.4            1.9
# VIB_Hydrop_2.CLUST0                 68.6                  1.1           68.4
# VIB_Hydrop_2.CLUST1                  3.1                 68.0            3.2
# s3atac.CLUST0                        1.1                 69.8            1.3
# s3atac.CLUST1                       69.9                  0.5           69.6
#
#                      CNAG_1.CLUST1  ...  VIB_1.CLUST0  VIB_1.CLUST1  \
# Broad_1.CLUST0                 0.7  ...          70.4           0.5
# Broad_1.CLUST1                70.0  ...           0.5          70.5
# Broad_2.CLUST0                70.1  ...           0.6          70.4
# Broad_2.CLUST1                 0.7  ...          70.4           0.4
# Broad_mito_1.CLUST0           70.1  ...           0.7          70.6
# Broad_mito_1.CLUST1            0.9  ...          70.6           0.5
# Broad_mito_2.CLUST0           70.1  ...           0.7          70.6
# Broad_mito_2.CLUST1            0.9  ...          70.7           0.7
# CNAG_1.CLUST0                 69.8  ...           0.9          69.9
# CNAG_1.CLUST1                  0.0  ...          70.0           0.7
# CNAG_2.CLUST0                 69.8  ...           0.8          70.2
# CNAG_2.CLUST1                  0.9  ...          70.2           0.9
# Sanger_1.CLUST0                0.8  ...          70.2           0.5
# Sanger_1.CLUST1               69.7  ...           0.7          70.2
# Sanger_2.CLUST0               69.5  ...           0.9          70.0
# Sanger_2.CLUST1                0.8  ...          70.1           0.6
# Stanford_1.CLUST0             70.2  ...           0.6          70.6
# Stanford_1.CLUST1              1.1  ...          70.5           0.8
# Stanford_2.CLUST0              0.7  ...          70.4           0.5
# Stanford_2.CLUST1             70.3  ...           0.5          70.5
# VIB_1.CLUST0                  70.0  ...           0.0          70.4
# VIB_1.CLUST1                   0.7  ...          70.4           0.0
# VIB_2.CLUST0                   1.0  ...          70.2           1.0
# VIB_2.CLUST1                  69.8  ...           0.4          70.2
# VIB_Hydrop_1.CLUST0            0.8  ...          68.4           0.9
# VIB_Hydrop_1.CLUST1           68.0  ...           1.7          68.2
# VIB_Hydrop_2.CLUST0            1.3  ...          68.4           1.1
# VIB_Hydrop_2.CLUST1           67.8  ...           2.9          67.8
# s3atac.CLUST0                 69.5  ...           1.1          69.6
# s3atac.CLUST1                  0.6  ...          69.7           0.4
#
#                      VIB_2.CLUST0  VIB_2.CLUST1  VIB_Hydrop_1.CLUST0  \
# Broad_1.CLUST0                0.9          70.2                  0.9
# Broad_1.CLUST1               70.1           0.4                 68.7
# Broad_2.CLUST0               70.3           0.4                 68.6
# Broad_2.CLUST1                0.8          70.4                  1.0
# Broad_mito_1.CLUST0          70.3           0.7                 68.6
# Broad_mito_1.CLUST1           1.3          70.4                  1.0
# Broad_mito_2.CLUST0          70.3           0.7                 68.6
# Broad_mito_2.CLUST1           1.3          70.4                  1.0
# CNAG_1.CLUST0                69.8           0.9                 68.2
# CNAG_1.CLUST1                 1.0          69.8                  0.8
# CNAG_2.CLUST0                70.0           0.7                 68.4
# CNAG_2.CLUST1                 1.1          70.1                  1.0
# Sanger_1.CLUST0               1.3          69.9                  0.8
# Sanger_1.CLUST1              69.7           0.9                 68.4
# Sanger_2.CLUST0              69.4           1.3                 68.5
# Sanger_2.CLUST1               1.4          69.8                  0.8
# Stanford_1.CLUST0            70.7           0.4                 68.6
# Stanford_1.CLUST1             1.0          70.6                  1.2
# Stanford_2.CLUST0             0.6          70.5                  0.8
# Stanford_2.CLUST1            70.5           0.5                 68.5
# VIB_1.CLUST0                 70.2           0.4                 68.4
# VIB_1.CLUST1                  1.0          70.2                  0.9
# VIB_2.CLUST0                  0.0          70.0                  0.8
# VIB_2.CLUST1                 70.0           0.0                 68.5
# VIB_Hydrop_1.CLUST0           0.8          68.5                  0.0
# VIB_Hydrop_1.CLUST1          68.2           1.8                 68.0
# VIB_Hydrop_2.CLUST0           1.1          68.6                  1.1
# VIB_Hydrop_2.CLUST1          67.9           3.0                 66.5
# s3atac.CLUST0                69.6           1.2                 68.3
# s3atac.CLUST1                 0.6          69.8                  1.0
#
#                      VIB_Hydrop_1.CLUST1  VIB_Hydrop_2.CLUST0  \
# Broad_1.CLUST0                      68.3                  1.2
# Broad_1.CLUST1                       2.0                 68.6
# Broad_2.CLUST0                       2.1                 68.4
# Broad_2.CLUST1                      68.2                  1.1
# Broad_mito_1.CLUST0                  1.9                 68.7
# Broad_mito_1.CLUST1                 68.4                  1.2
# Broad_mito_2.CLUST0                  1.9                 68.6
# Broad_mito_2.CLUST1                 68.4                  1.1
# CNAG_1.CLUST0                        1.9                 68.4
# CNAG_1.CLUST1                       68.0                  1.3
# CNAG_2.CLUST0                        1.9                 68.4
# CNAG_2.CLUST1                       68.2                  1.2
# Sanger_1.CLUST0                     68.2                  1.0
# Sanger_1.CLUST1                      1.8                 68.4
# Sanger_2.CLUST0                      1.9                 68.4
# Sanger_2.CLUST1                     68.2                  1.1
# Stanford_1.CLUST0                    2.2                 68.6
# Stanford_1.CLUST1                   68.3                  1.5
# Stanford_2.CLUST0                   68.3                  1.2
# Stanford_2.CLUST1                    2.0                 68.6
# VIB_1.CLUST0                         1.7                 68.4
# VIB_1.CLUST1                        68.2                  1.1
# VIB_2.CLUST0                        68.2                  1.1
# VIB_2.CLUST1                         1.8                 68.6
# VIB_Hydrop_1.CLUST0                 68.0                  1.1
# VIB_Hydrop_1.CLUST1                  0.0                 66.8
# VIB_Hydrop_2.CLUST0                 66.8                  0.0
# VIB_Hydrop_2.CLUST1                  3.1                 67.5
# s3atac.CLUST0                        2.2                 68.1
# s3atac.CLUST1                       68.3                  1.1
#
#                      VIB_Hydrop_2.CLUST1  s3atac.CLUST0  s3atac.CLUST1
# Broad_1.CLUST0                      67.9           69.8            0.6
# Broad_1.CLUST1                       3.2            1.4           69.9
# Broad_2.CLUST0                       3.1            1.3           69.8
# Broad_2.CLUST1                      67.8           69.7            0.6
# Broad_mito_1.CLUST0                  3.0            1.1           70.0
# Broad_mito_1.CLUST1                 68.1           69.8            0.4
# Broad_mito_2.CLUST0                  3.1            1.1           69.9
# Broad_mito_2.CLUST1                 68.0           69.8            0.5
# CNAG_1.CLUST0                        3.2            1.3           69.6
# CNAG_1.CLUST1                       67.8           69.5            0.6
# CNAG_2.CLUST0                        3.0            1.3           69.7
# CNAG_2.CLUST1                       67.8           69.6            0.7
# Sanger_1.CLUST0                     67.9           69.6            0.5
# Sanger_1.CLUST1                      2.8            1.2           69.7
# Sanger_2.CLUST0                      3.1            1.2           69.6
# Sanger_2.CLUST1                     67.9           69.5            0.5
# Stanford_1.CLUST0                    3.4            1.7           69.9
# Stanford_1.CLUST1                   67.9           69.7            1.0
# Stanford_2.CLUST0                   68.0           70.0            0.6
# Stanford_2.CLUST1                    3.0            1.6           70.2
# VIB_1.CLUST0                         2.9            1.1           69.7
# VIB_1.CLUST1                        67.8           69.6            0.4
# VIB_2.CLUST0                        67.9           69.6            0.6
# VIB_2.CLUST1                         3.0            1.2           69.8
# VIB_Hydrop_1.CLUST0                 66.5           68.3            1.0
# VIB_Hydrop_1.CLUST1                  3.1            2.2           68.3
# VIB_Hydrop_2.CLUST0                 67.5           68.1            1.1
# VIB_Hydrop_2.CLUST1                  0.0            3.4           67.7
# s3atac.CLUST0                        3.4            0.0           69.3
# s3atac.CLUST1                       67.7           69.3            0.0
#
# [30 rows x 30 columns]

# %%
# the number of common variants used to make the freemuxlet-derived VCF comparisons
nvar
# Out:
#                      Broad_1.CLUST0  Broad_1.CLUST1  Broad_2.CLUST0  \
# Broad_1.CLUST0                    0           26130           22716
# Broad_1.CLUST1                26130               0           22716
# Broad_2.CLUST0                22716           22716               0
# Broad_2.CLUST1                22716           22716           25239
# Broad_mito_1.CLUST0           22480           22480           22017
# Broad_mito_1.CLUST1           22480           22480           22017
# Broad_mito_2.CLUST0           22545           22545           22065
# Broad_mito_2.CLUST1           22545           22545           22065
# CNAG_1.CLUST0                 15863           15863           15675
# CNAG_1.CLUST1                 15863           15863           15675
# CNAG_2.CLUST0                 16649           16649           16393
# CNAG_2.CLUST1                 16649           16649           16393
# Sanger_1.CLUST0               25463           25463           24655
# Sanger_1.CLUST1               25463           25463           24655
# Sanger_2.CLUST0               25453           25453           24625
# Sanger_2.CLUST1               25453           25453           24625
# Stanford_1.CLUST0             14085           14085           14013
# Stanford_1.CLUST1             14085           14085           14013
# Stanford_2.CLUST0             11174           11174           11167
# Stanford_2.CLUST1             11174           11174           11167
# VIB_1.CLUST0                  21714           21714           21299
# VIB_1.CLUST1                  21714           21714           21299
# VIB_2.CLUST0                  23444           23444           22815
# VIB_2.CLUST1                  23444           23444           22815
# VIB_Hydrop_1.CLUST0            7178            7178            7172
# VIB_Hydrop_1.CLUST1            7178            7178            7172
# VIB_Hydrop_2.CLUST0            7477            7477            7480
# VIB_Hydrop_2.CLUST1            7477            7477            7480
# s3atac.CLUST0                 10678           10678           10653
# s3atac.CLUST1                 10678           10678           10653
#
#                      Broad_2.CLUST1  Broad_mito_1.CLUST0  Broad_mito_1.CLUST1  \
# Broad_1.CLUST0                22716                22480                22480
# Broad_1.CLUST1                22716                22480                22480
# Broad_2.CLUST0                25239                22017                22017
# Broad_2.CLUST1                    0                22017                22017
# Broad_mito_1.CLUST0           22017                    0                45478
# Broad_mito_1.CLUST1           22017                45478                    0
# Broad_mito_2.CLUST0           22065                39706                39706
# Broad_mito_2.CLUST1           22065                39706                39706
# CNAG_1.CLUST0                 15675                21324                21324
# CNAG_1.CLUST1                 15675                21324                21324
# CNAG_2.CLUST0                 16393                22982                22982
# CNAG_2.CLUST1                 16393                22982                22982
# Sanger_1.CLUST0               24655                38957                38957
# Sanger_1.CLUST1               24655                38957                38957
# Sanger_2.CLUST0               24625                39642                39642
# Sanger_2.CLUST1               24625                39642                39642
# Stanford_1.CLUST0             14013                16923                16923
# Stanford_1.CLUST1             14013                16923                16923
# Stanford_2.CLUST0             11167                12873                12873
# Stanford_2.CLUST1             11167                12873                12873
# VIB_1.CLUST0                  21299                28189                28189
# VIB_1.CLUST1                  21299                28189                28189
# VIB_2.CLUST0                  22815                34253                34253
# VIB_2.CLUST1                  22815                34253                34253
# VIB_Hydrop_1.CLUST0            7172                 7820                 7820
# VIB_Hydrop_1.CLUST1            7172                 7820                 7820
# VIB_Hydrop_2.CLUST0            7480                 8231                 8231
# VIB_Hydrop_2.CLUST1            7480                 8231                 8231
# s3atac.CLUST0                 10653                11549                11549
# s3atac.CLUST1                 10653                11549                11549
#
#                      Broad_mito_2.CLUST0  Broad_mito_2.CLUST1  CNAG_1.CLUST0  \
# Broad_1.CLUST0                     22545                22545          15863
# Broad_1.CLUST1                     22545                22545          15863
# Broad_2.CLUST0                     22065                22065          15675
# Broad_2.CLUST1                     22065                22065          15675
# Broad_mito_1.CLUST0                39706                39706          21324
# Broad_mito_1.CLUST1                39706                39706          21324
# Broad_mito_2.CLUST0                    0                45769          21377
# Broad_mito_2.CLUST1                45769                    0          21377
# CNAG_1.CLUST0                      21377                21377              0
# CNAG_1.CLUST1                      21377                21377          22506
# CNAG_2.CLUST0                      23065                23065          20293
# CNAG_2.CLUST1                      23065                23065          20293
# Sanger_1.CLUST0                    39072                39072          21522
# Sanger_1.CLUST1                    39072                39072          21522
# Sanger_2.CLUST0                    39848                39848          21589
# Sanger_2.CLUST1                    39848                39848          21589
# Stanford_1.CLUST0                  16887                16887          14118
# Stanford_1.CLUST1                  16887                16887          14118
# Stanford_2.CLUST0                  12838                12838          11733
# Stanford_2.CLUST1                  12838                12838          11733
# VIB_1.CLUST0                       28312                28312          20515
# VIB_1.CLUST1                       28312                28312          20515
# VIB_2.CLUST0                       34455                34455          21600
# VIB_2.CLUST1                       34455                34455          21600
# VIB_Hydrop_1.CLUST0                 7818                 7818           7601
# VIB_Hydrop_1.CLUST1                 7818                 7818           7601
# VIB_Hydrop_2.CLUST0                 8229                 8229           7960
# VIB_Hydrop_2.CLUST1                 8229                 8229           7960
# s3atac.CLUST0                      11558                11558           9944
# s3atac.CLUST1                      11558                11558           9944
#
#                      CNAG_1.CLUST1  ...  VIB_1.CLUST0  VIB_1.CLUST1  \
# Broad_1.CLUST0               15863  ...         21714         21714
# Broad_1.CLUST1               15863  ...         21714         21714
# Broad_2.CLUST0               15675  ...         21299         21299
# Broad_2.CLUST1               15675  ...         21299         21299
# Broad_mito_1.CLUST0          21324  ...         28189         28189
# Broad_mito_1.CLUST1          21324  ...         28189         28189
# Broad_mito_2.CLUST0          21377  ...         28312         28312
# Broad_mito_2.CLUST1          21377  ...         28312         28312
# CNAG_1.CLUST0                22506  ...         20515         20515
# CNAG_1.CLUST1                    0  ...         20515         20515
# CNAG_2.CLUST0                20293  ...         21783         21783
# CNAG_2.CLUST1                20293  ...         21783         21783
# Sanger_1.CLUST0              21522  ...         30273         30273
# Sanger_1.CLUST1              21522  ...         30273         30273
# Sanger_2.CLUST0              21589  ...         30296         30296
# Sanger_2.CLUST1              21589  ...         30296         30296
# Stanford_1.CLUST0            14118  ...         16164         16164
# Stanford_1.CLUST1            14118  ...         16164         16164
# Stanford_2.CLUST0            11733  ...         12570         12570
# Stanford_2.CLUST1            11733  ...         12570         12570
# VIB_1.CLUST0                 20515  ...             0         31222
# VIB_1.CLUST1                 20515  ...         31222             0
# VIB_2.CLUST0                 21600  ...         29599         29599
# VIB_2.CLUST1                 21600  ...         29599         29599
# VIB_Hydrop_1.CLUST0           7601  ...          7743          7743
# VIB_Hydrop_1.CLUST1           7601  ...          7743          7743
# VIB_Hydrop_2.CLUST0           7960  ...          8141          8141
# VIB_Hydrop_2.CLUST1           7960  ...          8141          8141
# s3atac.CLUST0                 9944  ...         11102         11102
# s3atac.CLUST1                 9944  ...         11102         11102
#
#                      VIB_2.CLUST0  VIB_2.CLUST1  VIB_Hydrop_1.CLUST0  \
# Broad_1.CLUST0              23444         23444                 7178
# Broad_1.CLUST1              23444         23444                 7178
# Broad_2.CLUST0              22815         22815                 7172
# Broad_2.CLUST1              22815         22815                 7172
# Broad_mito_1.CLUST0         34253         34253                 7820
# Broad_mito_1.CLUST1         34253         34253                 7820
# Broad_mito_2.CLUST0         34455         34455                 7818
# Broad_mito_2.CLUST1         34455         34455                 7818
# CNAG_1.CLUST0               21600         21600                 7601
# CNAG_1.CLUST1               21600         21600                 7601
# CNAG_2.CLUST0               23294         23294                 7671
# CNAG_2.CLUST1               23294         23294                 7671
# Sanger_1.CLUST0             38408         38408                 7807
# Sanger_1.CLUST1             38408         38408                 7807
# Sanger_2.CLUST0             38835         38835                 7805
# Sanger_2.CLUST1             38835         38835                 7805
# Stanford_1.CLUST0           16777         16777                 7658
# Stanford_1.CLUST1           16777         16777                 7658
# Stanford_2.CLUST0           12759         12759                 7303
# Stanford_2.CLUST1           12759         12759                 7303
# VIB_1.CLUST0                29599         29599                 7743
# VIB_1.CLUST1                29599         29599                 7743
# VIB_2.CLUST0                    0         41528                 7776
# VIB_2.CLUST1                41528             0                 7776
# VIB_Hydrop_1.CLUST0          7776          7776                    0
# VIB_Hydrop_1.CLUST1          7776          7776                 7933
# VIB_Hydrop_2.CLUST0          8196          8196                 6874
# VIB_Hydrop_2.CLUST1          8196          8196                 6874
# s3atac.CLUST0               11416         11416                 5973
# s3atac.CLUST1               11416         11416                 5973
#
#                      VIB_Hydrop_1.CLUST1  VIB_Hydrop_2.CLUST0  \
# Broad_1.CLUST0                      7178                 7477
# Broad_1.CLUST1                      7178                 7477
# Broad_2.CLUST0                      7172                 7480
# Broad_2.CLUST1                      7172                 7480
# Broad_mito_1.CLUST0                 7820                 8231
# Broad_mito_1.CLUST1                 7820                 8231
# Broad_mito_2.CLUST0                 7818                 8229
# Broad_mito_2.CLUST1                 7818                 8229
# CNAG_1.CLUST0                       7601                 7960
# CNAG_1.CLUST1                       7601                 7960
# CNAG_2.CLUST0                       7671                 8052
# CNAG_2.CLUST1                       7671                 8052
# Sanger_1.CLUST0                     7807                 8219
# Sanger_1.CLUST1                     7807                 8219
# Sanger_2.CLUST0                     7805                 8212
# Sanger_2.CLUST1                     7805                 8212
# Stanford_1.CLUST0                   7658                 7991
# Stanford_1.CLUST1                   7658                 7991
# Stanford_2.CLUST0                   7303                 7581
# Stanford_2.CLUST1                   7303                 7581
# VIB_1.CLUST0                        7743                 8141
# VIB_1.CLUST1                        7743                 8141
# VIB_2.CLUST0                        7776                 8196
# VIB_2.CLUST1                        7776                 8196
# VIB_Hydrop_1.CLUST0                 7933                 6874
# VIB_Hydrop_1.CLUST1                    0                 6874
# VIB_Hydrop_2.CLUST0                 6874                    0
# VIB_Hydrop_2.CLUST1                 6874                 8367
# s3atac.CLUST0                       5973                 6072
# s3atac.CLUST1                       5973                 6072
#
#                      VIB_Hydrop_2.CLUST1  s3atac.CLUST0  s3atac.CLUST1
# Broad_1.CLUST0                      7477          10678          10678
# Broad_1.CLUST1                      7477          10678          10678
# Broad_2.CLUST0                      7480          10653          10653
# Broad_2.CLUST1                      7480          10653          10653
# Broad_mito_1.CLUST0                 8231          11549          11549
# Broad_mito_1.CLUST1                 8231          11549          11549
# Broad_mito_2.CLUST0                 8229          11558          11558
# Broad_mito_2.CLUST1                 8229          11558          11558
# CNAG_1.CLUST0                       7960           9944           9944
# CNAG_1.CLUST1                       7960           9944           9944
# CNAG_2.CLUST0                       8052          10104          10104
# CNAG_2.CLUST1                       8052          10104          10104
# Sanger_1.CLUST0                     8219          11800          11800
# Sanger_1.CLUST1                     8219          11800          11800
# Sanger_2.CLUST0                     8212          11801          11801
# Sanger_2.CLUST1                     8212          11801          11801
# Stanford_1.CLUST0                   7991           9117           9117
# Stanford_1.CLUST1                   7991           9117           9117
# Stanford_2.CLUST0                   7581           8090           8090
# Stanford_2.CLUST1                   7581           8090           8090
# VIB_1.CLUST0                        8141          11102          11102
# VIB_1.CLUST1                        8141          11102          11102
# VIB_2.CLUST0                        8196          11416          11416
# VIB_2.CLUST1                        8196          11416          11416
# VIB_Hydrop_1.CLUST0                 6874           5973           5973
# VIB_Hydrop_1.CLUST1                 6874           5973           5973
# VIB_Hydrop_2.CLUST0                 8367           6072           6072
# VIB_Hydrop_2.CLUST1                    0           6072           6072
# s3atac.CLUST0                       6072              0          12102
# s3atac.CLUST1                       6072          12102              0
#
# [30 rows x 30 columns]

# %%
g = sns.clustermap(nrd.round(1), annot=True,  linecolor='gray',
                   yticklabels=True, xticklabels=True,
                   vmin=0.0, vmax=nrd.max().max(), # row_colors=colormap,
                   cmap=sns.color_palette('Reds'),
                   #cmap='vlag',
                   cbar_kws={'label': 'Non-ref. discord rate (%)'},
                   figsize=(12,12) )
g.cax.set_visible(True)
g.savefig('fmx_out/freemuxlet_nrd_fulldata.pdf', dpi=300, bbox_inches = "tight")
# Out:
# /opt/venv/lib/python3.8/site-packages/seaborn/matrix.py:624: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(self.array, method=self.method,

# %%
f_gc = 'fmx_out/genotype_concordance_unified.txt'

gc = pd.read_csv(f_gc, sep='\t')
gc
# Out:
#              INT_ID                                            BARCODE  \
# Broad_1.1         0  TAACGCCAATTGGTTAGTGTT_TGGAAGGCTGGCATGCGTAGA_AG...
# Broad_1.2         1        AGCGAATGGTTCACCCTATGT_CATGTATGTGGCGCCGTACAA
# Broad_1.3         2  CGTTTGACTGCGCCCAGAGAG_AATGATTAATGATTAGGATAC_TC...
# Broad_1.4         3  GAACCGTAAGCAGCGCCTCGT_CTGGCATCGTGATAAGACCAT_TA...
# Broad_1.5         4        CTATTCGTTGGTTAATTCGTT_ATGAGCTCGATGCAAATGGCC
# ...             ...                                                ...
# s3atac.3118    3117                       GGCTGGCTCTAATTGAGTTATCCGCTAA
# s3atac.3119    3118                       ATTGAGGATACTGCATTACGGCACGGAC
# s3atac.3120    3119                       GCAGGTCGTCCGCCGATATCTCTCTACT
# s3atac.3121    3120                       GGTTAGTTGGGGCATAACCGCTTATCGG
# s3atac.3122    3121                       GATTCGGTCATATTGCAGCTGCACGGAC
#
#              NUM.SNPS  NUM.READS DROPLET.TYPE BEST.GUESS  BEST.LLK NEXT.GUESS  \
# Broad_1.1        5730       5730          SNG        1,1 -10611.19        1,0
# Broad_1.2        1346       1346          SNG        0,0  -2404.38        1,0
# Broad_1.3        1043       1043          SNG        1,1  -1844.78        1,0
# Broad_1.4         932        932          SNG        0,0  -1678.63        1,0
# Broad_1.5        2252       2252          SNG        0,0  -4020.34        1,0
# ...               ...        ...          ...        ...       ...        ...
# s3atac.3118       399        399          SNG        1,1   -712.74        1,0
# s3atac.3119       556        556          SNG        0,0   -998.81        1,0
# s3atac.3120       264        264          SNG        1,1   -466.03        1,0
# s3atac.3121       485        485          SNG        1,1   -876.48        1,0
# s3atac.3122       321        321          SNG        1,1   -564.04        1,0
#
#              NEXT.LLK  DIFF.LLK.BEST.NEXT  ...  SNG.BEST.LLK  SNG.NEXT.GUESS  \
# Broad_1.1   -10820.83              209.64  ...     -10611.19               0
# Broad_1.2    -2573.58              169.20  ...      -2404.38               1
# Broad_1.3    -1989.71              144.94  ...      -1844.78               0
# Broad_1.4    -1802.85              124.21  ...      -1678.63               1
# Broad_1.5    -4299.26              278.92  ...      -4020.34               1
# ...               ...                 ...  ...           ...             ...
# s3atac.3118   -762.36               49.63  ...       -712.74               0
# s3atac.3119  -1040.59               41.77  ...       -998.81               1
# s3atac.3120   -495.28               29.25  ...       -466.03               0
# s3atac.3121   -901.28               24.80  ...       -876.48               0
# s3atac.3122   -605.87               41.84  ...       -564.04               0
#
#              SNG.NEXT.LLK  SNG.ONLY.POSTERIOR  DBL.BEST.GUESS  DBL.BEST.LLK  \
# Broad_1.1       -12152.14                 1.0             1,0     -10820.83
# Broad_1.2        -3106.74                 1.0             1,0      -2573.58
# Broad_1.3        -2408.30                 1.0             1,0      -1989.71
# Broad_1.4        -2189.64                 1.0             1,0      -1802.85
# Broad_1.5        -5110.11                 1.0             1,0      -4299.26
# ...                   ...                 ...             ...           ...
# s3atac.3118       -862.65                 1.0             1,0       -762.36
# s3atac.3119      -1110.97                 1.0             1,0      -1040.59
# s3atac.3120       -552.63                 1.0             1,0       -495.28
# s3atac.3121       -949.17                 1.0             1,0       -901.28
# s3atac.3122       -683.17                 1.0             1,0       -605.87
#
#              DIFF.LLK.SNG.DBL  \
# Broad_1.1              209.64
# Broad_1.2              169.20
# Broad_1.3              144.94
# Broad_1.4              124.21
# Broad_1.5              278.92
# ...                       ...
# s3atac.3118             49.63
# s3atac.3119             41.77
# s3atac.3120             29.25
# s3atac.3121             24.80
# s3atac.3122             41.84
#
#                                                       ubarcode  replicate  \
# Broad_1.1    Broad_1#TAACGCCAATTGGTTAGTGTT_TGGAAGGCTGGCATGC...    Broad_1
# Broad_1.2    Broad_1#AGCGAATGGTTCACCCTATGT_CATGTATGTGGCGCCG...    Broad_1
# Broad_1.3    Broad_1#CGTTTGACTGCGCCCAGAGAG_AATGATTAATGATTAG...    Broad_1
# Broad_1.4    Broad_1#GAACCGTAAGCAGCGCCTCGT_CTGGCATCGTGATAAG...    Broad_1
# Broad_1.5    Broad_1#CTATTCGTTGGTTAATTCGTT_ATGAGCTCGATGCAAA...    Broad_1
# ...                                                        ...        ...
# s3atac.3118                s3atac#GGCTGGCTCTAATTGAGTTATCCGCTAA     s3atac
# s3atac.3119                s3atac#ATTGAGGATACTGCATTACGGCACGGAC     s3atac
# s3atac.3120                s3atac#GCAGGTCGTCCGCCGATATCTCTCTACT     s3atac
# s3atac.3121                s3atac#GGTTAGTTGGGGCATAACCGCTTATCGG     s3atac
# s3atac.3122                s3atac#GATTCGGTCATATTGCAGCTGCACGGAC     s3atac
#
#               sample
# Broad_1.1    sampleB
# Broad_1.2    sampleA
# Broad_1.3    sampleB
# Broad_1.4    sampleA
# Broad_1.5    sampleA
# ...              ...
# s3atac.3118  sampleA
# s3atac.3119  sampleB
# s3atac.3120  sampleA
# s3atac.3121  sampleA
# s3atac.3122  sampleA
#
# [47761 rows x 23 columns]

# %% [markdown]
# ### Fmeemuxlet plots
#
# Loading data from unified fmeemuxlet annotations (inferred samples are linked)

# %%
#

tp = gc[['replicate','sample']].copy()
tp['droplet_type'] = tp['sample'].copy()
tp.loc[ tp['droplet_type']=='Undetermined', 'droplet_type'] = 'Doublet'
tp = tp.groupby(['replicate','droplet_type']).size().rename('count').reset_index()

tp.columns = ['sampleId','droplet_type','count']
tp.sort_values('sampleId', inplace=True)
tp
# Out:
#         sampleId droplet_type  count
# 0        Broad_1      Doublet    129
# 1        Broad_1      sampleA   2431
# 2        Broad_1      sampleB   1644
# 3        Broad_2      Doublet     99
# 4        Broad_2      sampleA   2319
# 5        Broad_2      sampleB   1635
# 6   Broad_mito_1      Doublet     25
# 7   Broad_mito_1      sampleA   1677
# 8   Broad_mito_1      sampleB   1764
# 11  Broad_mito_2      sampleB   1729
# 10  Broad_mito_2      sampleA   1548
# 9   Broad_mito_2      Doublet     25
# 12        CNAG_1      Doublet     43
# 13        CNAG_1      sampleA   1414
# 14        CNAG_1      sampleB   1239
# 15        CNAG_2      Doublet     47
# 16        CNAG_2      sampleA   1372
# 17        CNAG_2      sampleB   1293
# 18      Sanger_1      Doublet    212
# 19      Sanger_1      sampleA   1538
# 20      Sanger_1      sampleB   1392
# 23      Sanger_2      sampleB   1690
# 21      Sanger_2      Doublet    276
# 22      Sanger_2      sampleA   1848
# 24    Stanford_1      Doublet      5
# 25    Stanford_1      sampleA    393
# 26    Stanford_1      sampleB    370
# 27    Stanford_2      Doublet      4
# 28    Stanford_2      sampleA    680
# 29    Stanford_2      sampleB    719
# 32         VIB_1      sampleB   1384
# 30         VIB_1      Doublet     27
# 31         VIB_1      sampleA   1402
# 35         VIB_2      sampleB   4099
# 33         VIB_2      Doublet    200
# 34         VIB_2      sampleA   3037
# 36  VIB_Hydrop_1      Doublet     44
# 37  VIB_Hydrop_1      sampleA   1300
# 38  VIB_Hydrop_1      sampleB   1017
# 40  VIB_Hydrop_2      sampleA   1408
# 39  VIB_Hydrop_2      Doublet     58
# 41  VIB_Hydrop_2      sampleB   1103
# 42        s3atac      sampleA   1790
# 43        s3atac      sampleB   1332

# %%
# get all unique freemuxlet calls:
bgu = tp['droplet_type'].unique()
bgu.sort()
bgu = ['sampleA', 'Doublet', 'sampleB']

# %%
fig, ax = plt.subplots(1,1, figsize=(7,4), dpi=150 )

g = sns.barplot(x="sampleId", y="count", hue="droplet_type", data=tp, ax=ax)
g.set_xticklabels(g.get_xticklabels(), rotation=20, ha='right', fontsize=8)

ax.set_title('Freemuxlet classification (2-sample pool)')
ax.legend(title='Droplet type')
ax.set_xlabel('')

plt.tight_layout()
plt.show()

# %%
csum = pd.DataFrame([], index=tp['sampleId'].unique() )
#csum['lower']=0
for y in bgu:
    #print(tp[ tp['droplet_type']==y ])
    tmp = tp[ tp['droplet_type']==y ].set_index('sampleId')
    #csum[y] = pd.merge(csum, tmp['count'], left_index=True, right_index=True, how='left').sum(axis=1)
    csum[y] = tmp['count']
    
csum.fillna(0,inplace=True)
csum
# Out:
#               sampleA  Doublet  sampleB
# Broad_1          2431    129.0     1644
# Broad_2          2319     99.0     1635
# Broad_mito_1     1677     25.0     1764
# Broad_mito_2     1548     25.0     1729
# CNAG_1           1414     43.0     1239
# CNAG_2           1372     47.0     1293
# Sanger_1         1538    212.0     1392
# Sanger_2         1848    276.0     1690
# Stanford_1        393      5.0      370
# Stanford_2        680      4.0      719
# VIB_1            1402     27.0     1384
# VIB_2            3037    200.0     4099
# VIB_Hydrop_1     1300     44.0     1017
# VIB_Hydrop_2     1408     58.0     1103
# s3atac           1790      0.0     1332

# %%
fig, ax = plt.subplots(1,1, figsize=(5,4), dpi=150 )

width=0.75

lower = pd.DataFrame([], index=tp['sampleId'].unique() )
lower['lower']=0
for y in bgu:
    ax.bar(x=csum.index, height=csum[y], width=width, bottom=lower['lower'], label=y)#, color='#377CB6')
    lower['lower'] = csum.iloc[:,:(csum.columns.get_loc(y)+1) ].sum(axis=1)

ax.set_ylabel('Cell count')
ax.set_xlabel('')
plt.xticks(rotation=30, ha='right', fontsize=8)

ax.set_title('Freemuxlet classification (2-sample pool)')
ax.legend()#title='Freemuxlet')
plt.savefig('plts_qc/freemuxlet_counts.png', facecolor='white')
plt.show()
