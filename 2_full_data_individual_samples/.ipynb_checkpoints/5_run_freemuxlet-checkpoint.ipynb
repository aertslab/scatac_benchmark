# %% [markdown]
# We now run freemuxlet on all samples. We need freemuxlet results for the QC.

# %%
nwork=${VSC_SCRATCH}/hca_benchmark_freemuxlet/
mkdir $nwork
export NXF_WORK=$nwork
module load Nextflow
VSN=/staging/leuven/stg_00002/lcb/cflerin/testruns/vib-singlecell-nf/vsn__develop_atac/vsn-pipelines/main.nf
# Out:
# mkdir: cannot create directory ‘/scratch/leuven/330/vsc33042/hca_benchmark_freemuxlet/’: File exists

# %%
nextflow config $VSN \
    -profile bam,tsv,popscle,vsc \
    > vsn_freemuxlet_2.config

# %% [markdown]
# * change vcf to `vcf = '/staging/leuven/stg_00002/lcb/cflerin/data/public/1000G/1000Genomes.wgs.GRCH38.sites.minAF-0.1.freemuxlet-scATAC.vcf.gz'`
# * change tsv paths to `file_paths = out_qc_all/data/pycistopic/qc/selected_barcodes/*.cell_barcodes.txt'`
# * change bam paths to ` file_paths = '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021/atac_preprocess/multiplet_tagged/bam/*_1.bwa.out.possorted.mm.bam,/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021/atac_preprocess/multiplet_tagged/bam/*_2.bwa.out.possorted.mm.bam'`
# * change out directory to `out_fmx`
# * EXTREMELY IMPORTANT: Change the `barcode_tag = DB`! Otherwise you won't use multiplet merged cell barcodes!

# %% [markdown]
# I generate a config for all the hydrop samples. You can also run all samples together.

# %% [markdown]
# for hydrop:
# /lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_rerun_all_with_hydrop/bams_postbap/VIB_Hydrop_?*
# /lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_rerun_all_with_hydrop/out_qc_all/data/pycistopic/qc/selected_barcodes/VIB_Hydrop_?*

# %%
cat vsn_freemuxlet.config
# Out:
# manifest {
#    name = 'vib-singlecell-nf/vsn-pipelines'
#    description = 'A repository of pipelines for single-cell data in Nextflow DSL2'
#    homePage = 'https://github.com/vib-singlecell-nf/vsn-pipelines'
#    version = '0.27.0'
#    mainScript = 'main.nf'
#    defaultBranch = 'master'
#    nextflowVersion = '!>=21.04.3'
# }
#
# params {
#    global {
#       project_name = 'benchmark_fulldata_fmx'
#       outdir = 'out_fmx'
#    }
#    misc {
#       test {
#          enabled = false
#       }
#    }
#    utils {
#       container = 'vibsinglecellnf/utils:0.4.0'
#       file_converter {
#          off = 'h5ad'
#          tagCellWithSampleId = true
#          remove10xGEMWell = false
#          useFilteredMatrix = true
#          makeVarIndexUnique = false
#       }
#       publish {
#          compressionLevel = 6
#          annotateWithBatchVariableName = false
#          mode = 'copy'
#       }
#    }
#    tools {
#       popscle {
#          container = 'vibsinglecellnf/popscle:2021-05-05-da70fc7'
#          vcf = '/staging/leuven/stg_00002/lcb/cflerin/data/public/1000G/1000Genomes.wgs.GRCH38.sites.minAF-0.1.freemuxlet-scATAC.vcf.gz'
#          barcode_tag = 'CB'
#          freemuxlet {
#             nSamples = 2
#          }
#          demuxlet {
#             field = 'GT'
#          }
#       }
#       file_converter {
#          iff = 'bam'
#       }
#    }
#    data {
#       tsv {
#          file_paths = '/lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_rerun_all_with_hydrop/out_qc_all/data/pycistopic/qc/selected_barcodes/VIB_Hydrop_?*'
#          suffix = '.cell_barcodes.txt'
#       }
#       bam {
#          file_paths = '/lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_rerun_all_with_hydrop/bams_postbap/VIB_Hydrop_?*.bam'
#          suffix = '.bwa.out.possorted.mm.bam'
#          index_extension = '.bai'
#       }
#    }
# }
#
# process {
#    executor = 'local'
#    cpus = 2
#    memory = '60 GB'
#    clusterOptions = '-A cluster_account'
#    withLabel:compute_resources__default {
#       time = '1h'
#    }
#    withLabel:compute_resources__minimal {
#       cpus = 1
#       memory = '1 GB'
#    }
#    withLabel:compute_resources__mem {
#       cpus = 4
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__cpu {
#       cpus = 20
#       memory = '80 GB'
#    }
#    withLabel:compute_resources__report {
#       maxForks = 2
#       cpus = 1
#       memory = '160 GB'
#    }
#    withLabel:compute_resources__24hqueue {
#       time = '24h'
#    }
# }
#
# timeline {
#    enabled = true
#    file = 'out/nextflow_reports/execution_timeline.html'
# }
#
# report {
#    enabled = true
#    file = 'out/nextflow_reports/execution_report.html'
# }
#
# trace {
#    enabled = true
#    file = 'out/nextflow_reports/execution_trace.txt'
# }
#
# dag {
#    enabled = true
#    file = 'out/nextflow_reports/pipeline_dag.svg'
# }
#
# min {
#    enabled = false
# }
#
# vsc {
#    enabled = true
# }
#
# singularity {
#    enabled = true
#    autoMounts = true
#    runOptions = '--cleanenv -H $PWD -B /lustre1,/staging,/data,${VSC_SCRATCH},${VSC_SCRATCH}/tmp:/tmp,${HOME}/.nextflow/assets/'
#    cacheDir = '/staging/leuven/res_00001/software/vsn_containers/'
# }

# %% [markdown]
# then, run the pipeline (in tmux):

# %%
nextflow -C vsn_freemuxlet_hydrop.config run $VSN -entry freemuxlet -resume

# %% [markdown]
# The terminal output should look like so (Running for 2 samples only):

# %% [markdown]
# ```
# [08/67852a] process > freemuxlet:FREEMUXLET:DSC_PILEUP_FILTERED:SC__POPSCLE__PREFILTER_DSC_PILEUP (2) [  0%] 0 of 2
# [-        ] process > freemuxlet:FREEMUXLET:DSC_PILEUP_FILTERED:SC__POPSCLE__DSC_PILEUP               -
# [-        ] process > freemuxlet:FREEMUXLET:SC__POPSCLE__FREEMUXLET                                   -
#
# ------------------------------------------------------------------
#  No seed detected in the config
#  To ensure reproducibility the seed has been set to 270
# ------------------------------------------------------------------
# ```

# %% [markdown]
# # now, generate concordance files

# %%
cat cflerin/fmx/evaluate_fmx_concordance.notes
# Out:
# ################################################################################
# ################################################################################
# ################################################################################
# # use the python scripts in concordance/ to evaluate genotype concordance
#
# module load BCFtools
# module load VCFtools
#
# mkdir intermediate
#
# # first, subset vcfs, changing the sample name to be identical in every file (for vcf-compare to work)
# ./deconvolute_freemuxlet_results.py > vcf_filter_subset_compare.parallel
# # note: running too many processes in parallel may cause a vcf-compare step to run prior to the completion of an earlier filtering command, and cause an error
# time cat vcf_filter_subset_compare.parallel | parallel -j 2 --progress
#
#
# # second, compile the results from vcf-compare into a table:
# ./evaluate_genotype_concordances.py
# # (creates two files: genotype_concordance_nvar.txt, and genotype_concordance_nrd.txt)
#
# #mv genotype_concordance_nvar.txt genotype_concordance_ATAC_nvar.txt
# #mv genotype_concordance_nrd.txt genotype_concordance_ATAC_nrd.txt
#
#
# # ./plot_heatmap.py --input genotype_concordance_RNA_nrd.txt --output genotype_concordance_heatmap_RNA.pdf
# #./plot_heatmap.py --input genotype_concordance_ATAC_nrd.txt --output genotype_concordance_heatmap_ATAC.pdf
# ./plot_heatmap.py --input genotype_concordance_nrd.txt --output genotype_concordance_heatmap.pdf
#
#
# # finally, generate a combined annotation file using `genotype_concordance_pairings.R`

# %%
module load BCFtools
module load VCFtools

INTERMEDIATE=fmx_out/intermediate
mkdir $INTERMEDIATE
# Out:
# mkdir: cannot create directory ‘fmx_out/intermediate’: File exists
# : 1

# %% [markdown]
# We now cross-compare all vcfs. First, generate a list of commands using `deconvolute_freemuxlet_results.py`.
# in `deconvolute_freemuxlet_results.py`, we need to change:
# * base dir with output from vsn fmx pipeline
# * intermediate output dir
# * sample names

# %%
./fmx_out/deconvolute_freemuxlet_results.py > fmx_out/vcf_filter_subset_compare.parallel

# %% [markdown]
# then, run the resulting file

# %%
time cat fmx_out/vcf_filter_subset_compare.parallel | parallel -j 4 --progress
# Out:
# Computers / CPU cores / Max jobs to run
# 1:local / 35 / 4
#
# Computer:jobs running/jobs completed/%of started jobs/Average seconds to complete
# local:4/28/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/29/100%/0.9s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/30/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/33/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/34/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/35/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/36/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/37/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/38/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/39/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/40/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/41/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/42/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/43/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/44/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/45/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/46/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/47/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/48/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/49/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/50/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/51/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/52/100%/0.8s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/53/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/54/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/55/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/56/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/57/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/58/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/59/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/60/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/61/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/62/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/63/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/64/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/65/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/66/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/67/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/68/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/69/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/70/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/71/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/72/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/73/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/74/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/75/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/76/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/77/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/78/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/79/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/80/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/81/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/82/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/83/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/84/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/85/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/86/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/87/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/88/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/89/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/90/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/91/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/92/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/93/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/94/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/95/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/96/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/97/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/98/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/99/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/100/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/101/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/102/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/103/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/104/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/105/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/106/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/107/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/108/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/109/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/110/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/111/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/112/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/113/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/114/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/115/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/116/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/117/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/118/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/119/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/120/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/121/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/122/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/123/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/124/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/125/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/126/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/127/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/128/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/129/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/130/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/131/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/132/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/133/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/134/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/135/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/136/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/137/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/138/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/139/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/140/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/141/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/142/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/143/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/144/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/145/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/146/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/147/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/148/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/149/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/150/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/151/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/152/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/153/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/154/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/155/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/156/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/157/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/158/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/159/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/160/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/161/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/162/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/163/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/164/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/165/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/166/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/167/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/168/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/169/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/170/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/171/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/172/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/173/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/174/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/175/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/176/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/177/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/178/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/179/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/180/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/181/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/182/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/183/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/184/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/185/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/186/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/187/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/188/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/189/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/190/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/191/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/192/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/193/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/194/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/195/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/196/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/197/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/198/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/199/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/200/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/201/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/202/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/203/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/204/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/205/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/206/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/207/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/208/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/209/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/210/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/211/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/212/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/213/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/214/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/215/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/216/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/217/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/218/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/219/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/220/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/221/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/222/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/223/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/224/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/225/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/226/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/227/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/228/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/229/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/230/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/231/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/232/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/233/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/234/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/235/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/236/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/237/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/238/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/239/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/240/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/241/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/242/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/243/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/244/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/245/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/246/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/247/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/248/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/249/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/250/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/251/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/252/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/253/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/254/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/255/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/256/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/257/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/258/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/259/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/260/100%/0.7s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/261/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/262/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/263/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/264/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/265/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/266/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/267/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/268/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/269/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/270/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/271/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/272/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/273/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/274/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/275/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/276/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/277/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/278/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/279/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/280/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/281/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/282/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/283/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/284/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/285/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/286/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/287/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/288/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/289/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/290/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/291/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/292/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/293/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/294/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/295/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/296/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/297/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/298/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/299/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/300/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/301/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/302/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/303/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/304/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/305/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/306/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/307/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/308/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/309/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/310/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/311/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/312/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/313/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/314/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/315/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/316/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/317/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/318/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/319/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/320/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/321/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/322/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/323/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/324/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/325/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/326/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/327/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/328/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/329/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/330/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/331/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/332/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/333/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/334/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/335/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/336/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/337/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/338/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/339/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/340/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/341/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/342/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/343/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/344/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/345/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/346/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/347/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/348/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/349/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/350/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/351/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/352/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/353/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/354/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/355/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/356/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/357/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/358/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/359/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/360/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/361/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/362/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/363/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/364/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/365/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/366/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/367/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/368/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/369/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/370/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/371/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/372/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/373/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/374/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/375/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/376/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/377/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/378/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/379/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/380/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/381/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/382/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/383/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/384/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/385/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/386/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/387/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/388/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/389/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/390/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/391/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/392/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/393/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/394/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/395/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/396/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/397/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/398/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/399/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/400/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/401/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/402/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/403/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/404/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/405/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/406/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/407/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/408/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/409/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/410/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/411/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/412/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/413/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/414/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/415/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/416/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/417/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/418/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/419/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/420/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/421/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/422/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/423/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/424/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/425/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/426/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/427/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/428/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/429/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/430/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/431/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/432/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/433/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/434/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/435/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/436/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/437/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/438/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/439/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/440/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/441/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/442/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/443/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/444/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/445/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/446/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/447/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/448/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/449/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/450/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/451/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/452/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/453/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/454/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/455/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/456/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/457/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/458/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/459/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/460/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/461/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/462/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/463/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/464/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/465/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/466/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/467/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/468/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/469/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/470/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/471/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/472/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/473/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/474/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/475/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/476/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/477/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/478/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/479/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/480/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/481/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/482/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/483/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/484/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/485/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/486/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/487/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/488/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/489/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/490/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/491/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/492/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/493/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/494/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/495/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/496/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/497/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/498/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/499/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/500/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/501/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/502/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/503/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/504/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/505/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/506/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/507/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/508/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/509/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/510/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/511/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/512/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/513/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/514/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/515/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/516/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/517/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/518/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/519/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/520/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/521/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/522/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/523/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/524/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/525/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/526/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/527/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/528/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/529/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/530/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/531/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/532/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/533/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/534/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/535/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/536/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/537/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/538/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/539/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/540/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/541/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/542/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/543/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/544/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/545/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/546/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/547/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/548/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/549/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/550/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/551/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/552/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/553/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/554/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/555/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/556/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/557/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/558/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/559/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/560/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/561/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/562/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/563/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/564/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/565/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/566/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/567/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/568/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/569/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/570/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/571/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/572/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/573/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/574/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/575/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/576/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/577/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/578/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/579/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/580/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/581/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/582/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/583/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/584/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/585/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/586/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/587/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/588/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/589/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/590/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/591/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/592/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/593/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/594/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/595/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/596/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/597/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/598/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/599/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/600/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/601/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/602/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/603/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/604/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/605/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/606/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/607/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/608/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/609/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/610/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/611/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/612/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/613/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/614/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/615/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/616/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/617/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/618/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/619/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/620/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/621/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/622/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/623/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/624/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/625/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/626/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/627/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/628/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/629/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/630/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/631/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/632/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/633/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/634/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/635/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/636/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/637/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/638/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/639/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/640/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/641/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/642/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/643/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/644/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/645/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/646/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/647/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/648/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/649/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/650/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/651/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/652/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/653/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/654/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/655/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/656/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/657/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/658/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/659/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/660/100%/0.6s
# gzip: stdout: Broken pipe
#
# ...
#
# gzip: stdout: Broken pipe
# local:4/721/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/722/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/723/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/724/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/725/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/726/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/727/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/728/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/729/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/730/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/731/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/732/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/733/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/734/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/735/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/736/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/737/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/738/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/739/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/740/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/741/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/742/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/743/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/744/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/745/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/746/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/747/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/748/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/749/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/750/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/751/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/752/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/753/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/754/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/755/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/756/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/757/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/758/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/759/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/760/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/761/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/762/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/763/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/764/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/765/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/766/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/767/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/768/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/769/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/770/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/771/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/772/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/773/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/774/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/775/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/776/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/777/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/778/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/779/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/780/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/781/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/782/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/783/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/784/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/785/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/786/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/787/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/788/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/789/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/790/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/791/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/792/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/793/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/794/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/795/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/796/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/797/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/798/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/799/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/800/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/801/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/802/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/803/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/804/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/805/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/806/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/807/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/808/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/809/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/810/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/811/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/812/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/813/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/814/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/815/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/816/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/817/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/818/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/819/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/820/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/821/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/822/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/823/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/824/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/825/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/826/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/827/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/828/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/829/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/830/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/831/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/832/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/833/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/834/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/835/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/836/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/837/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/838/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/839/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/840/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/841/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/842/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/843/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/844/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/845/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/846/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/847/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/848/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/849/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/850/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/851/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/852/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/853/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/854/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/855/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/856/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/857/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/858/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/859/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/860/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/861/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/862/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/863/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/864/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/865/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/866/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/867/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/868/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/869/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/870/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/871/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/872/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/873/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/874/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/875/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/876/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/877/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/878/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/879/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/880/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/881/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/882/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/883/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/884/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/885/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/886/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/887/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/888/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/889/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/890/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/891/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/892/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/893/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/894/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/895/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/896/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/897/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/898/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/899/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/900/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/901/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/902/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/903/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/904/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/905/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/906/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/907/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/908/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/909/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/910/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/911/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/912/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/913/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/914/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/915/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/916/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/917/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/918/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/919/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/920/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/921/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/922/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/923/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/924/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/925/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:4/926/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:3/927/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:2/928/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:1/929/100%/0.6s
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
# local:0/930/100%/0.6s
#
# real	8m52.181s
# user	32m11.573s
# sys	9m21.935s

# %% [markdown]
# then, evaluate the output by running `evaluate_genotype_concordances.py`. Change the following:
# * sample names
# * intermediate dir
# * output dir

# %%
fmx_out/evaluate_genotype_concordances.py
# Out:
# Created two files:
# 	genotype_concordance_nvar.txt
# 	genotype_concordance_nrd.txt

# %%
fmx_out/plot_heatmap.py --input fmx_out/genotype_concordance_nrd.txt --output fmx_out/genotype_concordance_heatmap.pdf
# Out:
# /staging/leuven/stg_00002/lcb/fderop/software_2/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:1216: UserWarning: ``square=True`` ignored in clustermap
#   warnings.warn(msg)
# /staging/leuven/stg_00002/lcb/fderop/software_2/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:620: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   metric=self.metric)

# %% [markdown]
# now, r script. I need to manually insert the concordance of the clusters:
# ![image.png](attachment:0292ad9b-5ef8-4a11-9d33-1c14cf60495c.png)

# %% [markdown]
# becomes:
# ```
# sampleA = list(
#     c('Broad_1',0),
#     c('Broad_2',1),
#     c('Broad_mito_1',1),
#     c('Broad_mito_2',1),
#     c('CNAG_1',1),
#     c('CNAG_2',1),
#     c('Sanger_1',0),
#     c('Sanger_2',1),
#     c('Stanford_1',1),
#     c('Stanford_2',0),
#     c('VIB_1',1),
#     c('VIB_2',0),
#     c('VIB_Hydrop_1',0),
#     c('VIB_Hydrop_2',0),
#     c('s3atac',1)
# )
# ```

# %%
singularity run --cleanenv -H $PWD -B /lustre1,/staging,${VSC_SCRATCH}/tmp:/tmp /staging/leuven/stg_00002/lcb/cflerin/containers/cflerin-seurat-4.0.3-plus.sif

# %% [markdown]
# then run `genotype_concordance_pairings.R`

# %%
cat fmx_out/genotype_concordance_pairings.R
# Out:
# f_fmx_dir = 'fmx_out/out/'
#
# samples = c(
#     'Broad_1',
#     'Broad_2',
#     'Broad_mito_1',
#     'Broad_mito_2',
#     'CNAG_1',
#     'CNAG_2',
#     'Sanger_1',
#     'Sanger_2',
#     'Stanford_1',
#     'Stanford_2',
#     'VIB_1',
#     'VIB_2',
#     'VIB_Hydrop_1',
#     'VIB_Hydrop_2',
#     's3atac'
#     )
#
# f_fmx = sapply(samples, function(s) paste0(f_fmx_dir,s,'_freemuxlet.clust1.samples.gz'))
#
# fmx = lapply(f_fmx, read.delim, sep='\t', stringsAsFactors=FALSE)
#
# # assign unique barcode:
# for(i in 1:length(fmx)) {
#     fmx[[i]]$ubarcode = paste(names(fmx)[i], "#", fmx[[i]]$BARCODE, sep="")
#     fmx[[i]]$replicate = names(fmx)[i]
# }
#
#
# ################################################################################
# # freemuxlet sample pairing
# ################################################################################
#
# # these groupings are made manually:
# # based on the CLUST? in the heatmap
#
# sampleA = list(
#     c('Broad_1',0),
#     c('Broad_2',1),
#     c('Broad_mito_1',1),
#     c('Broad_mito_2',1),
#     c('CNAG_1',1),
#     c('CNAG_2',1),
#     c('Sanger_1',0),
#     c('Sanger_2',1),
#     c('Stanford_1',1),
#     c('Stanford_2',0),
#     c('VIB_1',1),
#     c('VIB_2',0),
#     c('VIB_Hydrop_1',0),
#     c('VIB_Hydrop_2',0),
#     c('s3atac',1)
# )
#
# sampleB = lapply(sampleA, function(A) c(A[1], ifelse(A[2]==0,1,0)) )
#
#
# fmxA = list()
# for(i in 1:length(sampleA)) {
#     rep = sampleA[[i]][1]
#     clust = sampleA[[i]][2]
#     tmp = fmx[[rep]]
#     bestguess = paste(clust,',',clust,sep="")
#     ix = which(tmp$BEST.GUESS==bestguess)
#     tmp = tmp[ix,]
#     tmp$replicate = rep
#     tmp$sample = "sampleA"
#     fmxA[[i]] = tmp
# }
# fmxB = list()
# for(i in 1:length(sampleB)) {
#     rep = sampleB[[i]][1]
#     clust = sampleB[[i]][2]
#     tmp = fmx[[rep]]
#     bestguess = paste(clust,',',clust,sep="")
#     ix = which(tmp$BEST.GUESS==bestguess)
#     tmp = tmp[ix,]
#     tmp$replicate = rep
#     tmp$sample = "sampleB"
#     fmxB[[i]] = tmp
# }
#
# fmxA = do.call("rbind",fmxA)
# fmxB = do.call("rbind",fmxB)
#
#
# # unified table:
# fmx = do.call(rbind,fmx)
#
# # check there are no unexpected intersections
# intersect(fmxA$ubarcode,fmxB$ubarcode)
#
# ixA = which(fmx$ubarcode %in% fmxA$ubarcode)
# ixB = which(fmx$ubarcode %in% fmxB$ubarcode)
# intersect(ixA,ixB)
#
#
# fmx$sample = 'Undetermined'
# fmx$sample[ixA] = "sampleA"
# fmx$sample[ixB] = "sampleB"
#
# write.table(fmx, file="fmx_out/genotype_concordance_unified.txt", sep='\t', quote=FALSE )
#
#
#
#
#
# ################################################################################
# ################################################################################
# ################################################################################
# ################################################################################
# ################################################################################

# %% [markdown]
# the output `genotype_concordance_unified.txt` will be used to analyse freemuxlet doublets.
