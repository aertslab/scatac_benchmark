# %% [markdown]
# # pycisTopic analysis
#
# Full dataset, using SCREEN regions.

# %%
import pycisTopic
pycisTopic.__version__
# Out:
# '0.1.dev300+g7494158'

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pickle
import pandas as pd

# %%
import os
wdir = '/lustre1/project/stg_00002/lcb/fderop/data/20211008_hca_benchmark_full_singles/'
os.chdir( wdir )

# %%
import glob
from collections import OrderedDict

# %% [markdown]
# # load cistopic objs

# %%
filenames = glob.glob('fragments_postbap/*.sinto.mm.fragments.tsv.gz')
samples = [item.replace(".sinto.mm.fragments.tsv.gz", "") for item in filenames]
samples = [item.replace("fragments_postbap/", "") for item in samples]
files_dict = {samples[i]: filenames[i] for i in range(len(samples))}
files_dict = OrderedDict(sorted(files_dict.items()))
files_dict.keys()
# Out:
# odict_keys(['Broad_1', 'Broad_2', 'Broad_mito_1', 'Broad_mito_2', 'CNAG_1', 'CNAG_2', 'Sanger_1', 'Sanger_2', 'Stanford_1', 'Stanford_2', 'VIB_1', 'VIB_2', 'VIB_Hydrop_1', 'VIB_Hydrop_2', 's3atac'])

# %%
f_cto_dir = 'cistopic_objs__screen'

cistopic_obj_dict = {}
for key in files_dict.keys():
    f_cto = os.path.join(wdir, f_cto_dir, key + '__cistopic_obj_filtered.pkl')
    if(os.path.isfile(f_cto)):
        with open(f_cto, 'rb') as f:
            cistopic_obj_dict[key] = pickle.load(f)
        print(f"Loaded filtered cistopic object {key}")
    else:
        print(f"file {f_cto} doesn't exist")
# Out:
# Loaded filtered cistopic object Broad_1
# Loaded filtered cistopic object Broad_2
# Loaded filtered cistopic object Broad_mito_1
# Loaded filtered cistopic object Broad_mito_2
# Loaded filtered cistopic object CNAG_1
# Loaded filtered cistopic object CNAG_2
# Loaded filtered cistopic object Sanger_1
# Loaded filtered cistopic object Sanger_2
# Loaded filtered cistopic object Stanford_1
# Loaded filtered cistopic object Stanford_2
# Loaded filtered cistopic object VIB_1
# Loaded filtered cistopic object VIB_2
# Loaded filtered cistopic object VIB_Hydrop_1
# Loaded filtered cistopic object VIB_Hydrop_2
# Loaded filtered cistopic object s3atac

# %% [markdown]
# ## Export region-accessibility looms
#
# For use in cell type identification
# # BE CAREFUL WITH THIS: col_attrs = barcodes -> need to make sure that the barcode will match the one in the fragments files, otherwise downstream will not work.

# %% [markdown]
# better is for example: `            col_attrs={ 'CellID': list(cistopic_obj_dict[key].cell_data['barcode']) }, # for hydrop
# `

# %%
import loompy as lp

# %%
f_crl_dir = 'cell_region_loom__screen'
if not os.path.exists(os.path.join(wdir, f_crl_dir)):
    os.makedirs(os.path.join(wdir, f_crl_dir))

# %%
for key in cistopic_obj_dict.keys():
    f_out = os.path.join(wdir, f_crl_dir, key + 'cell_region-all.loom')
    if os.path.isfile(f_out):
        print(f"Skipping {key} loom writing, already exists")
    else:
        lp.create(
            filename = f_out,
            layers=cistopic_obj_dict[key].fragment_matrix,
            row_attrs={ 'Gene': cistopic_obj_dict[key].region_names }, 
            #col_attrs={ 'CellID': cistopic_obj_dict[key].cell_names }, 
            # col_attrs={ 'CellID': [ x.split('-')[0] for x in cistopic_obj_dict[key].cell_names ] },
            col_attrs={ 'CellID': [ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ] },

            #file_attrs=attrs
        )
        print(f"Finished {key} loom writing")
# Out:
# Skipping Broad_1 loom writing, already exists
# Skipping Broad_2 loom writing, already exists
# Skipping Broad_mito_1 loom writing, already exists
# Skipping Broad_mito_2 loom writing, already exists
# Skipping CNAG_1 loom writing, already exists
# Skipping CNAG_2 loom writing, already exists
# Skipping Sanger_1 loom writing, already exists
# Skipping Sanger_2 loom writing, already exists
# Skipping Stanford_1 loom writing, already exists
# Skipping Stanford_2 loom writing, already exists
# Skipping VIB_1 loom writing, already exists
# Skipping VIB_2 loom writing, already exists
# Finished VIB_Hydrop_1 loom writing
# Finished VIB_Hydrop_2 loom writing
# Skipping s3atac loom writing, already exists

# %% [markdown]
# go to next notebook to run the modeling

# %%
cistopic_obj_dict['VIB_Hydrop_1'].cell_data
# Out:
#                                      cisTopic_nr_frag cisTopic_log_nr_frag  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1             2471             3.392873
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1             3958             3.597476
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1             5189             3.715084
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1             4054             3.607884
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1             3504             3.544564
# ...                                               ...                  ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1              960             2.982271
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1             1734             3.239049
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1             1328             3.123198
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1             1392             3.143639
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1             1430             3.155336
#
#                                      cisTopic_nr_acc cisTopic_log_nr_acc  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1            2334            3.368101
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1            3817            3.581722
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1            4839            3.684756
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1            3826            3.582745
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1            3281            3.516006
# ...                                              ...                 ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1             938            2.972203
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1            1600             3.20412
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1            1255            3.098644
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1            1352            3.130977
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1            1393            3.143951
#
#                                          sample_id  Log_total_nr_frag  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1  VIB_Hydrop_1           4.363650
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1  VIB_Hydrop_1           4.049799
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1  VIB_Hydrop_1           4.595342
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1  VIB_Hydrop_1           4.710456
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1  VIB_Hydrop_1           4.485040
# ...                                            ...                ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1  VIB_Hydrop_1           3.599337
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1  VIB_Hydrop_1           4.163758
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1  VIB_Hydrop_1           3.956313
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1  VIB_Hydrop_1           4.209381
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1  VIB_Hydrop_1           3.919706
#
#                                       Log_unique_nr_frag  Total_nr_frag  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1            3.415974          23102
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1            3.719083          11215
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1            3.751048          39386
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1            3.671451          51340
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1            3.582972          30552
# ...                                                  ...            ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1            3.037426           3975
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1            3.287130          14580
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1            3.163758           9043
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1            3.196729          16195
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1            3.187521           8312
#
#                                       Unique_nr_frag  Dupl_nr_frag  Dupl_rate  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1            2606         20496   0.887196
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1            5237          5978   0.533036
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1            5637         33749   0.856878
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1            4693         46647   0.908590
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1            3828         26724   0.874705
# ...                                              ...           ...        ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1            1090          2885   0.725786
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1            1937         12643   0.867147
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1            1458          7585   0.838770
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1            1573         14622   0.902871
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1            1540          6772   0.814726
#
#                                       Total_nr_frag_in_regions  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1                     20180
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1                      6590
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1                     33769
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1                     41910
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1                     25865
# ...                                                        ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1                      2936
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1                     11874
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1                      7528
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1                     13463
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1                      7039
#
#                                       Unique_nr_frag_in_regions      FRIP  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1                       2149  0.824635
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1                       2719  0.519190
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1                       4613  0.818343
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1                       3488  0.743235
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1                       2982  0.778997
# ...                                                         ...       ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1                        751  0.688991
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1                       1435  0.740836
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1                       1118  0.766804
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1                       1155  0.734266
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1                       1254  0.814286
#
#                                       TSS_enrichment                  barcode  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1       30.242277  ATTCTCAGACCAGGTTCGTG-12
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1       23.026618  GACTGAGATTCTGACCAGAT-12
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1       25.942880  CAATTGGAGAAACATTCCGG-12
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1       22.186640  GAGTTAACGTCATCGCAGGT-12
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1       21.792673  AAGACGCAACTGAGGTAGGC-12
# ...                                              ...                      ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1       29.406409  GACTTAGAGATCCAGTTCAC-11
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1       29.439356  TTGCTGGCGTATAGTGCAGG-11
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1       43.349566  GTGTGCTACAATCACGTGTC-12
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1       25.262572  TTGCTGGCGTTACGAGGTGG-11
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1       18.634006  TCGTGAGGCTAGCGGATACA-12
#
#                                      fmx_droplet_type fmx_sample  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1              SNG    sampleA
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1              SNG    sampleA
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1              SNG    sampleB
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1              SNG    sampleB
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1              SNG    sampleA
# ...                                               ...        ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1              SNG    sampleB
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1              SNG    sampleA
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1              SNG    sampleB
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1              SNG    sampleA
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1              SNG    sampleB
#
#                                      Doublet_scores_fragments  \
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1                 0.271255
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1                 0.121951
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1                 0.271255
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1                 0.109278
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1                 0.186747
# ...                                                       ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1                 0.136691
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1                 0.115385
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1                 0.034247
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1                 0.059507
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1                 0.056657
#
#                                      Predicted_doublets_fragments
# ATTCTCAGACCAGGTTCGTG-12-VIB_Hydrop_1                        False
# GACTGAGATTCTGACCAGAT-12-VIB_Hydrop_1                        False
# CAATTGGAGAAACATTCCGG-12-VIB_Hydrop_1                        False
# GAGTTAACGTCATCGCAGGT-12-VIB_Hydrop_1                        False
# AAGACGCAACTGAGGTAGGC-12-VIB_Hydrop_1                        False
# ...                                                           ...
# GACTTAGAGATCCAGTTCAC-11-VIB_Hydrop_1                        False
# TTGCTGGCGTATAGTGCAGG-11-VIB_Hydrop_1                        False
# GTGTGCTACAATCACGTGTC-12-VIB_Hydrop_1                        False
# TTGCTGGCGTTACGAGGTGG-11-VIB_Hydrop_1                        False
# TCGTGAGGCTAGCGGATACA-12-VIB_Hydrop_1                        False
#
# [2226 rows x 20 columns]

# %%
[ x.split('-')[0] for x in cistopic_obj_dict['VIB_Hydrop_1'].cell_names ]
# Out:
# ['ATTCTCAGACCAGGTTCGTG',
#  'GACTGAGATTCTGACCAGAT',
#  'CAATTGGAGAAACATTCCGG',
#  'GAGTTAACGTCATCGCAGGT',
#  'AAGACGCAACTGAGGTAGGC',
#  'CAGATTGACCCGCCAACACA',
#  'TGCATGTCGCTGACCGGAAC',
#  'GATTCGAAGGATTCAGGACG',
#  'CGATAATCCTGTTGGACATA',
#  'GTCGGTTCTTATGACTCCAA',
#  'TGGAGCAGTCAGGAATCGCA',
#  'TAGAGCCTGACATCAAGCTG',
#  'GCACACAGTCCTCCTATCAT',
#  'GAACTCAACCCCTCTATGTA',
#  'CGATAATCCTTAGATGCTCA',
#  'TCGCCACGAAATTCAGGACG',
#  'GTGCAACAACTTGCCACAAT',
#  'TGGAGCAGTCCTTGATTACG',
#  'TTATGACACCGCCTTCTCTC',
#  'GAGTGAGGTATGGTCTACTC',
#  'AGTGGAATGCGTTCGTCAGC',
#  'GCTATGGCGACCACGTTGTG',
#  'TCGGATCCATGTGTATCAGA',
#  'GGAGTATTCTCGTTCCAAGA',
#  'GCGCCATAGTGTATCAGCCG',
#  'TGGCATTCACGTATACGATC',
#  'CAACGTAGTTAGGTGTCGTG',
#  'AGACATGCGAACATAATCCG',
#  'TAACTCACAGATGAAGTGCG',
#  'CGATAATCCTTTGTCCGCCA',
#  'TTGTACTGCAGGACAGGACA',
#  'CCAGAGCAAGGACGGCTTCA',
#  'AATTCCTGCGATTCGGTCAG',
#  'TGGCATTCACAGGCTCTATT',
#  'GGATCAAGGCGATCTCGCGT',
#  'GTTCAGGTAATCGAGTGATA',
#  'GTGTAAGTGAGTAACTGACA',
#  'TCTATTGAGCCGCGACAATG',
#  'CCTCCATAAGTTGCAGTTCT',
#  'ACACCTGAAGAGAACAATCC',
#  'CGACTGGATTTGAGGTAGGC',
#  'GATTCGAAGGTCTACGAACG',
#  'CACTAGCGTGGAACTCGTAG',
#  'AAGTCAAGCCACTCTCTACG',
#  'GGCAACCTCTGAAGGTGAAG',
#  'GCGTTGACTTTGACCGTCCT',
#  'GCACACAGTCCATTGCGAGT',
#  'CGACTAAGACCTCTAGATAC',
#  'ACCGAAGGCTTTGTGTAGGA',
#  'GAGAATGCTCACCAGACTTA',
#  'TCAGCTCGAGATTCAGGACG',
#  'GTGGTATCCTGAACTCGTAG',
#  'ATTGTAGAGGGACATGACGA',
#  'CAATTGGAGATGCGTAGTAA',
#  'CAATAACGGCGTATACGATC',
#  'GCTATCCGGACGTAGTTACA',
#  'TAGTGAGACACTCAAGGATT',
#  'ATAAGCAGTCTACCGGTTAA',
#  'CAACGCATGCAGAACAATCC',
#  'AACCTAGACATGCAACGCAA',
#  'ATCATCCGTTGTTCGAATGG',
#  'TGGCGAAGAAGAGCGGTAAC',
#  'ATTGTAGAGGCCACGTTGTG',
#  'ATCATCCGTTAGGCTCTATT',
#  'ATAAGCAGTCCTGGAACACG',
#  'GTGCTACGGTAGGCGATGTA',
#  'AATACCGGAAACTCTCTACG',
#  'GTCAGCTCAGAGTCAGAGCA',
#  'TGCATGAGGTTGGAAGGAGA',
#  'CACCTGCTAGATAGTGCAGG',
#  'GGAGTATTCTCTTGATTACG',
#  'TTGAGGCAGGGAAGGTGAAG',
#  'GCGATCTACGCCAGAGTGGA',
#  'CTACGGTCACGTTGGACATA',
#  'TAGAGCCTGAAGCTCGGAAT',
#  'TTCTACAACGACTCTCTACG',
#  'TCTCGACAGGTAGCTGTTGG',
#  'GGTACTCATTCATTCCTAAG',
#  'GTGCTCTGAGTCCAGTGTTC',
#  'CTCCTCACTATACACAACGG',
#  'ATTCTCAGACTCCTGATAAG',
#  'GTGTAAGTGAATAGTGCAGG',
#  'TCGGATCCATTGCTGTATCA',
#  'TAGAGCCTGAAGAGAATGTC',
#  'CATATCCGGCTTAGTGCACA',
#  'CTGTCTGGCTCTCAAGGATT',
#  'TATTCCACGTCCAATACTCG',
#  'GGAATTAGCGTAGTGTCAGA',
#  'AGTTCATCCGCCTAACCAGG',
#  'TGGAGCAGTCGAACTCGTAG',
#  'GATTCGAAGGTCGTTGGACT',
#  'TCGTCACAAGCGCGACAATG',
#  'GGAATTAGCGCTCCGATTCT',
#  'AGCACGATGCTGCAGACCGT',
#  'AGTTCCATGGCGTAGGAGAA',
#  'CGGATCAAGCGGCGTGTTAG',
#  'CCTATTCTGATGCCGTACTG',
#  'ATGCGTTCTGTGCAGACCGT',
#  'GCGATAATCCACGGTGGACA',
#  'ACCGAAGGCTCTGGAACACG',
#  'TCTATAACGGGCGCAGAGTA',
#  'ATGGCATAGGAGCGGATACA',
#  'TGTGGAGGTAACTTGCCGGT',
#  'CGCTAATGGAAAGAGGCTAA',
#  'GATCAGAGGTAACGCCTGCT',
#  'AGTTCCATGGCATTCCTAAG',
#  'GACATTCAGCATGATCATGC',
#  'TCTATACGTGCTTGATGTGA',
#  'CATTGGTGCATTGCAGTTCT',
#  'GCGATAATCCCAAGACGTCT',
#  'CGGTAACGCTGTGCGAACCT',
#  'CCGAGCATTCAGCCGAAGTC',
#  'AACCACGGATTTGGTACGTA_AACCACGGATAATGCCGTGC',
#  'GAAGGACTACTCGCGAATCT',
#  'CCGTGTTCACTTGGTCTCAG',
#  'CATACCACAAGCCATTGAGG',
#  'TCTATTGAGCCATCAAGCTG',
#  'CGAACAACAAGTAATCGGTG_CGAACAACAATTAGCAGTGC_ACCGAAGGCTTTGCAGTTCT_TCCAGACAGCTGAGGTAGGC',
#  'TCGTCTAGAGCCTTCGTTAA',
#  'AACACTGTCTCGTAGGAGAA',
#  'TTGAGGCAGGAGACTGTTCT',
#  'AACGATACCAAACATACTCG',
#  'AGTCGCTGGAGCGTGGATCA',
#  'AGTTCCATGGCACTGGTGGT',
#  'GCGATAATCCCTCGATCAAC',
#  'CCTATTCTGAGGCGTGTTAG',
#  'AAGTCCACGGTGCGTAGTAA',
#  'AATCTGAGGCACATAATCCG',
#  'ATAGGCGAGCACGTATCCAA_ATAGGCGAGCATACAGAGAG',
#  'ATGAACAGAGACTTGAGGCC',
#  'ATCGGAATACACTTGAGGCC',
#  'GACTGAGATTTCGGTGTCTC',
#  'ATGCGTTCTGCTTGGCTGGA',
#  'TCAGATCGGTGATCGCATCT',
#  'ATAAGCAGTCTGCGTAGTAA',
#  'CGATAATCCTGGTACCTAGC',
#  'GAACTATGACTGTGCGATTA',
#  'ACAGTGAAGACTATCCTTCA',
#  'TGATTGTCACCCAATACTCG',
#  'GTCGAACTGGGATTCCGGAG',
#  'GTTAAGAACGCCTAACCAGG',
#  'AGTACGCGTACTAGAAGGCT',
#  'TGGTAGTATGCCAGTCAATC',
#  'TTCCTCGTGTCTTGATTACG',
#  'CCGAGTGAATTCGCGAATCT',
#  'AGAGGAGTTCATTGAACCAC',
#  'GTGCAACAACGGTAGGTAGG',
#  'AATGACCGGTTGTAGCAAGT',
#  'TGGCGAAGAACTAATGTGTG',
#  'ATAAGCAGTCCTATTCGGCT',
#  'AAGTAACGACCTGTAATCCA',
#  'TGCGTATCGGCATTGCGAGT',
#  'CGTGAATGAAGCGGTACTAC',
#  'TCTGCTAGAATCCGTAACCT',
#  'GAAGGTACATTTGCAGTTCT',
#  'CCGTGTTCACATCAATCGAG',
#  'TTCTACAACGTTAGTTGGAC',
#  'ATATGCACTGCATACAAGGT',
#  'GTTCCGCGAAGCTGTCCTAG',
#  'CTCACAGTGGATCTTGCAGC',
#  'AAGACGCAACTGCTCCAGAC',
#  'TTGCGTGAGAAGGACGTTCG',
#  'TCGCCACGAAAACATACTCG',
#  'GAACTATGACAGATATCGAG',
#  'AACAACCAAGCATCAAGCTG',
#  'CCATTCACGCAAGCTGTATC',
#  'AAGTAACGACACTTAAGAGC',
#  'TAGACTGGTCTGTTAAGCCA',
#  'CCAACCTGTGTACAATCCAG',
#  'TTGCGTGAGAGTGCCAATAA',
#  'AACCACGGATAGCGGATACA',
#  'ACCTACCTCCCTAATGTGTG',
#  'TGTGGAGGTATAGTGTGTTG',
#  'TAGGTGATGAACCAATTGAC',
#  'TACTCGCAGATACGGACGGT',
#  'ACTACGTGCTAACATACTCG',
#  'CACGATGCATACATAATCCG',
#  'TCGTGAGGCTGTGTCAGCAC',
#  'AGTTCATCCGCTTGAAGAAG',
#  'TGCATGTCGCATTGAACCAC',
#  'GGCGTAGGTTGGACAGGACA',
#  'AACCTAGACAACGGTGGACA',
#  'CCAACCTGTGTACGCGGCTT',
#  'TAACTCACAGTCTGAGATCG',
#  'GCAGGTTCCAGTAATCGGTG',
#  'AACGAGGACTTGGATAGGCA',
#  'TGGCATTCACAGAACAATCC',
#  'AATACCGGAAATTCGGTCAG',
#  'GCTATGGCGAGGTAGGACTG',
#  'CGTGAAGCACAGCGGATACA',
#  'CGATAATCCTGCTCGTTGTT',
#  'TCTCCTGCAGGATCGCATCT',
#  'GCACACAGTCCATAATGCCT',
#  'TAGGTGATGAGAACTCGTAG',
#  'TCTATAACGGCTCCTATCAT',
#  'GCAGGTTCCAGCCAAGCCAA',
#  'ATACACAGGTCGTAGGAGAA',
#  'TGTTAGTGACCTATTCGGCT',
#  'TCGCCACGAACTGAGACCAA_TCTATTGAGCCAGTTAAGGA',
#  'CAGAGTGGCTTAATGTGCTC',
#  'GAACTATGACCAGTGCTATG',
#  'TTCGCTTCACTGTGCGATTA',
#  'TCCTATACCATGAGGTAGGC',
#  'TCATTGACCTGGTAGGACTG',
#  'AGGTCTGTATCACGTTAAGA',
#  'ATGTCGTGAAGTCGAAGCAC',
#  'GTGCAACAACAACATACTCG',
#  'GTAACGCAAGAACATTCCGG',
#  'GACATGACGAATTCGGTCAG',
#  'ATGCTCCTTAAGCCGAAGTC',
#  'TTGCCATGCGAAGAGGCTAA',
#  'AACAGTCAGTTGGTCTACTC',
#  'CCGTGTTCACTAATACCAGG',
#  'CAACACCATTCCTCAATTGC',
#  'GATTGGCGGTTTCCTGTACG',
#  'TACGGATACGAACGGATAAC',
#  'ATCTCGAGCACTGGAGTTGA',
#  'AATACCGGAATAGGAGTCAA',
#  'CTGTAGACGGCATACAAGGT',
#  'AGACATGCGACTTGATGTGA',
#  'TATCGCTCACCCGTCAAGTG',
#  'TGGCATTCACTAGGCTGATT',
#  'CCTCAACGACTTGGTACGTA',
#  'TGTGGAGGTAGCATTGAGCC',
#  'TTGAGAAGAGCTTGAAGAAG',
#  'ACCGCTTCAACTATTCGGCT',
#  'CAACGCATGCGCGCAGAGTA',
#  'ATGCTCCTTAATCGGAACCA',
#  'TCTCTAGTGAAGGTGCCAGA',
#  'GTTCAGGTAACTCAAGAGGT',
#  'CCGTATTAGGAGGTTAGAGC',
#  'ACCGCTTCAACAAGCATATC',
#  'CATACCACAACCTTCGTTAA',
#  'AGGTCTGTATGTGCTTACTT',
#  'GTAACGAGCTTGGAATAGAC',
#  'GTGCTCTGAGTGACACACCT',
#  'GACATGACGATACCTTCGAT',
#  'TGATCCGGCTAGGAGACTCA',
#  'GCATATAACCACCGCACTAA',
#  'TAACGTAAGGGTTAGAGACA',
#  'CCGAGTGAATCTCCGGATAG',
#  'ATGCGTTCTGGGCCAATCGA',
#  'GGCGTAGGTTGCTTAGAGAA',
#  'GATCAGAGGTGAAGGTAGTG',
#  'GTTAAGAACGGAGCGGTAAC',
#  'TGCTCAACGAAGAGAATGTC',
#  'TACAAGAGGCACCGGTAATA',
#  'GGATCTCATGCGAGGATCAT',
#  'TGATCCGGCTGCTGTCCTAG_TGATCCGGCTAATCTGCACA',
#  'GAGAGGACTCTCGGTGTCTC',
#  'GGATCAAGGCGGTAGGACTG',
#  'TCGTCACAAGGACAAGTGGA',
#  'CTCAGTTGCCGCCATTGAGG',
#  'GACTGAGATTGAGGACAAGG',
#  'GTAACGAGCTCTATCCTTCA',
#  'GAGTGAGGTACTCACATCCT',
#  'TATGCAATCCGTATCCAGTC',
#  'CAACGCATGCCTTGATGTGA_CAACGCATGCTCGAACTCCG',
#  'GCATATGCAACTTACAGCCA',
#  'AGGCTTGCCTAGCGGATACA',
#  'TCGATATGCGTTGCTCAGCA',
#  'TAACCGAATCGGCGTGTTAG',
#  'CTAGGTCTAATGAACACAAC',
#  'ACAATCCAACAGGACGACAG',
#  'GTAGATACGATGACCGGAAC',
#  'TCGTGAGGCTCGCGAATGCT',
#  'CAGATTGACCTACAATCCAG',
#  'TCTCCTGCAGTACTAGGCCT_ATGAGCTGGCTGCGTAGTAA_AAGACGTGCACCATCTCTGT',
#  'AAGACCAAGCTTGCCACAAT',
#  'GAAGGTACATGTGTATCAGA',
#  'AGCTCATCAATGTAGCAAGT',
#  'GAATCACTTCGGCCAATCGA',
#  'AACCTAGACACGAAGTACCG',
#  'TAGAGCCTGAAGCCGAAGTC',
#  'ATCGCATGGCGATCTCGCGT',
#  'CTCTGCACAGAGATACAGCG',
#  'TGAACGGCAACACGTTAAGA',
#  'ATCATCCGTTACTTAAGAGC',
#  'TCTATAACGGTCTGGTCCGA',
#  'CGGCAATGTGTCGAGTGATA',
#  'CTCGTGAGATTACACAACGG',
#  'CATGGACTGAGTGTGAAGAA',
#  'CAACACCATTCCGGTTACAT',
#  'ACAGTGAAGAGATACAAGAG',
#  'TCGCCACGAAGAACTCGTAG',
#  'CATATCCGGCTAGGCTGATT',
#  'CGACTAAGACGTGATAGGAA',
#  'TTGAGGCAGGCGTTCCAAGA',
#  'TGTGGACCATTCTACGAACG',
#  'CTCTGTGCACGCTGACAACG',
#  'CGTTACTGGCCCTTAGGCGA',
#  'GCTATCCGGACATACAAGGT',
#  'ACTGCCTTGACACTGGTGGT',
#  'TATCGCTCACTCGCGAATCT',
#  'AGGTCTGTATAGAACAATCC',
#  'ACAGTCCTGATGACCGTCCT',
#  'CACCTGCTAGTGCGTAGTAA',
#  'ACTGCCTTGAATGAAGTGCG',
#  'ACGAGTTGCCCTGGTTCGGA',
#  'GACCATAGTGTTCGCACAAC',
#  'GTCAATCCACAGATACAGCG',
#  'ATGCTCCTTAGTGACGTGGA',
#  'GTAGAGAATCAGATACAGCG',
#  'GACTGAGATTGCGAAGAACA',
#  'CAATAACGGCCACCAACCTA',
#  'TGCGTATCGGTCGGTGTCTC',
#  'ATTCTCAGACCTTGATGTGA',
#  'AAGGAGCATGTCGAGTGATA',
#  'AATTCCTGCGGTGTATCAGA',
#  'GCAGGTTCCAACGGTGGACA',
#  'AACACTGTCTATACAGAGAG',
#  'AGTGGAATGCCAAGGTCGAT',
#  'ACTGCCTTGAGGACAGGACA',
#  'AATTCCTGCGTTAGCAGTGC',
#  'AGATCGTTGGGTGCGAACCT',
#  'ACCGCTTCAATAAGCTGGAA',
#  'TCTCTAGTGATCGAACTCCG',
#  'TCGATCCTTACTCCGGATAG',
#  'TTCAACCTGGGGTTGGAATA',
#  'GAACTATGACACCAATATCG',
#  'GGATCTCATGGTCGAAGCAC',
#  'ATACGCAAGAGCCATTGAGG',
#  'CCGACAGGATAGGAATCGCA',
#  'ACTACGTGCTACTAATGACG',
#  'CCAACAGAGAGCTACGACAG',
#  'CGTTGACCACTCTACGAACG',
#  'CTGTCTGGCTGACTTGTAAC',
#  'GAAGGACTACCTCGATCAAC',
#  'GACTGAGATTGTGATAGGAA',
#  'TAACCGAATCCGTACCTGAG',
#  'AGGAAGTGGACATTGCGAGT',
#  'TCTATACGTGGTGTGAAGAA',
#  'TGCATGAGGTTAAGCTGGAA',
#  'ATCTCGAGCATTAGTGCACA',
#  'CCTCAACGACTTAGTACCAG',
#  'CTTGGCAAGCGGCCAATCGA',
#  'GAAGGTACATCATTGCGAGT',
#  'AAGTCCACGGTTCACTAGTC',
#  'TCAGCTCGAGCTTACAGCCA',
#  'TCGCGCATTGGCAAGCGTGT',
#  'TAACTCACAGTAGCTGTTGG',
#  'ATACAGGTCCGGTGACTATA',
#  'GTTGCCAGCTGCGGTACTAC',
#  'ACTGCCTTGACGTTCCAAGA',
#  'TCTACATCACTTCCTGTACG',
#  'TCGGCATAGCAAGAACGGTG',
#  'ACCGCTTCAAGTTGTATCGG',
#  'ATCGTGCCTACACTGGTGGT',
#  'GTCGAACTGGGGCCAATCGA',
#  'GCAGGTTCCACAGAGGAACG',
#  'GTGGTATCCTTGACCGGAAC',
#  'TTGTACTGCAGCTCGTGTCA',
#  'TAACTCACAGCCATGCATAC',
#  'GCAGGTTCCATCCGGTCAAG',
#  'GCGCCATAGTGTTGGACATA',
#  'TCCAGAACTCAAGAGGCTAA',
#  'AGTCGCTGGATGAATCCACC',
#  'TGGTAGTATGACTTGAGGCC',
#  'GTGCTACGGTCGGTAAGGTC',
#  'CTGTACGTCTGTCGACTAAC',
#  'CCTCCATAAGTGACGAGATG',
#  'GGAGCGGATTCTACTGGTAT',
#  'TAATTCCGTGCCATGCATAC',
#  'GCTATGGCGAATCCAGCGCA',
#  'CTGTAGACGGTAGTGTCAGA',
#  'CTGAGGTAGAGTATCCAGTC',
#  'ACAGGATGCGCTGACCAGAT',
#  'TTGTACTGCATAGGCTGATT',
#  'ACAATCCAACGCGAAGAACA',
#  'ATGGCATAGGACCAATATCG',
#  'AACAGTCAGTTAGTGTGTTG',
#  'CCTATTCTGAACCAAGGAGA',
#  'CCGAGTGAATATCAATCGAG',
#  'AACGACTCAGAACGGATAAC',
#  'CACGATGCATAACATTCCGG',
#  'TTGCTGGCGTTGCTCCAGAC',
#  'TGGTATTCCGCACGTTAAGA',
#  'CGTTGACCACGCTACGACAG',
#  'GGATCTCATGTCCGTAACCT',
#  'CTCGTGAGATTGTCAGGCGA',
#  'CACCTGCTAGCGCGACAATG',
#  'CGATAATCCTCGCGAATGCT',
#  'CTAGGTCTAATGACCGGAAC',
#  'TGTGGAGGTAGTGTGAAGAA',
#  'GGTCTGGAACCCTGTCTGCA',
#  'GATTGAAGCACACGTTAAGA',
#  'GCTTCTCGCTGCGAAGAACA',
#  'GTTCCGCGAAAGTGTGGCAA',
#  'TAGGTGATGACTGTAATCCA',
#  'TCGGCATAGCGTGTGAAGAA',
#  'ACCGAAGGCTTGTAGCAAGT',
#  'TACGGTTGAAATCCAGCGCA',
#  'TGCATGAGGTCTATGTGCTG',
#  'ACACCTGAAGAGCGTACTAT',
#  'CAGAGTGGCTGCTTCAGAAG',
#  'CCGTGTTCACATACAGAGAG',
#  'CCTCCATAAGTAGATGCTCA',
#  'GCCAATCTGGAACCAACTGA',
#  'GGTACTCATTACGGTGCTCT',
#  'CCGACAGGATAGGACGTTCG',
#  'TTGCCATGCGTACAATCCAG',
#  'TCGATATGCGCAGTGCTATG',
#  'GACCGTCAACTGTGGTTATC',
#  'TATGCTTCTGACTTGAGGCC',
#  'GGACTGGCATGCGTGGATCA',
#  'TCTACATCACAACATACTCG',
#  'TCGGATCCATGCATTGAGCC',
#  'GGAGCCATCTGCGCAGAGTA',
#  'CTGCATTCCGCTGGTTCGGA',
#  'AGGTTGCATTACCTCGAATC',
#  'TGACAACGTGTCCAGTTCAC',
#  'AACGAGGACTCTCTAGATAC',
#  'GAAGGTACATAACGGATAAC',
#  'GTAGATACGATTCACATTCC',
#  'TCTCGACAGGTACGAGGTGG',
#  'CATGGACTGAGTACACACAT',
#  'ACAATCCAACCTCCTATCAT',
#  'TCGGATCCATGCCTTCTCTC',
#  'ATGAGCTGGCTACAATCCAG',
#  'GGTACTCATTGTTAGAGACA',
#  'GAGAGGACTCGCTGTCCTAG',
#  'TATTGTGCCAGGCTGTCGAT',
#  'CAGAGTGGCTGGAGCTTGTC',
#  'TCCGATTCAGACTTAAGAGC',
#  'ACGATTACGAAATCGGAGAA',
#  'AATCTGAGGCTCAATGCGCA',
#  'CGAGATCGGAACATAATCCG',
#  'TGATGCGGTATTGACACAGC',
#  'CTGTCTGGCTTGTTAAGCCA',
#  'GACTTAGAGAAGGCTCTATT',
#  'AGCTTGGTAGTACAATCCAG',
#  'GAGTGAGGTATACAATCCAG',
#  'GCCACAGACTACGGTGGACA',
#  'CTGGCAGACACCACGTTGTG',
#  'CGGCAATGTGCATACAAGGT',
#  'CCATTCACGCACGAGGATTG',
#  'CTAAGGTACGGAAGGTAGTG',
#  'TTGCTGGCGTAGAACAATCC',
#  'ACGATTACGATCCGTAACCT',
#  'GATAGTGGTCGGTAGGTAGG',
#  'AGCTCATCAACGTCATCCTA',
#  'GAACTATGACTTGTGTAGGA',
#  'GCTATCCATGTCCAGTTCAC',
#  'ATACAGGTCCTTAGCAGTGC',
#  'TAAGCGAAGGTGCTCCAGAC',
#  'GGTATAGAGCATGAAGTGCG',
#  'GCTTCTCGCTTCCGGTCAAG',
#  'AACAACCAAGGAGCTAGTAA',
#  'GCATATGCAAGGTTAGCAGA',
#  'GACTCAGGACCGTTCCAAGA',
#  'CCGAGTGAATAGCGTACTAT',
#  'CAGATTGACCCCACGTTGTG',
#  'CGACATTACAGTTGTATCGG',
#  'GTAACGCAAGCCTAACCAGG',
#  'AGTCGCTGGACCAGAGTGGA',
#  'TCTGCAACCAACCAGAAGAA',
#  'CTAGGTCTAACCAATACTCG',
#  'GTCAATCCACAACGCCTGCT',
#  'CTATACAGTGTGCCGTACTG',
#  'ATGCGTTCTGCTATTCGGCT',
#  'ATTAGCAACCACCAGAAGAA',
#  'GTCAAGACCAGCCATTGAGG',
#  'GGAGCGGATTGCAAGCGTGT',
#  'TCCAGAACTCTAAGCTGGAA',
#  'TGTAAGCGATCGTACCTGAG',
#  'ACGATTACGATGTAGCAAGT',
#  'GGCGTAGGTTTGTGTCTGCC',
#  'GGTGACATAGTCATGTGAAG',
#  'ATTAGCAACCCAAGCACCGT',
#  'ACCGCTTCAAGTGAGTAGCC',
#  'TACGGATACGTTAGTGCACA',
#  'TCCTGGTGGAGATCGCATCT',
#  'ATCGCATGGCGTGAGTAGCC',
#  'CCAACCTGTGAGGTGTCGTG',
#  'TCAGCTCGAGACGTATCCAA',
#  'ACAGTCCTGAGGCGTGTTAG',
#  'ACCTACCTCCCTTGATTACG',
#  'GGTAGTCGACCCTCAATTGC',
#  'AATGACCGGTTCTCGCACGA',
#  'CGCTAATGGATCAATGCGCA',
#  'TTCACGACGTAATCTGCACA',
#  'CGGTAACGCTCACCAACCTA',
#  'ATGAACAGAGGAAGGTAGTG',
#  'TTCAACCTGGATCCAGCGCA',
#  'CTCGTGAGATGACATGACGA',
#  'ACTTGGACTGATCCGAGTAT',
#  'ACCGTAGCATTAGGCTGATT',
#  'GTCGGTTCTTTACAATCCAG',
#  'CTCAGTTGCCTTGGTCTCAG',
#  'CCGACACCTACATTGCGAGT',
#  'AGACAATGGAACCAAGGAGA',
#  'TACGGTTGAAAAGCTGTATC',
#  'GAAGAACGTGCGTCATCCTA',
#  'GGTTAACCTGTTGGTACGTA',
#  'AGCACGATGCAGGTTAGAGC',
#  'CGATAATCCTATTGAACCAC',
#  'CGATAATCCTAGCTCGGAAT',
#  'ATGCGTTCTGGGCGTGTTAG',
#  'ATAAGCAGTCGTATGTGCGA',
#  'TCCTGGACTATCGCGAATCT',
#  'GCATATAACCTGTCAGGCGA',
#  'AGCACGATGCTAATGTGCTC',
#  'CGTGAATGAATTGGTCTCAG',
#  'GAGTATATGGGTTCGAATGG',
#  'TATACCATGGTACTGATAGC',
#  'TGACAACGTGGATATTGCAC',
#  'TCGCCACGAAACCGGTAATA',
#  'TGCAGCTGAACTCCTATCAT',
#  'TGGCATTCACATCCGAGTAT',
#  'CCATTCACGCGTATCCAGTC',
#  'TCTATAACGGCTCGCTGTAT',
#  'CTGTAGACGGGTGCCAATAA',
#  'ACGATTACGAGCGTGGATCA',
#  'TCGAATACTCCTTAGCACTC',
#  'ATACACAGGTCTAATGTGTG',
#  'GACCGTCAACGCTGACAACG',
#  'CACCTGCTAGACATAATCCG',
#  'CAACGCATGCGGCTTCCAGA',
#  'ATAAGCAGTCCGGAGAGGTA',
#  'TTCAACCTGGGGCCAATCGA',
#  'ACATGTGAGAGTGACCAGTA',
#  'AACGATACCAGCATTGAGCC',
#  'CGGCAATGTGAGTCAGAGCA',
#  'GGATCAAGGCTTCTAGGTCG',
#  'GGAGCCATCTATAGCAGGCC',
#  'GCGTTGACTTCCGGTTACAT',
#  'CTGAATGGAGTGTGCGATTA',
#  'TCGCCACGAATCATGTGAAG',
#  'AATGACCGGTCCAGTCAATC',
#  'TAGAGCCTGACTCTAGATAC',
#  'TGGAGCAGTCCCACGTTGTG',
#  'CAATAACGGCTAATGTGCTC',
#  'CCGACAGGATATAGGTACGG_AACCTAGACACTGGTTCGGA',
#  'ATTCTCAGACTGTCAGGCGA',
#  'TGTTCTCGGAGATCGCATCT',
#  'CGTTACTGGCTCCAGTGTTC',
#  'CATCAAGGATGAGTTCTTGA',
#  'AATCTGAGGCTACTGATAGC',
#  'TCTCCTGCAGAGTGTGGCAA',
#  'GAAGCCTGGTACCAATATCG',
#  'AGTGGAATGCCGGCTTAAGG',
#  'CGACTGGATTGCTGACAACG',
#  'TAAGCGAAGGTCTACAGTGC',
#  'CCATTCACGCGCGGTACTAC',
#  'GTGCAACAACGAACGTGCGT',
#  'CCATTCACGCTTCATGGCCT',
#  'GTCATAACCTAATGCCGTGC',
#  'GCGTTGACTTTAATGTGCTC',
#  'TCGTGAGGCTGTGAGTAGCC',
#  'ACACCTGAAGGAAGGTAGTG',
#  'GGTTAACCTGGCTTAGAGAA',
#  'AATACCGGAAAGATATCGAG',
#  'GTCAATCCACACCTCGAATC',
#  'CCGTTGTACGGGCCAATCGA',
#  'TGGTCAGATAATACAGAGAG',
#  'ATCCTCGTAATAGGTCAAGC',
#  'GGTACTCATTCCATTACGGA',
#  'GTGTAAGTGATCGAGTGATA',
#  'TTCAACCTGGTTCTAGGTCG',
#  'CGAACAACAACCACGTTGTG',
#  'CCGAGTGAATACGGTGGACA',
#  'ATACGCAAGAATTGAACCAC',
#  'AACGACTCAGGTTCGAATGG',
#  'CCTATAGACATTGCTCAGCA',
#  'TCCTATACCACCTGTCTGCA',
#  'GGAGCGGATTGGACAGGACA',
#  'GATTCGAAGGCGAATATCAG',
#  'TTGCGTGAGACCAGAGTGGA',
#  'TCTGCAACCATCGGTGTCTC',
#  'CGGTAACGCTAAGAGGCTAA',
#  'GAACTCAACCCCGGTTACAT',
#  'CGATGCTTGATACTAGGCCT',
#  'TGTTGCCTCCTGTGTCTGCC',
#  'TCTCCTGCAGAGAAGCGAAC',
#  'CCGACACCTAGGAGCTTGTC',
#  'CAGCTGACGAATACGAGCCA',
#  'AACCACGGATACGACCACTT',
#  'ACTACGTGCTCGGCTTAAGG',
#  'GAGTTAACGTTTCCTGTACG',
#  'GATTCGAAGGGTTCCATGCT',
#  'CTGTAGACGGAAGTGCAGAA',
#  'CCGAGCATTCTCGTTGGACT',
#  'CGACTAAGACGCTGTCCTAG',
#  'CTAGGTCTAACGGAGAGGTA',
#  'TCCGTTGACCAGCGCCACTA',
#  'GATTGGCGGTTTCGCTTGGT',
#  'GACTGAGATTACGAGGATTG',
#  'GCGCCATAGTTGAAGTACAC',
#  'GGATCTCATGAGGCGCGAAT',
#  'GAACCTAGTCTTAGTTGGAC_GAACCTAGTCTCCAGTTCAC',
#  'TGGATCTGGATGTTAAGCCA',
#  'TAGAGCCTGACTAACGGCTA',
#  'AATTCCTGCGCATTCCTAAG',
#  'GAGAGGACTCTACTGATAGC',
#  'GGTACTCATTTGACCGTCCT',
#  'AGCTTGGTAGATACGAGCCA',
#  'TGCTCAACGAAACGGATAAC',
#  'GGAATTAGCGTACGAGGTGG',
#  'CTCACAGTGGACAACAGGAA',
#  'GAACCTAGTCAGGACGTTCG',
#  'TTCACGACGTGTGACCAGTA',
#  'ACGAGTTGCCTGTCACAACA',
#  'TGATCCGGCTCTGGAACACG',
#  'GTCGTAGTATGTTCGAATGG',
#  'CTGTCTGGCTTAGCTAGATC',
#  'ATTCCTGAGCACTAATGACG',
#  'GTGCAACAACCCTAACCAGG',
#  'AAGGAGCATGTAGGTCAAGC',
#  'AACCTAGACAGAAGGTGAAG',
#  'AGGAGGCAATCTAACGGCTA',
#  'GTCAGCTCAGAGATATCGAG',
#  'TAGAGCCTGAAGTGTGGCAA',
#  'ATGAGCTGGCTAATCTGTGC',
#  'TAACTCACAGGCGTGGATCA',
#  'GTAGATACGATTAGTTGGAC',
#  'CACCTGCTAGCGTTCAATCT',
#  'GTTGATCCTATGACCGGAAC',
#  'ATGAACAGAGCCATAGCGAA',
#  'GTCGAACTGGGTATGTGCGA',
#  'GCTATCCGGAAAGCTGTATC',
#  'GTTGCCAAGGATTGGATCCT',
#  'TACTCGCAGAACTTGCCGGT',
#  'GCACACAGTCAACGGATAAC',
#  'ACAGTGAAGACCGTCAAGTG',
#  'GAATGTCCGGGCCTTCTCTC',
#  'CGACATTACATACCGGTTAA',
#  'CTCGTGAGATAGGAATCGCA',
#  'AGATCGTTGGCTTAGAGTGA',
#  'CGATCACATACCGGTTACAT',
#  'GGAGTATTCTACATAATCCG',
#  'GAAGAACGTGGGACCGATTC',
#  'GAGTCTCAAGCGCCAACACA',
#  'CACGATGCATGGACCGATTC',
#  'CCGTATTAGGCCATTACGGA',
#  'CGTGAAGCACTTGCCACAAT',
#  'GGTACTCATTGATACAAGAG',
#  'ATAAGCAGTCGATGGCCAAC',
#  'ATTGTAGAGGAAGCTGTATC',
#  'CTGGCAGACATGCAGACCGT',
#  'CTAAGGTACGTCCAGTTCAC',
#  'TAACTCACAGATCGGAACCA',
#  'TGTTGCCTCCTACTAGGCCT',
#  'ATGAGCTGGCAGCTCGGAAT',
#  'CGTGAAGCACGACAAGTGGA',
#  'ACAGTCCTGAGATGGCCAAC',
#  'AGCTTGGTAGCGTAGTTACA',
#  'GTCGGTTCTTGTTCGAATGG',
#  'AACCTAGACATAGGTCAAGC',
#  'CTAAGGTACGGGTAGGTAGG',
#  'ATTCACACCGCTCGATCAAC',
#  'CATGGCATAGAGCTGGAAGA',
#  'GCTATGGCGACCAGAGTGGA_AGTCGCTGGAGCCAGAGAGA',
#  'TCTATAACGGCTCCTCATCC',
#  'GAACCTAGTCCAAGCACCGT',
#  'GCATATAACCGAACGTGCGT',
#  'GACTGAGATTACGGTGGACA',
#  'TCCACATGGAGAAGGTGAAG',
#  'ATCCTCGTAAGTGTATCAGA',
#  'GCTTGCGCAAAACATACTCG',
#  'CGGATCAAGCTACCGGTTAA',
#  'GGTGACATAGCCTAACCAGG',
#  'TAGAGCCTGAACTTGAGGCC',
#  'GAGATGCACTCATTGCGAGT',
#  'AGAGGAGTTCCGTCACGTCA',
#  'GTTGATCCTACGGCTTAAGG',
#  'ACCGAAGGCTGCTTAGAGAA',
#  'AATCGTGAGGTGGATAGGCA',
#  'GTCATAACCTCACAGACAAC',
#  'GGCATCGAACAGCGCCACTA',
#  'CTATACAGTGAGCGGATACA',
#  'AGGAAGTGGACTATTCGGCT',
#  'AGACATGCGATGAAGTACAC',
#  'GAGATGCACTAGGCGCGAAT',
#  'GATTGGCGGTGAACTCGTAG',
#  'TGATTGTCACCTCCTCATCC',
#  'AGTCGCTGGAGGTGACTATA',
#  'GTCATAACCTGTCTTGTATG',
#  'GTGTGCTACACTGGAGTTGA',
#  'TCCGTTGACCGTTCGAATGG',
#  'GGTAGTCGACCGGCTTAAGG',
#  'CGGATCAAGCTGACACACCT',
#  'ATGAACAGAGGTGCTTACTT',
#  'GTGCTCTGAGGCATTGAGCC',
#  'ATACAAGGCGACTTGCCGGT',
#  'ATTAGCAACCCAGTGCTATG',
#  'ATGCGTTCTGCGTACCTGAG',
#  'CCGAGCATTCAGTGTGGCAA',
#  'CCGAGTGAATGACATGACGA',
#  'AACACTGTCTCAGTGCTATG',
#  'GGAGTATTCTCTCTAGATAC',
#  'TCCATGTCAAGTAACTGACA',
#  'TGCATGTCGCCTTGGAATTC',
#  'TCTCTAGTGACCAGAGTGGA',
#  'CATGAACGTTCCTTCGTTAA',
#  'CAACGTAGTTCTGACCAGAT',
#  'CTCTGTGCACAGTATAGTCC',
#  'GACAAGGAACCGCCAACACA',
#  'TTGCACCACGGTCACTCAAT',
#  'AGTACGCGTAACTAAGTAGC',
#  'CTTGACAACAGTCACTCAAT',
#  'GACATTCAGCGCTTAGAGAA',
#  'CGTGAATGAAAACGCCTGCT',
#  'AGGAAGTGGATATGCAGCTA',
#  'ACGAGTTGCCCTGGAACACG',
#  'ACACCTGAAGCGTAGTTACA',
#  'CTTGGCAAGCACCAAGGAGA',
#  'TACTCGCAGAGTTGTATCGG',
#  'AGTACGCGTAGGCTGTCGAT',
#  'GAGAGGACTCAGATATCGAG',
#  'TGCGGCTATGATAGGTACGG',
#  'AAGTCCACGGGAACGTGCGT',
#  'ACAGTCCTGACCAGAGTGGA',
#  'ATCGTGCCTAAACGGATAAC',
#  'GACTTAGAGATGCGTAGTAA',
#  'GGTTAACCTGGTGCTTACTT',
#  'GACTACAAGAGATCTCGCGT',
#  'GTCGTAGTATTACGAGGTGG',
#  'TATTCCACGTAGCGGATACA',
#  'TGACAACGTGACACACTAGA',
#  'GACAAGGAACTTGGTCGAGT',
#  'TCGCGCATTGGTGTTGAAGT',
#  'TTGAGGCAGGTGGATAGGCA',
#  'TATCGCTCACTGCAGACCGT',
#  'GAGAATGCTCCCACACGGAT',
#  'GAGGACATAATGTAGCAAGT',
#  'CCGACAGGATCCTTCGTTAA',
#  'TGGCATCGGAGTAATCGGTG',
#  'TCTACATCACGATACAAGAG',
#  'AGTCGCTGGACCTTCGTTAA',
#  'GAACGCAGTAGTGTATCAGA',
#  'GTCGTAGTATCTAATGTGTG',
#  'AGGCTTGCCTGGAGCTTGTC',
#  'AGGCTTGCCTGTAACTGACA',
#  'GACTACAAGATTCGCTTGGT',
#  'ATGCTCCTTATCCAGTTCAC',
#  'CGCTAATGGAGAGGACAAGG',
#  'TCTCTAGTGACCATAGCGAA',
#  'GTTCAGGTAACACAGACAAC',
#  'AGCAGGAGCTCCTAACCAGG',
#  'ATGCTCCTTAATCAATCGAG',
#  'ATCGCATGGCTGACCGTCCT',
#  'AGGAGGCAATGTCGACTAAC',
#  'TATGCTTCTGGCAATGATTG',
#  'CTGAATGGAGCCAGAGTGGA',
#  'AAGTCAAGCCGCAATGATTG',
#  'GATGGTTCCGAGCATGTTGG',
#  'CGATAATCCTTGTGTCTGCC',
#  'TGATTGTCACTGACGAGATG',
#  'GTAACGAGCTTACTAGGCCT',
#  'ATGCGTTCTGGCGTGGATCA',
#  'CGCTAATGGAGTGCCAATAA',
#  'ATGAACAGAGTTCGCTTGGT',
#  'GAAGGACTACATAGCAGGCC',
#  'GCTGACTTGCATGACTCCAA',
#  'AACGAGGACTGTGACGTGGA',
#  'AACCTAGACACCGGTTACAT',
#  'ATGAACAGAGACACAACGCC',
#  'CGTTACTGGCTGTGTCTGCC',
#  'GAGAATGCTCTCCGTAACCT',
#  'CCGAGTGAATCTGACCAGAT',
#  'CGAACAACAAGTCCAGGCTT',
#  'GACATGACGAATAGGTACGG_GACATGACGACAGTGCTATG',
#  'AAGTCAAGCCATCACGTGTC',
#  'CCAACCTGTGTTCATGGCCT',
#  'CAGAGTGGCTACACAACGCC',
#  'TCGATCCTTAGTCACTCAAT',
#  'ATTGTAGAGGAATGATGCGG',
#  'TTCGCTTCACCGAATGATCA',
#  'GTTGATCCTACGCGAATGCT',
#  'GAATCACTTCGCAATGATTG',
#  'GTAGATACGACTGGTTCGGA',
#  'CTACGGTCACACTCTCTACG',
#  'GTCATAACCTAACGGATAAC',
#  'CCAACCTGTGAGGTGCCAGA',
#  'CTGAATGGAGGACGTCTCCT',
#  'TCATTGACCTTACGCGGCTT',
#  'ACAGTCCTGATAGCTAGATC',
#  'GTACGACGAACAGGTTCGTG',
#  'CCGTGTTCACCTCCTATCAT',
#  'TGGTAGTATGTGCAGACCGT',
#  'TGGTAGTATGTAATACCAGG',
#  'GAGAGGACTCCTGGAGTTGA',
#  'ACAGAGTTCCGGTAGGTAGG',
#  'AACGATACCAAATCTGCACA',
#  'CCTATAGACACCTTCGTTAA',
#  'TCGGCATAGCGCAATGATTG',
#  'CAACGCATGCGAACGTGCGT',
#  'TAGGTGATGAAGATTGCTGA',
#  'CTTGGCAAGCAGGCGCGAAT',
#  'TCCAGAACTCGCCAGAGAGA',
#  'TCAAGAGGCGGATACAAGAG',
#  'ATAAGCAGTCCAGTGTGGAA',
#  'TGATGCGGTAAGAAGCGAAC',
#  'TGGCACGATAACTTGAGGCC',
#  'GTTGATCCTATAGTGTCAGA',
#  'AGATCGTTGGAATAGCGTGG',
#  'TGACAACGTGCTCCTCATCC',
#  'GCCAATCTGGCCACACGGAT',
#  'CAACGCATGCCTTAGCACTC',
#  'CAGATTGACCCGTCACGTCA',
#  'TTGCTGGCGTATGATCATGC',
#  'TAGGTGATGATCCGCTATCG',
#  'GACGAGGTAAGCTTAGAAGT',
#  'TATACCATGGAACGCCTGCT',
#  'TGATCCGGCTGATTCCGGAG_TGATCCGGCTCGAATGATCA',
#  'ATTCCTGAGCTTCACTAGTC',
#  'GACATGACGATAGTGTGTTG',
#  'TTCAACCTGGCCTCAATTGC',
#  'GTCAAGACCAAGTCAGAGCA',
#  'ACACGAGTCTTGCTGTATCA',
#  'ATGTCGTGAACCTAACCAGG',
#  'TCAGATCGGTGATGGCCAAC',
#  'CCGTGTTCACAGAAGCGAAC_CCGTGTTCACTAGTGTCAGA_CCGTGTTCACTTGTGTAGGA_CCGTGTTCACGACTTGTAAC',
#  'CCAACAGAGATAGGAGTCAA',
#  'CGGCAATGTGATGCTAATCG',
#  'GACTTAGAGATACGAGGTGG',
#  'CGACTAAGACCGAATATCAG',
#  'TGACAACGTGCACACGCATT',
#  'AGGAGGCAATGCCAAGCCAA',
#  'CGGATCAAGCTGACGAGATG',
#  'GACTGAGATTGTTAGAGACA',
#  'TGGTATTCCGCTTGATTACG',
#  'GGTGACATAGGAGTTCTTGA',
#  'ATCATCCGTTGTGAGTAGCC',
#  'GCGACTCTGATTAGTTGGAC',
#  'TCGAATACTCAGGCGCGAAT',
#  'GGCATCGAACGCCATTGAGG',
#  'AGCTTGGTAGGAGTAACAGG',
#  'GTTGCCAAGGGTCGACTAAC_GTTGCCAAGGTACCGGTTAA',
#  'ACAGAGTTCCAATCTGCACA',
#  'AATGACCGGTAACGCCTGCT',
#  'CAACGCATGCACGAGCTCTC',
#  'TCCAGAACTCCTATCCTTCA',
#  'GAATGTCCGGAGTGTGGCAA',
#  'CTAGGTCTAACAAGCACCGT',
#  'GATAGTGGTCGCCTTCTCTC',
#  'GAGGACATAATGCTTGCCGT',
#  'CGATAATCCTAATTCGCGTG',
#  'GCAGGTTCCAGAAGGTAGTG',
#  'TAGCTCATCCCCATTACGGA',
#  'TGGAGCAGTCTGAGGTAGGC_TGGAGCAGTCTCCGCTATCG',
#  'GTGCAACAACAATCGGAGAA',
#  'GTTGATCCTATGACCGTCCT',
#  'GAAGGACTACTAGATGCTCA',
#  'AACTAAGAGGACCAATATCG',
#  'TCGATCCTTACTTAGCACTC',
#  'ACGATTACGACACGTTAAGA',
#  'GAGAGGACTCGAGTTCTTGA',
#  'GACTGAGATTGGCTTCCAGA',
#  'GAACCTAGTCTAGTGTCAGA',
#  'AACTAAGAGGGTTCCATGCT',
#  'GAGTTAACGTAGGCGATGTA',
#  'GAAGAACGTGACAACAGGAA',
#  'CCTATAGACATGGTCTACTC',
#  'GACCGTCAACAGGAATCGCA',
#  'ATTAGCAACCTGTTAAGCCA',
#  'ATACACAGGTTACTAGGCCT',
#  'CCGTTGTACGACTTAAGAGC',
#  'ACCGAAGGCTCTCGGATGCA',
#  'ACAGTCCTGAATGCTAATCG',
#  'AGAGGAGTTCGCCTTCTCTC',
#  'GCTAGATGCAGCTACGACAG',
#  'AGGAAGTGGACACAGACAAC',
#  'GGTAGTCGACTAGTGTCAGA',
#  'AGGTTGCATTGACGTCTCCT',
#  'TCGGCATAGCAGGTGCCAGA',
#  'CGGCAATGTGGCCTTCTCTC',
#  'CGCATTGCATGCTACGACAG',
#  'TCAGAGTCCGGTATACGATC',
#  'CTCCTCACTATCCGCTATCG',
#  'ATACAAGGCGCTCCTCATCC',
#  'TATGCAATCCGGCTGTCGAT',
#  'GCGAGGTATTGCGAAGAACA',
#  'GTGCTACGGTATCCAGACGG',
#  'TCCTATACCACTCGGATGCA',
#  'GGATCAAGGCGAGTTCTTGA',
#  'TCTCGACAGGACTTAAGAGC',
#  'GGTTAACCTGGAAGGTAGTG',
#  'AGCTCATCAAACCAATATCG',
#  'CTCACAGTGGAAGAGGCTAA',
#  'ACCGAAGGCTACCTCGAATC',
#  'CGGATCAAGCGTGTCAGCAC',
#  'CCGAGCATTCGTGGAAGGTC',
#  'TCTCCTGCAGGCAGACCAGA',
#  'TGGCACGATATGTCAGGCGA',
#  'GTGCAACAACTTCATGGCCT',
#  'CCAGAGCAAGTAGGCTGATT',
#  'ACTACGTGCTACATAATCCG_ACGAGTTGCCATGCTAATCG',
#  'CATGGCATAGTCAATGCGCA',
#  'TTGGACGTCATCGCGAATCT',
#  'ATAGGCGAGCCCATGCATAC',
#  'TGGCATTCACCTAGAAGGCT',
#  'GTCGGTTCTTTTGTCCGCCA',
#  'TGCATCGTATTGTAGCAAGT',
#  'GAGATGCACTTAGGAGTCAA_GAGATGCACTATGCTAATCG',
#  'AAGTCAAGCCTATGCAGCTA',
#  'TGATCCGGCTAAGTGCAGAA',
#  'GTTAAGAACGTAGTGTCAGA',
#  'GGTGACATAGTAATACCAGG',
#  'GTCGTAGTATGTGACGTGGA',
#  'GGAGTATTCTTGCGTAGTAA',
#  'TCGGATCCATGTTGTATCGG',
#  'GTGTAAGTGACTCCTATCAT',
#  'TGTTGCAATGCTGGAACACG',
#  'GGCATTATCCCAAGACGTCT',
#  'ACATGTGAGATTAGTGCACA',
#  'ACAGAGTTCCATTCGGTCAG',
#  'CTACGGTCACATCACGTGTC',
#  'TCATTGACCTATGTCTGCTT',
#  'TCTCGACAGGAGCATGTTGG',
#  'AATGACCGGTAGGCGATGTA',
#  'CTCAGTTGCCCTAGAAGGCT',
#  'AACGACTCAGCTCCTCATCC',
#  'ATTAGCAACCTGTCAGGCGA',
#  'CGAACAACAAATCTCAACAG',
#  'ACACCTGAAGCATAATGCCT',
#  'TCATTGACCTAGGTGTCGTG',
#  'ATAGGCGAGCCGAAGTACCG',
#  'CTGTAGACGGGAACTCGTAG_CTGTAGACGGTGACCGGAAC',
#  'CTCACAGTGGGCCATTGAGG',
#  'ATACAGGTCCATCCAGCGCA',
#  'TCTCTAGTGAAGGAATCGCA',
#  'TCGGCATAGCTCGTTGGACT',
#  'ACGAGTTGCCCTTGAAGAAG',
#  'TCTGTCGAACCTAACGGCTA',
#  'TCATTGACCTAGGACGTTCG',
#  'ACATGTGAGACTCCGATTCT',
#  'CGTATGCCTCAGTATAGTCC',
#  'AGGAAGTGGAGTGATAGGAA',
#  'AGATCGTTGGGTTCCATGCT',
#  'TGCATGTCGCGTCTTGTATG',
#  'ACGAGTTGCCAAGAGGCTAA',
#  'ATTGTAGAGGGCTCGTTGTT',
#  'CGTTGACCACAGAAGCGAAC',
#  'CACCTGCTAGTGTGTCTGCC',
#  'GAATGTCCGGCCATAGCGAA',
#  'GAAGCCTGGTCGAATATCAG',
#  'ACACGAGTCTGTTGGACATA',
#  'GCTAGTATACTAGGAGTCAA',
#  'CTTGTGGAGACAGGTTCGTG',
#  'CAACACCATTGGTTAATCAC',
#  'GAGATGCACTTTGGTACGTA',
#  'TTGCTGGCGTGAGCGGTAAC',
#  'ATGCGTTCTGGCCTTCTCTC',
#  'GTCGTAGTATTACCTTCGAT',
#  'TACAAGAGGCATGAAGTGCG',
#  'GGAACAGGCAGTTGGACATA',
#  'ATCAGACCGCACGGTGGACA',
#  'GGACTGGCATGTAACTGACA',
#  'CTGTCTGGCTTAGTGTCAGA',
#  'TGTGGACCATCACTGGTGGT',
#  'GGAGCGGATTTAGTGTGTTG',
#  'GGCTGAAGTAAGGTGCCAGA',
#  'GGCAACCTCTAGACTGTTCT',
#  'TCGTCTAGAGGCGGTGGTTA',
#  'CATGGACTGATCGTTGGACT',
#  'AACAGTCAGTCACCAACCTA',
#  'TGGTCCAAGGTGAACCTTAC',
#  'CGACAGACGTGCTGATGGTA',
#  'GAACTATGACACGGTGGACA',
#  'CAATTGGAGAAGCGTACTAT',
#  'TCCTGGTGGAATGACTCCAA',
#  'ATTCTCAGACTAGTGTGTTG',
#  'CTCACAGTGGAACGCCTGCT',
#  'ATCCTCGTAACTCGATCAAC',
#  'CATACCACAAACCTCGAATC',
#  'GTTAAGAACGAATCTGCACA',
#  'GTCGAACTGGTAAGTGATCG',
#  'TCGATCCTTACTTGATGTGA',
#  'TAACTCACAGGCCAGAGAGA',
#  'TGGTCGTGGATGTCACAACA',
#  'ATACACAGGTCTGACCAGAT',
#  'GTGCAACAACCGTTCCAAGA',
#  'CTCTGTGCACAGCGGATACA',
#  'CTGAATGGAGACTTAAGAGC',
#  'GATGTTCGATTAAGCTGGAA',
#  'GACTACAAGATCCGTAACCT',
#  'GCGATCTACGCTTGATGTGA',
#  'GTTGATCCTACGCTTGAGAG',
#  'ATTGTAGAGGACGACCACTT',
#  'TTCCTCGTGTGTATCCAGTC',
#  'ATTAGCAACCAAGCTGTATC',
#  'CTTGTGGAGAAACATTCCGG',
#  'GTCAGCTCAGCCGGTTACAT',
#  'GTGTGCTACAGCGAAGAACA',
#  'GTTGATCCTACTGGAGTTGA',
#  'CTCTGTGCACTAATCTGTGC',
#  'CTCAGTTGCCCAGAGGAACG',
#  'AGTTCCATGGCAACCAACGG',
#  'AAGTCAAGCCTGAGGTAGGC',
#  'TGTCTGCGTGGTGTGAAGAA',
#  'CTTGTGGAGATCGGTGTCTC',
#  'GAAGCCTGGTTAATGTGCTC',
#  'GACTGAGATTGAGCTGTGAA',
#  'CGAGATCGGAACGGTGCTCT',
#  'TGCATGAGGTAGGTGCCAGA',
#  'TCTATACGTGCTAACGGCTA',
#  'TTGCACCACGCTGTAATCCA',
#  'CACCTGCTAGGCAATGATTG',
#  'CAGATTGACCCTTGGAATTC',
#  ...]
