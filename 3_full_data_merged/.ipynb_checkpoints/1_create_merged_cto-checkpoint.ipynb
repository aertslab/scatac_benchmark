# %% [markdown]
# # pycisTopic analysis
#
# Library downsampled dataset

# %%
import pycisTopic
pycisTopic.__version__
# Out:
# '0.1.dev300+g7494158'

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pickle
import pandas as pd

# %%
import os
wdir = '/user/leuven/330/vsc33042/fderop/data/20211027_hca_benchmark_full_merged/'
os.chdir( wdir )

# %%
import glob
from collections import OrderedDict

# %% [markdown]
# # read the SCREEN CTOs from the single sample analysises

# %%
filenames = glob.glob('pycistopic_screen/ctos/*__cistopic_obj.pkl')
samples = [item.replace("__cistopic_obj.pkl", "") for item in filenames]
samples = [item.replace("ctos/", "") for item in samples]
ctos_files_dict = {samples[i]: filenames[i] for i in range(len(samples))}
ctos_files_dict = OrderedDict(sorted(ctos_files_dict.items()))
ctos_files_dict.keys()
# Out:
# odict_keys(['pycistopic_screen/Broad_1', 'pycistopic_screen/Broad_2', 'pycistopic_screen/Broad_mito_1', 'pycistopic_screen/Broad_mito_2', 'pycistopic_screen/CNAG_1', 'pycistopic_screen/CNAG_2', 'pycistopic_screen/Sanger_1', 'pycistopic_screen/Sanger_2', 'pycistopic_screen/Stanford_1', 'pycistopic_screen/Stanford_2', 'pycistopic_screen/VIB_1', 'pycistopic_screen/VIB_2', 'pycistopic_screen/VIB_Hydrop_1', 'pycistopic_screen/VIB_Hydrop_2', 'pycistopic_screen/full_merged', 'pycistopic_screen/s3atac'])

# %%
# load objects into dict:
f_cto_dir = 'ctos'

cistopic_obj_dict = {}
for key in ctos_files_dict.keys():
    f_out = ctos_files_dict[key]
    infile = open(f_out, 'rb')
    tmp_cto = pickle.load(infile)
    infile.close()
    cistopic_obj_dict[key] = tmp_cto
    print(f"Loaded {key}")

# %% [markdown]
# ## Cell filtering

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ### Read in Freemuxlet doublet predictions

# %%
f_fmx = 'fmx_out/genotype_concordance_unified.txt'
fmx = pd.read_csv(f_fmx, sep='\t')

# %%
# create an annotation df:
fmx['cell_names'] = fmx['BARCODE'] + "-" + fmx['replicate']

fmx_annot = fmx[['DROPLET.TYPE','sample','cell_names']].copy().set_index('cell_names')
fmx_annot.columns = ['fmx_droplet_type','fmx_sample']

# %%
for key in cistopic_obj_dict.keys():
    cistopic_obj_dict[key].add_cell_data(fmx_annot)

# %% [markdown]
# ### Run Scrublet

# %%
import scrublet as scr
import pandas as pd
import matplotlib.pyplot as plt

# %%
scrublet_doublet_thresholds = {
    'Broad_1': 0.35,
    'Broad_2': 0.4,
    'Broad_mito_1': 0.37,
    'Broad_mito_2': 0.4,
    'CNAG_1': 0.36,
    'CNAG_2': 0.35,
    's3atac': 0.4,
    'Sanger_1': 0.35,
    'Sanger_2': 0.35,
    'Stanford_1': 0.34,
    'Stanford_2': 0.4,
    'VIB_1': 0.39,
    'VIB_2': 0.38,
    'VIB_Hydrop_1': 0.35,
    'VIB_Hydrop_2': 0.35,
}

# %%
for key in cistopic_obj_dict.keys():
    print(f"Starting {key}")
    scrub = scr.Scrublet(cistopic_obj_dict[key].fragment_matrix.T, expected_doublet_rate=0.1)
    doublet_scores, predicted_doublets = scrub.scrub_doublets()
    #scrub.plot_histogram();
    scrub.call_doublets(threshold=scrublet_doublet_thresholds[key])
    a,b = scrub.plot_histogram();
    a.suptitle(key)
    plt.show()
    scrublet = pd.DataFrame([scrub.doublet_scores_obs_, scrub.predicted_doublets_], 
        columns=cistopic_obj_dict[key].cell_names,
        index=['Doublet_scores_fragments', 'Predicted_doublets_fragments']).T
    cistopic_obj_dict[key].add_cell_data(scrublet)
# Out:
# Starting Broad_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 5.9%
# Estimated detectable doublet fraction = 58.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.1%
# Elapsed time: 13.8 seconds
# Detected doublet rate = 5.2%
# Estimated detectable doublet fraction = 56.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.3%
# Starting Broad_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 5.8%
# Estimated detectable doublet fraction = 59.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.7%
# Elapsed time: 12.0 seconds
# Detected doublet rate = 4.1%
# Estimated detectable doublet fraction = 51.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.9%
# Starting Broad_mito_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 3.2%
# Estimated detectable doublet fraction = 59.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 5.3%
# Elapsed time: 22.3 seconds
# Detected doublet rate = 3.1%
# Estimated detectable doublet fraction = 58.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 5.4%
# Starting Broad_mito_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 2.7%
# Estimated detectable doublet fraction = 60.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.4%
# Elapsed time: 25.4 seconds
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 59.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.2%
# Starting CNAG_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 6.4%
# Estimated detectable doublet fraction = 51.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.5%
# Elapsed time: 20.0 seconds
# Detected doublet rate = 5.3%
# Estimated detectable doublet fraction = 47.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.0%
# Starting CNAG_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 5.4%
# Estimated detectable doublet fraction = 52.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.3%
# Elapsed time: 8.2 seconds
# Detected doublet rate = 4.5%
# Estimated detectable doublet fraction = 48.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.2%
# Starting Sanger_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 9.7%
# Estimated detectable doublet fraction = 66.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.6%
# Elapsed time: 36.3 seconds
# Detected doublet rate = 4.8%
# Estimated detectable doublet fraction = 44.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.7%
# Starting Sanger_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 73.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 17.1%
# Elapsed time: 38.9 seconds
# Detected doublet rate = 4.1%
# Estimated detectable doublet fraction = 37.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.9%
# Starting Stanford_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 49.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.7%
# Elapsed time: 4.9 seconds
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 51.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.0%
# Starting Stanford_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 49.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.7%
# Elapsed time: 5.1 seconds
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 49.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.7%
# Starting VIB_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 51.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.0%
# Elapsed time: 9.0 seconds
# Detected doublet rate = 2.1%
# Estimated detectable doublet fraction = 51.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.0%
# Starting VIB_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.24
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 51.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 19.4%
# Elapsed time: 15.0 seconds
# Detected doublet rate = 3.2%
# Estimated detectable doublet fraction = 24.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.8%
# Starting VIB_Hydrop_1
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.1%
# Elapsed time: 6.3 seconds
# Detected doublet rate = 6.3%
# Estimated detectable doublet fraction = 28.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 21.9%
# Starting VIB_Hydrop_2
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 20.0%
# Estimated detectable doublet fraction = 58.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.1%
# Elapsed time: 3.4 seconds
# Detected doublet rate = 3.5%
# Estimated detectable doublet fraction = 20.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 17.5%
# Starting s3atac
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.08
# Detected doublet rate = 88.9%
# Estimated detectable doublet fraction = 96.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 92.5%
# Elapsed time: 147.0 seconds
# Detected doublet rate = 2.5%
# Estimated detectable doublet fraction = 6.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.5%

# %%
for key in scrublet_doublet_thresholds.keys():
    print(f"{key}: found doublets: \n\t({sum(cistopic_obj_dict[key].cell_data.Predicted_doublets_fragments)}: Scrublet); "
          f"\n\t({sum(cistopic_obj_dict[key].cell_data.fmx_droplet_type == 'DBL')}: freemuxlet)"
         )
# Out:
# Broad_1: found doublets:
# 	(220: Scrublet);
# 	(129: freemuxlet)
# Broad_2: found doublets:
# 	(165: Scrublet);
# 	(99: freemuxlet)
# Broad_mito_1: found doublets:
# 	(109: Scrublet);
# 	(25: freemuxlet)
# Broad_mito_2: found doublets:
# 	(81: Scrublet);
# 	(25: freemuxlet)
# CNAG_1: found doublets:
# 	(142: Scrublet);
# 	(43: freemuxlet)
# CNAG_2: found doublets:
# 	(122: Scrublet);
# 	(47: freemuxlet)
# s3atac: found doublets:
# 	(77: Scrublet);
# 	(0: freemuxlet)
# Sanger_1: found doublets:
# 	(151: Scrublet);
# 	(212: freemuxlet)
# Sanger_2: found doublets:
# 	(155: Scrublet);
# 	(276: freemuxlet)
# Stanford_1: found doublets:
# 	(16: Scrublet);
# 	(5: freemuxlet)
# Stanford_2: found doublets:
# 	(26: Scrublet);
# 	(4: freemuxlet)
# VIB_1: found doublets:
# 	(59: Scrublet);
# 	(27: freemuxlet)
# VIB_2: found doublets:
# 	(232: Scrublet);
# 	(200: freemuxlet)
# VIB_Hydrop_1: found doublets:
# 	(151: Scrublet);
# 	(40: freemuxlet)
# VIB_Hydrop_2: found doublets:
# 	(97: Scrublet);
# 	(57: freemuxlet)

# %% [markdown]
# ### Apply cell filtering
#
# Remove doublets (freemuxlet, scrublet)

# %%
removed_bcs_dict = {}
for key in cistopic_obj_dict.keys():
    if key=='merged':
        continue
        
    removed_bcs_dict[key] = {
        'dbl_scrublet': cistopic_obj_dict[key].cell_data.barcode[ cistopic_obj_dict[key].cell_data.Predicted_doublets_fragments == True ].tolist(),
        'dbl_fmx': cistopic_obj_dict[key].cell_data.barcode[ cistopic_obj_dict[key].cell_data.fmx_droplet_type == 'DBL' ].tolist(),    
    }
    # Remove doublets 
    singlets = cistopic_obj_dict[key].cell_data[
        (cistopic_obj_dict[key].cell_data.Predicted_doublets_fragments == False) & 
        (cistopic_obj_dict[key].cell_data.fmx_droplet_type != 'DBL')
    ].index.tolist()
    print(f"{key}: Removing {len(cistopic_obj_dict[key].cell_names)-len(singlets)} cells"
    )
    # Subset cisTopic object
    cistopic_obj_dict[key].subset(singlets)
    
with open(os.path.join(wdir, 'removed_barcodes_dict.pkl'), 'wb') as f:
    pickle.dump(removed_bcs_dict, f)
# Out:
# Broad_1: Removing 283 cells
# Broad_2: Removing 214 cells
# Broad_mito_1: Removing 117 cells
# Broad_mito_2: Removing 92 cells
# CNAG_1: Removing 163 cells
# CNAG_2: Removing 151 cells
# Sanger_1: Removing 309 cells
# Sanger_2: Removing 371 cells
# Stanford_1: Removing 19 cells
# Stanford_2: Removing 28 cells
# VIB_1: Removing 74 cells
# VIB_2: Removing 399 cells
# VIB_Hydrop_1: Removing 184 cells
# VIB_Hydrop_2: Removing 144 cells
# s3atac: Removing 77 cells

# %% [markdown]
# # merge

# %%
import copy

# %%
f_out = os.path.join(wdir, f_cto_dir, 'full_merged__cistopic_obj.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        cistopic_obj_dict['merged'] = pickle.load(f)
else:
    # merge:
    ct_keys = list(cistopic_obj_dict.keys())
    cto_merged = copy.copy(cistopic_obj_dict[ct_keys[0]])
    cto_merged.merge([ cistopic_obj_dict[k] for k in ct_keys[1:] ], project='scATAC-seq_benchmark')
    with open(f_out, 'wb') as f:
        pickle.dump(cto_merged, f)
    cistopic_obj_dict['merged'] = cto_merged
# Out:
# 2021-10-27 15:10:00,805 cisTopic     INFO     cisTopic object 1 merged
# 2021-10-27 15:10:39,904 cisTopic     INFO     cisTopic object 2 merged
# 2021-10-27 15:11:15,196 cisTopic     INFO     cisTopic object 3 merged
# 2021-10-27 15:11:52,721 cisTopic     INFO     cisTopic object 4 merged
# 2021-10-27 15:12:31,288 cisTopic     INFO     cisTopic object 5 merged
# 2021-10-27 15:13:11,860 cisTopic     INFO     cisTopic object 6 merged
# 2021-10-27 15:14:01,056 cisTopic     INFO     cisTopic object 7 merged
# 2021-10-27 15:14:49,699 cisTopic     INFO     cisTopic object 8 merged
# 2021-10-27 15:15:42,296 cisTopic     INFO     cisTopic object 9 merged
# 2021-10-27 15:16:42,253 cisTopic     INFO     cisTopic object 10 merged
# 2021-10-27 15:17:45,328 cisTopic     INFO     cisTopic object 11 merged
# 2021-10-27 15:18:57,884 cisTopic     INFO     cisTopic object 12 merged
# 2021-10-27 15:20:11,336 cisTopic     INFO     cisTopic object 13 merged
# 2021-10-27 15:21:27,731 cisTopic     INFO     cisTopic object 14 merged
