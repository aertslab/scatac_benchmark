# %% [markdown]
# # pycisTopic analysis
#
# Full dataset, using consensus peak regions.

# %%
import pycisTopic
pycisTopic.__version__
# Out:
# '0.1.dev300+g7494158'

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pickle
import pandas as pd

# %%
import os
wdir = '/lustre1/project/stg_00002/lcb/fderop/data/20211013_hca_benchmark_libds'
os.chdir( wdir )

# %%
# create output directory:
f_final_dir = os.path.join(wdir, 'downstream_analysis')
if not os.path.exists(f_final_dir):
    os.makedirs(f_final_dir)

# %%
import re

sample_annot = pd.DataFrame(
    [
        ['Broad_1','BioRad'],
        ['Broad_2','BioRad'],
        ['Stanford_1','10x v1.0'],
        ['Stanford_2','10x v1.0'],
        ['VIB_1','10x v1.0'],
        ['VIB_2','10x v1.0'],
        ['CNAG_1','10x v1.1'],
        ['CNAG_2','10x v1.1'],
        ['Broad_mito_1','mito-scATAC-seq'],
        ['Broad_mito_2','mito-scATAC-seq'],
        ['Sanger_1','10x multiome'],
        ['Sanger_2','10x multiome'],
        ['s3atac','s3-ATAC'],
        ['VIB_Hydrop_1','HyDrop'],
        ['VIB_Hydrop_2','HyDrop'],
        
    ],
    columns=['key','Technology']
)
sample_annot['Sample'] = sample_annot['key']
sample_annot.set_index('key', drop=False, inplace=True)
# rename samples:
sample_annot.loc['Broad_1','Sample'] = 'Harvard_1'
sample_annot.loc['Broad_2','Sample'] = 'Harvard_2'
sample_annot.loc['Broad_mito_1','Sample'] = 'Broad_1'
sample_annot.loc['Broad_mito_2','Sample'] = 'Broad_2'
sample_annot.loc['s3atac','Sample'] = 'OHSU'
sample_annot.loc['VIB_Hydrop_1','Sample'] = 'Hydrop_1'
sample_annot.loc['VIB_Hydrop_2','Sample'] = 'Hydrop_2'

sample_annot['Replicate'] = [ x.Sample.split('_')[-1] for i,x in sample_annot.iterrows() ]
sample_annot['st'] = [ re.sub('_[0-9]','',x.Sample)+' ('+x.Technology+')' for i,x in sample_annot.iterrows() ]

sample_annot.loc[sample_annot['key']=='s3atac','Replicate'] = 1
sample_map = { x: y.Sample for x,y in sample_annot.iterrows() }
sample_annot
# Out:
#                        key       Technology      Sample Replicate  \
# key
# Broad_1            Broad_1           BioRad   Harvard_1         1
# Broad_2            Broad_2           BioRad   Harvard_2         2
# Stanford_1      Stanford_1         10x v1.0  Stanford_1         1
# Stanford_2      Stanford_2         10x v1.0  Stanford_2         2
# VIB_1                VIB_1         10x v1.0       VIB_1         1
# VIB_2                VIB_2         10x v1.0       VIB_2         2
# CNAG_1              CNAG_1         10x v1.1      CNAG_1         1
# CNAG_2              CNAG_2         10x v1.1      CNAG_2         2
# Broad_mito_1  Broad_mito_1  mito-scATAC-seq     Broad_1         1
# Broad_mito_2  Broad_mito_2  mito-scATAC-seq     Broad_2         2
# Sanger_1          Sanger_1     10x multiome    Sanger_1         1
# Sanger_2          Sanger_2     10x multiome    Sanger_2         2
# s3atac              s3atac          s3-ATAC        OHSU         1
# VIB_Hydrop_1  VIB_Hydrop_1           HyDrop    Hydrop_1         1
# VIB_Hydrop_2  VIB_Hydrop_2           HyDrop    Hydrop_2         2
#
#                                    st
# key
# Broad_1              Harvard (BioRad)
# Broad_2              Harvard (BioRad)
# Stanford_1        Stanford (10x v1.0)
# Stanford_2        Stanford (10x v1.0)
# VIB_1                  VIB (10x v1.0)
# VIB_2                  VIB (10x v1.0)
# CNAG_1                CNAG (10x v1.1)
# CNAG_2                CNAG (10x v1.1)
# Broad_mito_1  Broad (mito-scATAC-seq)
# Broad_mito_2  Broad (mito-scATAC-seq)
# Sanger_1        Sanger (10x multiome)
# Sanger_2        Sanger (10x multiome)
# s3atac                 OHSU (s3-ATAC)
# VIB_Hydrop_1          Hydrop (HyDrop)
# VIB_Hydrop_2          Hydrop (HyDrop)

# %% [markdown]
# ## Load the cisTopic objects
# For each sample: using the sample-specific peaks
# For the merged set: using the merged consensus peaks

# %%
# Valid barcodes
with open(wdir + '/pycistopic_screen/barcodes_passing_filters_filtered.pkl', 'rb') as f:
    bc_passing_filters = pickle.load(f)

# %% [markdown]
# # f_cto_merged_dir = 'cistopic_objs__consensus_peaks_merged'
# if not os.path.exists(os.path.join(wdir, f_cto_dir)):
#     os.makedirs(os.path.join(wdir, f_cto_dir))

# %%
f_cto_dir = 'pycistopic_consensus_peaks/cistopic_objs__consensus'
if not os.path.exists(os.path.join(wdir, f_cto_dir)):
    os.makedirs(os.path.join(wdir, f_cto_dir))

# %%
# load objects into dict:
cistopic_obj_dict = {}
for key in bc_passing_filters.keys():
    f_out = os.path.join(wdir, f_cto_dir, key + '__cistopic_obj_metadata_annotated.pkl')
    with open(f_out, 'rb') as f:
        tmp_cto = pickle.load(f)
    cistopic_obj_dict[key] = tmp_cto
    print(f"Loaded {key}")
# Out:
# Loaded VIB_Hydrop_1
# Loaded VIB_Hydrop_2

# %% [markdown]
# # add the merged object:
# f_out = os.path.join(wdir, f_cto_merged_dir, 'libds_merged__cistopic_obj.pkl')
# if os.path.isfile(f_out):
#     print(f"Loading {f_out}")
#     with open(f_out, 'rb') as f:
#         cistopic_obj_dict['merged'] = pickle.load(f)

# %%
for key in cistopic_obj_dict.keys():
    print(cistopic_obj_dict[key])
# Out:
# CistopicObject from project VIB_Hydrop_1 with n_cells × n_regions = 2208 × 89030
# CistopicObject from project VIB_Hydrop_2 with n_cells × n_regions = 2531 × 99392

# %% [markdown]
# ## Add cell annotations

# %%
cellannot = pd.read_csv(
    'pycistopic_screen/filtered_cell_data.tsv',
    sep='\t', index_col=0)
cellannot
# Out:
#                                       cisTopic_nr_frag  cisTopic_log_nr_frag  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1              2815              3.449478
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1              1977              3.296007
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1              5101              3.707655
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1              1930              3.285557
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1              3877              3.588496
# ...                                                ...                   ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2               898              2.953276
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2              1331              3.124178
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2              1128              3.052309
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2              1396              3.144885
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2               757              2.879096
#
#                                       cisTopic_nr_acc  cisTopic_log_nr_acc  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1             2691             3.429914
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1             1890             3.276462
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1             4791             3.680426
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1             1832             3.262925
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1             3670             3.564666
# ...                                               ...                  ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2              868             2.938520
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2             1263             3.101403
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2             1084             3.035029
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2             1376             3.138618
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2              715             2.854306
#
#                                          sample_id  Log_total_nr_frag  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1  VIB_Hydrop_1           3.977906
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1  VIB_Hydrop_1           3.998913
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1  VIB_Hydrop_1           4.411771
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1  VIB_Hydrop_1           4.120607
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1  VIB_Hydrop_1           4.389644
# ...                                            ...                ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2  VIB_Hydrop_2           3.648653
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2  VIB_Hydrop_2           3.712229
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2  VIB_Hydrop_2           3.719414
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2  VIB_Hydrop_2           3.973497
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2  VIB_Hydrop_2           3.631342
#
#                                       Log_unique_nr_frag  Total_nr_frag  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1            3.499824           9504
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1            3.330617           9975
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1            3.753506          25809
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1            3.353916          13201
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1            3.634376          24527
# ...                                                  ...            ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2            2.981819           4453
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2            3.154424           5155
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2            3.070776           5241
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2            3.205204           9408
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2            2.972666           4279
#
#                                       Unique_nr_frag  Dupl_nr_frag  ...  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1            3161          6343  ...
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1            2141          7834  ...
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1            5669         20140  ...
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1            2259         10942  ...
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1            4309         20218  ...
# ...                                              ...           ...  ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2             959          3494  ...
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2            1427          3728  ...
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2            1177          4064  ...
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2            1604          7804  ...
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2             939          3340  ...
#
#                                                       barcode  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1  GTTAAGAACGTAGTGTCAGA-12
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1  GGTACTCATTTACTGATAGC-11
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1  GTCGTTGAGATGCGTAGTAA-12
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1  GTGGTATCCTTGACCGGAAC-12
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1  CATTGGTGCAACGGTGGACA-12
# ...                                                       ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2  TAACTCACAGCTTAGCACTC-22
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2  CTTGGCAAGCTCCTGATAAG-21
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2  GCACACAGTCTCCGGTCAAG-22
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2  ATCGTGCCTACCACACGGAT-22
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2  GAGTGAGGTATCTGGTCCGA-22
#
#                                       fmx_droplet_type  fmx_sample  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1               SNG     sampleA
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1               SNG     sampleA
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1               SNG     sampleA
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1               SNG     sampleB
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1               SNG     sampleA
# ...                                                ...         ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2               SNG     sampleA
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2               SNG     sampleA
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2               SNG     sampleA
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2               SNG     sampleB
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2               SNG     sampleA
#
#                                       Doublet_scores_fragments  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1                  0.079365
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1                  0.122970
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1                  0.167630
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1                  0.179331
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1                  0.138539
# ...                                                        ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2                  0.076923
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2                  0.066667
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2                  0.127753
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2                  0.084746
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2                  0.045623
#
#                                       Predicted_doublets_fragments  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1                         False
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1                         False
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1                         False
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1                         False
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1                         False
# ...                                                            ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2                         False
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2                         False
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2                         False
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2                         False
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2                         False
#
#                                      pycisTopic_leiden_10_0.6  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1                       10
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1                        1
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1                        0
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1                        2
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1                        4
# ...                                                       ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2                        7
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2                        0
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2                        6
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2                        2
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2                        3
#
#                                      pycisTopic_leiden_10_0.8  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1                        9
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1                        1
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1                        0
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1                       10
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1                        4
# ...                                                       ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2                        6
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2                        1
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2                        8
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2                       12
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2                        9
#
#                                       seurat_cell_type  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1    CD14+ monocyte
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1    CD14+ monocyte
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1    CD14+ monocyte
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1       CD4+ T cell
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1    CD14+ monocyte
# ...                                                ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2       CD4+ T cell
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2  Cytotoxic T cell
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2  Cytotoxic T cell
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2    CD14+ monocyte
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2  Cytotoxic T cell
#
#                                       seurat_cell_type_pred_score  \
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1                     0.805399
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1                     0.389450
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1                     0.391287
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1                     0.456999
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1                     0.678991
# ...                                                           ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2                     0.464026
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2                     0.539867
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2                     0.439248
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2                     0.510324
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2                     0.488427
#
#                                       consensus_cell_type
# GTTAAGAACGTAGTGTCAGA-12-VIB_Hydrop_1       CD14+ monocyte
# GGTACTCATTTACTGATAGC-11-VIB_Hydrop_1       CD14+ monocyte
# GTCGTTGAGATGCGTAGTAA-12-VIB_Hydrop_1       CD14+ monocyte
# GTGGTATCCTTGACCGGAAC-12-VIB_Hydrop_1          CD4+ T cell
# CATTGGTGCAACGGTGGACA-12-VIB_Hydrop_1       CD14+ monocyte
# ...                                                   ...
# TAACTCACAGCTTAGCACTC-22-VIB_Hydrop_2     Cytotoxic T cell
# CTTGGCAAGCTCCTGATAAG-21-VIB_Hydrop_2     Cytotoxic T cell
# GCACACAGTCTCCGGTCAAG-22-VIB_Hydrop_2          CD4+ T cell
# ATCGTGCCTACCACACGGAT-22-VIB_Hydrop_2       CD14+ monocyte
# GAGTGAGGTATCTGGTCCGA-22-VIB_Hydrop_2     Cytotoxic T cell
#
# [4739 rows x 25 columns]

# %%
cellannot = cellannot.add_prefix('SCREEN_')

# %%
for key in cistopic_obj_dict.keys():
    cistopic_obj_dict[key].add_cell_data(
        cellannot[['SCREEN_seurat_cell_type','SCREEN_fmx_sample', 'SCREEN_TSS_enrichment','SCREEN_FRIP','SCREEN_Unique_nr_frag','SCREEN_Log_unique_nr_frag','SCREEN_Dupl_rate']]
    )

# %% [markdown]
# ### Read in LDA/mallett models

# %%
from pycisTopic.lda_models import evaluate_models
import matplotlib.pyplot as plt

# %%
n_iter = 500

# %%
f_mod_dir = 'pycistopic_consensus_peaks/models__consensus__mallet'

models_dict = {}
for key in cistopic_obj_dict.keys():
    f_mod = os.path.join(wdir, f_mod_dir, key + '__models_' + str(n_iter) + '_iter.pkl')
    if(os.path.isfile(f_mod)):
        with open(f_mod, 'rb') as f:
            models_dict[key] = pickle.load(f)
        print(f"Loaded {key}")
# Out:
# Loaded VIB_Hydrop_1
# Loaded VIB_Hydrop_2

# %%
model_selection = {
    'Broad_1': 40,
    'Broad_2': 40,
    'Broad_mito_1': 30,
    'Broad_mito_2': 35,
    'CNAG_1': 40,
    'CNAG_2': 40,
    's3atac': 40,
    'Sanger_1': 35,
    'Sanger_2': 40,
    'Stanford_1': 35,
    'Stanford_2': 35,
    'VIB_1': 40,
    'VIB_2': 40,
    'merged': 80,
    'VIB_Hydrop_1': 50,
    'VIB_Hydrop_2': 40
}

# %%
for key in models_dict.keys():
    print(key)
    model=evaluate_models(models_dict[key],
                         select_model=model_selection[key], 
                         return_model=True, 
                         metrics=['Arun_2010','Cao_Juan_2009', 'Minmo_2011', 'loglikelihood'],
                         plot=True,
                         plot_metrics=False
                         )
    cistopic_obj_dict[key].add_LDA_model(model)
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# ## Visualizations

# %%
from pycisTopic.clust_vis import (
    find_clusters,
    run_umap,
    run_tsne,
    plot_metadata,
    plot_topic,
    cell_topic_heatmap
)

# %%
for key in cistopic_obj_dict.keys():
    find_clusters(cistopic_obj_dict[key],
              target  = 'cell',
              k = 10,
              res = [0.6, 0.8, 1.0],
              prefix = 'pycisTopic_')
    cistopic_obj_dict[key].projections['cell'] = {}
    run_umap(cistopic_obj_dict[key], target = 'cell')
    #run_tsne(cistopic_obj_dict[key], target = 'cell')
# Out:
# 2021-10-22 12:56:05,077 cisTopic     INFO     Finding neighbours
# 2021-10-22 12:56:05,359 cisTopic     INFO     Running UMAP
# 2021-10-22 12:56:15,959 cisTopic     INFO     Finding neighbours
# 2021-10-22 12:56:16,279 cisTopic     INFO     Running UMAP

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    plot_metadata(cistopic_obj_dict[key],
                  reduction_name='UMAP',
                  variables=['cisTopic_nr_frag', 'cisTopic_nr_acc',
                             'pycisTopic_leiden_10_0.8', 'consensus_cell_type'],
                  target='cell',
                  num_columns=4,
                  text_size=16,
                  dot_size=15,
                  figsize=(18,5),
                 )
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    cell_topic_heatmap(cistopic_obj_dict[key],
                     variables = ['consensus_cell_type'],
                     scale = False,
                     legend_loc_x = 1.05,
                     legend_loc_y = -1.2,
                     legend_dist_y = -1,
                     figsize=(10,8),
                     )
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# ## Save/load cisTopic objects

# %%
f_cto_dir = 'pycistopic_consensus_peaks/cistopic_objs__consensus'

if not os.path.exists(os.path.join(wdir, f_cto_dir)):
    os.makedirs(os.path.join(wdir, f_cto_dir))

for key in cistopic_obj_dict.keys():
    f_out = os.path.join(wdir, f_cto_dir, key + '__cistopic_obj_metadata_annotated_dimreduc.pkl')
    if os.path.isfile(f_out):
        print(f"Skipping {key}, already exists")
        continue
    with open(f_out, 'wb') as f:
        pickle.dump(cistopic_obj_dict[key], f)
    print(f"Generated and saved cistopic object for {key}")
# Out:
# Generated and saved cistopic object for VIB_Hydrop_1
# Generated and saved cistopic object for VIB_Hydrop_2

# %%
f_out = os.path.join(wdir, f_cto_dir, 'libds_all_with_models__cistopic_obj.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        cistopic_obj_dict = pickle.load(f)
else:
    with open(f_out, 'wb') as f:
        pickle.dump(cistopic_obj_dict, f)
# Out:
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_library_downsampled/atac_qc_multiplet_merged/jupyter/cistopic_objs__consensus_peaks/libds_all_with_models__cistopic_obj.pkl

# %% [markdown]
# ## Topic binarization & QC

# %%
from pycisTopic.topic_binarization import binarize_topics

# %% [markdown]
# ### Binarize the topic-region distributions

# %%
region_bin_topics_dict = {}
for key in cistopic_obj_dict.keys():
    print(key)
    region_bin_topics_dict[key] = binarize_topics(
        cistopic_obj_dict[key],
        method='otsu',
        ntop=3000,
        plot=True,
        num_columns=6,
    )
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# ### Binarize the cell-topic distribions

# %%
binarized_cell_topic_dict = {}
for key in cistopic_obj_dict.keys():
    print(key)
    binarized_cell_topic = binarize_topics(
        cistopic_obj_dict[key],
        target='cell',
        method='li',
        plot=True,
        num_columns=5,
        nbins=100
    )
    binarized_cell_topic_dict[key] = binarized_cell_topic.copy()
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# ### Refine the binarization thresholds

# %%
# predifined_thr={'Topic12':0.7, 'Topic13':0.4, 'Topic27':0.5}
# binarized_cell_topic = binarize_topics(
#     cistopic_obj_dict['CNAG_1'],
#     target='cell',
#     method='li',
#     plot=True,
#     num_columns=5,
#     nbins=100,
#     predifined_thr=predifined_thr
# )

# %% [markdown]
# ### Compute the topic quality control metrics

# %%
from pycisTopic.topic_qc import compute_topic_metrics, plot_topic_qc
from pycisTopic.utils import fig2img
import matplotlib.pyplot as plt

# %%
topic_qc_metrics_dict = {}
for key in cistopic_obj_dict.keys():
    print(key)
    topic_qc_metrics = compute_topic_metrics(
        cistopic_obj_dict[key]
    )

    fig_dict={}
    fig_dict['CoherenceVSAssignments']=plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Log10_Assignments', var_color='Gini_index', plot=False, return_fig=True)
    fig_dict['AssignmentsVSCells_in_bin']=plot_topic_qc(topic_qc_metrics, var_x='Log10_Assignments', var_y='Cells_in_binarized_topic', var_color='Gini_index', plot=False, return_fig=True)
    fig_dict['CoherenceVSCells_in_bin']=plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Cells_in_binarized_topic', var_color='Gini_index', plot=False, return_fig=True)
    fig_dict['CoherenceVSRegions_in_bin']=plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Regions_in_binarized_topic', var_color='Gini_index', plot=False, return_fig=True)
    fig_dict['CoherenceVSMarginal_dist']=plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Marginal_topic_dist', var_color='Gini_index', plot=False, return_fig=True)
    fig_dict['CoherenceVSGini_index']=plot_topic_qc(topic_qc_metrics, var_x='Coherence', var_y='Gini_index', var_color='Gini_index', plot=False, return_fig=True)

    fig=plt.figure(figsize=(40, 43))
    i = 1
    for fig_ in fig_dict.keys():
        plt.subplot(2, 3, i)
        img = fig2img(fig_dict[fig_]) #To convert figures to png to plot together, see .utils.py. This converts the figure to png.
        plt.imshow(img)
        plt.axis('off')
        i += 1
    plt.subplots_adjust(wspace=0, hspace=-0.70)
    #plt.tight_layout()
    plt.show()
    
    topic_qc_metrics_dict[key] = topic_qc_metrics.copy()
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# ### Annotate topics

# %%
from pycisTopic.topic_qc import topic_annotation

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    topic_annot = topic_annotation(
        cistopic_obj_dict[key],
        annot_var='consensus_cell_type',
        binarized_cell_topic=binarized_cell_topic_dict[key],
        general_topic_thr = 0.2
    )
    topic_qc_metrics_dict[key] = pd.concat(
        [ 
            topic_annot[['consensus_cell_type', 'Ratio_cells_in_topic', 'Ratio_group_in_population']],
            topic_qc_metrics_dict[key]
        ],
        axis=1
    )
# Out:
# VIB_Hydrop_1
# VIB_Hydrop_2

# %% [markdown]
# # imputed acc

# %% [markdown]
# ## Differentially Accessible Regions (DARs)

# %%
from pycisTopic.diff_features import (
    impute_accessibility,
    normalize_scores,
    find_highly_variable_features,
    find_diff_features
)
from pycisTopic.clust_vis import plot_imputed_features
import numpy as np
import copy

# %%
imputed_acc_obj_dict = {}
markers_dict_dict = {}

for key in cistopic_obj_dict.keys():
    print(key)
    imputed_acc_obj = impute_accessibility(
        cistopic_obj_dict[key],
        selected_cells=None,
        selected_regions=None,
        scale_factor=10**6
    )
    normalized_imputed_acc_obj = normalize_scores(
        imputed_acc_obj,
        scale_factor=10**4
    )
    variable_regions = find_highly_variable_features(
        normalized_imputed_acc_obj,
        min_disp = 0.05,
        min_mean = 0.0125, 
        max_mean = 3,
        max_disp = np.inf,
        n_bins=20, 
        n_top_features=None,
        plot=True,
    )
    print(f"Found {len(variable_regions)} variable regions")
    markers_dict= find_diff_features(
        cistopic_obj_dict[key],
        imputed_acc_obj,
        variable='consensus_cell_type',
        var_features=variable_regions,
        contrasts=None,
        adjpval_thr=0.05,
        log2fc_thr=np.log2(1.5),
        n_cpu=5,
    )
    imputed_acc_obj_dict[key] = copy.copy(imputed_acc_obj)
    markers_dict_dict[key] = markers_dict.copy()
# Out:
# VIB_Hydrop_1
# 2021-10-22 13:02:12,805 cisTopic     INFO     Imputing drop-outs
# 2021-10-22 13:02:15,983 cisTopic     INFO     Removing small values
# 2021-10-22 13:02:16,655 cisTopic     INFO     Converting to sparse matrix
# 2021-10-22 13:02:22,707 cisTopic     INFO     Scaling
# 2021-10-22 13:02:22,927 cisTopic     INFO     Keep non zero rows
# 2021-10-22 13:02:23,563 cisTopic     INFO     Create CistopicImputedFeatures object
# 2021-10-22 13:02:23,564 cisTopic     INFO     Done!
# 2021-10-22 13:02:23,565 cisTopic     INFO     Normalizing imputed data
# 2021-10-22 13:02:27,223 cisTopic     INFO     Done!
# 2021-10-22 13:02:27,223 cisTopic     INFO     Calculating mean and variance
# 2021-10-22 13:02:37,989 cisTopic     INFO     Done!
# Found 41766 variable regions
# 2021-10-22 13:02:40,677	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=31230) 2021-10-22 13:02:43,504 cisTopic     INFO     Computing p-value for CD4+ T cell
# (pid=31232) 2021-10-22 13:02:43,529 cisTopic     INFO     Computing p-value for B cell
# (pid=31229) 2021-10-22 13:02:43,527 cisTopic     INFO     Computing p-value for CD14+ monocyte
# (pid=31233) 2021-10-22 13:02:43,478 cisTopic     INFO     Computing p-value for Cytotoxic T cell
# (pid=31230) 2021-10-22 13:03:24,560 cisTopic     INFO     Computing log2FC for CD4+ T cell
# (pid=31229) 2021-10-22 13:03:25,015 cisTopic     INFO     Computing log2FC for CD14+ monocyte
# (pid=31233) 2021-10-22 13:03:25,165 cisTopic     INFO     Computing log2FC for Cytotoxic T cell
# (pid=31232) 2021-10-22 13:03:25,491 cisTopic     INFO     Computing log2FC for B cell
# (pid=31230) 2021-10-22 13:03:54,314 cisTopic     INFO     CD4+ T cell done!
# (pid=31233) 2021-10-22 13:03:55,129 cisTopic     INFO     Cytotoxic T cell done!
# (pid=31229) 2021-10-22 13:03:55,606 cisTopic     INFO     CD14+ monocyte done!
# VIB_Hydrop_2
# 2021-10-22 13:03:57,423 cisTopic     INFO     Imputing drop-outs
# 2021-10-22 13:04:01,094 cisTopic     INFO     Removing small values
# 2021-10-22 13:04:01,923 cisTopic     INFO     Converting to sparse matrix
# 2021-10-22 13:04:09,486 cisTopic     INFO     Scaling
# 2021-10-22 13:04:09,752 cisTopic     INFO     Keep non zero rows
# 2021-10-22 13:04:10,505 cisTopic     INFO     Create CistopicImputedFeatures object
# 2021-10-22 13:04:10,506 cisTopic     INFO     Done!
# 2021-10-22 13:04:10,507 cisTopic     INFO     Normalizing imputed data
# 2021-10-22 13:04:15,560 cisTopic     INFO     Done!
# 2021-10-22 13:04:15,566 cisTopic     INFO     Calculating mean and variance
# 2021-10-22 13:04:29,595 cisTopic     INFO     Done!
# Found 44161 variable regions
# 2021-10-22 13:04:32,021	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=32440) 2021-10-22 13:04:34,704 cisTopic     INFO     Computing p-value for B cell
# (pid=32443) 2021-10-22 13:04:34,746 cisTopic     INFO     Computing p-value for CD4+ T cell
# (pid=32442) 2021-10-22 13:04:34,766 cisTopic     INFO     Computing p-value for CD14+ monocyte
# (pid=32441) 2021-10-22 13:04:34,766 cisTopic     INFO     Computing p-value for Cytotoxic T cell
# (pid=32443) 2021-10-22 13:05:21,690 cisTopic     INFO     Computing log2FC for CD4+ T cell
# (pid=32442) 2021-10-22 13:05:21,906 cisTopic     INFO     Computing log2FC for CD14+ monocyte
# (pid=32440) 2021-10-22 13:05:22,196 cisTopic     INFO     Computing log2FC for B cell
# (pid=32441) 2021-10-22 13:05:22,267 cisTopic     INFO     Computing log2FC for Cytotoxic T cell
# (pid=32443) 2021-10-22 13:05:55,688 cisTopic     INFO     CD4+ T cell done!
# (pid=32442) 2021-10-22 13:05:56,274 cisTopic     INFO     CD14+ monocyte done!
# (pid=32440) 2021-10-22 13:05:56,459 cisTopic     INFO     B cell done!
# (pid=32441) 2021-10-22 13:05:56,953 cisTopic     INFO     Cytotoxic T cell done!

# %% [raw]
# markers_dict_dict

# %% [markdown]
# # fderop: write dars to bed

# %%
markers_dict_dict.keys()
# Out:
# dict_keys(['VIB_Hydrop_1', 'VIB_Hydrop_2'])

# %%
markers_dict_dict['VIB_Hydrop_1'].keys()
# Out:
# dict_keys(['B cell', 'CD14+ monocyte', 'CD4+ T cell', 'Cytotoxic T cell'])

# %%
for x in markers_dict_dict['VIB_Hydrop_1'].keys():
    markers = markers_dict_dict['VIB_Hydrop_1'][x].index.tolist()
    df = pd.DataFrame(markers)
    df[[0,1]] = df[0].str.split(':',expand=True)
    df[[1,2]] = df[1].str.split('-',expand=True)
    df[3] = markers_dict_dict['VIB_Hydrop_1'][x].index.tolist()
    df[3] = x + '_' + df[3].astype(str)
    score = markers_dict_dict['VIB_Hydrop_1'][x]['Log2FC']
    score = score.reset_index(drop=True)
    df[4] = score
    # name = x.replace(' ', '_')
    name = x
    print(name)
# Out:
# B cell
# CD14+ monocyte
# CD4+ T cell
# Cytotoxic T cell

# %%
markers_dict_dict[key][x]
# Out:
#                              Log2FC Adjusted_pval          Contrast
# chr1:15405362-15405862     5.075711           0.0  Cytotoxic T cell
# chr1:91116668-91117168     5.075711           0.0  Cytotoxic T cell
# chr1:157700702-157701202   5.075711           0.0  Cytotoxic T cell
# chr1:168391990-168392490   5.075711           0.0  Cytotoxic T cell
# chr2:47155543-47156043     5.075711           0.0  Cytotoxic T cell
# ...                             ...           ...               ...
# chr1:15847357-15847857     0.585161           0.0  Cytotoxic T cell
# chr2:70087149-70087649     0.585126           0.0  Cytotoxic T cell
# chr15:40367969-40368469    0.585108           0.0  Cytotoxic T cell
# chr6:38702956-38703456      0.58509           0.0  Cytotoxic T cell
# chr12:122974953-122975453  0.585028           0.0  Cytotoxic T cell
#
# [6879 rows x 3 columns]

# %%
markers_dict_dict[key][x]
# Out:
#                              Log2FC Adjusted_pval          Contrast
# chr1:15405362-15405862     5.075711           0.0  Cytotoxic T cell
# chr1:91116668-91117168     5.075711           0.0  Cytotoxic T cell
# chr1:157700702-157701202   5.075711           0.0  Cytotoxic T cell
# chr1:168391990-168392490   5.075711           0.0  Cytotoxic T cell
# chr2:47155543-47156043     5.075711           0.0  Cytotoxic T cell
# ...                             ...           ...               ...
# chr1:15847357-15847857     0.585161           0.0  Cytotoxic T cell
# chr2:70087149-70087649     0.585126           0.0  Cytotoxic T cell
# chr15:40367969-40368469    0.585108           0.0  Cytotoxic T cell
# chr6:38702956-38703456      0.58509           0.0  Cytotoxic T cell
# chr12:122974953-122975453  0.585028           0.0  Cytotoxic T cell
#
# [6879 rows x 3 columns]

# %%
markers_dict_dict[key][x]['Adjusted_pval']
# Out:
# chr1:15405362-15405862       0.0
# chr1:91116668-91117168       0.0
# chr1:157700702-157701202     0.0
# chr1:168391990-168392490     0.0
# chr2:47155543-47156043       0.0
#                             ...
# chr1:15847357-15847857       0.0
# chr2:70087149-70087649       0.0
# chr15:40367969-40368469      0.0
# chr6:38702956-38703456       0.0
# chr12:122974953-122975453    0.0
# Name: Adjusted_pval, Length: 6879, dtype: object

# %%
df
# Out:
#           0          1          2                 3         4    5
# 0      chr1   15405362   15405862  Cytotoxic T cell  5.075711  NaN
# 1      chr1   91116668   91117168  Cytotoxic T cell  5.075711  NaN
# 2      chr1  157700702  157701202  Cytotoxic T cell  5.075711  NaN
# 3      chr1  168391990  168392490  Cytotoxic T cell  5.075711  NaN
# 4      chr2   47155543   47156043  Cytotoxic T cell  5.075711  NaN
# ...     ...        ...        ...               ...       ...  ...
# 6874   chr1   15847357   15847857  Cytotoxic T cell  0.585161  NaN
# 6875   chr2   70087149   70087649  Cytotoxic T cell  0.585126  NaN
# 6876  chr15   40367969   40368469  Cytotoxic T cell  0.585108  NaN
# 6877   chr6   38702956   38703456  Cytotoxic T cell   0.58509  NaN
# 6878  chr12  122974953  122975453  Cytotoxic T cell  0.585028  NaN
#
# [6879 rows x 6 columns]

# %%
for key in markers_dict_dict.keys():
    for x in markers_dict_dict[key].keys():
        markers = markers_dict_dict[key][x].index.tolist()
        df = pd.DataFrame(markers)
        df[[0,1]] = df[0].str.split(':',expand=True)
        df[[1,2]] = df[1].str.split('-',expand=True)
        df[3] = markers_dict_dict[key][x].index.tolist()
        df[3] = x.replace(' ', '_')# + '_' + df[3].astype(str)
        score = markers_dict_dict[key][x]['Log2FC']
        score = score.reset_index(drop=True)
        df[4] = score
        df[5] = '.'
        pval = markers_dict_dict[key][x]['Adjusted_pval']
        pval = pval.reset_index(drop=True)
        df[6] = pval
        name = x.replace(' ', '_')
        # name = name.replace('/', '-')
        df.to_csv('downstream_analysis/DARs/libds__'+key + '__'+name.replace(' ', '_')+'__DARs.bed', sep='\t', header=False, index=False)
        df[0:2000].to_csv('downstream_analysis/DARs/libds__'+key + '__'+name.replace(' ', '_')+'__DARs.TOP2K.bed', sep='\t', header=False, index=False)

# %% [markdown]
# # visualise dars

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    [ print(x + ': '+ str(len(markers_dict_dict[key][x]))) for x in markers_dict_dict[key].keys() ]
    plot_imputed_features(
        cistopic_obj_dict[key],
        reduction_name='UMAP',
        imputed_data=imputed_acc_obj_dict[key],
        features=[markers_dict_dict[key][x].index.tolist()[0] for x in markers_dict_dict[key].keys()],
        #['B cell', 'CD14+ monocyte', 'CD4+ T cell', 'Cytotoxic T cell', 'Natural killer cell']
        scale=False,
        num_columns=3,
        selected_cells = cistopic_obj_dict[key].projections['cell']['UMAP'].index.tolist(),
    )
# Out:
# VIB_Hydrop_1
# B cell: 5739
# CD14+ monocyte: 28004
# CD4+ T cell: 8159
# Cytotoxic T cell: 5056
# VIB_Hydrop_2
# B cell: 6330
# CD14+ monocyte: 28716
# CD4+ T cell: 6855
# Cytotoxic T cell: 6879

# %% [markdown]
# #### Save/load

# %%
f_out = os.path.join(f_final_dir, 'region_bin_topics.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        region_bin_topics_dict = pickle.load(f)
else:
    with open(f_out, 'wb') as f:
        pickle.dump(region_bin_topics_dict, f)
# Out:
# Loading /lustre1/project/stg_00002/lcb/fderop/data/20211013_hca_benchmark_libds/downstream_analysis/region_bin_topics.pkl

# %%
f_out = os.path.join(f_final_dir, 'binarized_cell_topic.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        binarized_cell_topic_dict = pickle.load(f)
else:
    with open(f_out, 'wb') as f:
        pickle.dump(binarized_cell_topic_dict, f)
# Out:
# Loading /lustre1/project/stg_00002/lcb/fderop/data/20211013_hca_benchmark_libds/downstream_analysis/binarized_cell_topic.pkl

# %%
f_out = os.path.join(f_final_dir, 'imputed_acc_obj.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        imputed_acc_obj_dict = pickle.load(f)
else:
    with open(f_out, 'wb') as f:
        pickle.dump(imputed_acc_obj_dict, f)
# Out:
# Loading /lustre1/project/stg_00002/lcb/fderop/data/20211013_hca_benchmark_libds/downstream_analysis/imputed_acc_obj.pkl

# %%
f_out = os.path.join(f_final_dir, 'markers_dict.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        markers_dict_dict = pickle.load(f)
else:
    with open(f_out, 'wb') as f:
        pickle.dump(markers_dict_dict, f)
# Out:
# Loading /lustre1/project/stg_00002/lcb/fderop/data/20211013_hca_benchmark_libds/downstream_analysis/markers_dict.pkl

# %% [markdown]
# ## Gene activity

# %%
import pyranges as pr
import requests
import pybiomart as pbm

# %% [markdown]
# ### Get gene annotations and chromosome sizes

# %%
# For human
dataset = pbm.Dataset(name='hsapiens_gene_ensembl',  host='http://www.ensembl.org')
annot = dataset.query(attributes=['chromosome_name', 'start_position', 'end_position', 'strand', 'external_gene_name', 'transcription_start_site', 'transcript_biotype'])
annot['Chromosome/scaffold name'] = 'chr' + annot['Chromosome/scaffold name'].astype(str)
annot.columns=['Chromosome', 'Start', 'End', 'Strand', 'Gene','Transcription_Start_Site', 'Transcript_type']
annot = annot[annot.Transcript_type == 'protein_coding']
annot.Strand[annot.Strand == 1] = '+'
annot.Strand[annot.Strand == -1] = '-'
pr_annotation = pr.PyRanges(annot.dropna(axis = 0))
pr_annotation
# Out:
# +--------------+-----------+-----------+--------------+------------+-------+
# | Chromosome   | Start     | End       | Strand       | Gene       | +2    |
# | (category)   | (int32)   | (int32)   | (category)   | (object)   | ...   |
# |--------------+-----------+-----------+--------------+------------+-------|
# | chr1         | 1471765   | 1497848   | +            | ATAD3B     | ...   |
# | chr1         | 1471765   | 1497848   | +            | ATAD3B     | ...   |
# | chr1         | 6624866   | 6635586   | +            | THAP3      | ...   |
# | chr1         | 6624866   | 6635586   | +            | THAP3      | ...   |
# | ...          | ...       | ...       | ...          | ...        | ...   |
# | chrY         | 13234577  | 13480673  | -            | UTY        | ...   |
# | chrY         | 13234577  | 13480673  | -            | UTY        | ...   |
# | chrY         | 13234577  | 13480673  | -            | UTY        | ...   |
# | chrY         | 13985772  | 13986473  | -            | VCY        | ...   |
# +--------------+-----------+-----------+--------------+------------+-------+
# Stranded PyRanges object has 84,421 rows and 7 columns from 331 chromosomes.
# For printing, the PyRanges was sorted on Chromosome and Strand.
# 2 hidden columns: Transcription_Start_Site, Transcript_type

# %%
# get chromosome sizes (hg38)
target_url = 'http://hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/hg38.chrom.sizes'
chromsizes = pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns = ['Chromosome', 'End']
chromsizes['Start'] = [0]*chromsizes.shape[0]
chromsizes = chromsizes.loc[:,['Chromosome', 'Start', 'End']]
chromsizes = pr.PyRanges(chromsizes)
chromsizes
# Out:
# +------------------------+-----------+-----------+
# | Chromosome             | Start     | End       |
# | (category)             | (int32)   | (int32)   |
# |------------------------+-----------+-----------|
# | chr1                   | 0         | 248956422 |
# | chr1_GL383518v1_alt    | 0         | 182439    |
# | chr1_GL383519v1_alt    | 0         | 110268    |
# | chr1_GL383520v2_alt    | 0         | 366580    |
# | ...                    | ...       | ...       |
# | chrX_KI270881v1_alt    | 0         | 144206    |
# | chrX_KI270913v1_alt    | 0         | 274009    |
# | chrY                   | 0         | 57227415  |
# | chrY_KI270740v1_random | 0         | 37240     |
# +------------------------+-----------+-----------+
# Unstranded PyRanges object has 455 rows and 3 columns from 455 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %% [markdown]
# ### Infer gene activity

# %%
from pycisTopic.gene_activity import get_gene_activity
from pycisTopic.diff_features import find_diff_features

# %%
gene_act_dict = {}

for key in cistopic_obj_dict.keys():
    print(key)
    gene_act, weights = get_gene_activity(
        imputed_acc_obj_dict[key], # Region-cell probabilities
        pr_annotation, # Gene annotation
        chromsizes, # Chromosome size
        use_gene_boundaries=True, # Whether to use the whole search space or stop when encountering another gene
        upstream=[1000, 100000], # Search space upstream. The minimum means that even if there is a gene right next to it 
                                 #these bp will be taken (1kbp here)
        downstream=[1000,100000], # Search space downstream
        distance_weight=True, # Whether to add a distance weight (an exponential function, the weight will decrease with distance)
        decay_rate=1, # Exponent for the distance exponential funciton (the higher the faster will be the decrease)
        extend_gene_body_upstream=10000, # Number of bp upstream immune to the distance weight (their value will be maximum for 
                                         #this weight)
        extend_gene_body_downstream=500, # Number of bp downstream immune to the distance weight
        gene_size_weight=False, # Whether to add a weights based on the length of the gene
        gene_size_scale_factor='median', # Dividend to calculate the gene size weigth. Default is the median value of all genes
                                         #in the genome
        remove_promoters=False, # Whether to remove promoters when computing gene activity scores
        average_scores=True, # Whether to divide by the total number of region assigned to a gene when calculating the gene 
                             # activity score
        scale_factor=1, # Value to multiply for the final gene activity matrix
        extend_tss=[10,10], # Space to consider a promoter
        gini_weight = True, # Whether to add a gini index weigth. The more unique the region is, the higher this weight will be
        return_weights= True, # Whether to return the final weights
        project='Gene_activity') # Project name for the gene activity object
    gene_act_dict[key] = copy.copy(gene_act)
# Out:
# VIB_Hydrop_1
# 2021-10-22 15:17:54,586 cisTopic     INFO     Calculating gene boundaries
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.
# 2021-10-22 15:18:05,218 cisTopic     INFO     Calculating distances
# 2021-10-22 15:18:22,582 cisTopic     INFO     Calculating distance weigths
# 2021-10-22 15:18:23,261 cisTopic     INFO     Distance weights done
# 2021-10-22 15:18:23,263 cisTopic     INFO     Calculating gini weights
# 2021-10-22 15:18:44,685 cisTopic     INFO     Getting gene activity scores
# 2021-10-22 15:21:03,654 cisTopic     INFO     Creating imputed features object
# VIB_Hydrop_2
# 2021-10-22 15:21:10,291 cisTopic     INFO     Calculating gene boundaries
# join: Strand data from other will be added as strand data to self.
# If this is undesired use the flag apply_strand_suffix=False.
# To turn off the warning set apply_strand_suffix to True or False.
# 2021-10-22 15:21:21,083 cisTopic     INFO     Calculating distances
# 2021-10-22 15:21:40,207 cisTopic     INFO     Calculating distance weigths
# 2021-10-22 15:21:41,111 cisTopic     INFO     Distance weights done
# 2021-10-22 15:21:41,112 cisTopic     INFO     Calculating gini weights
# 2021-10-22 15:22:08,393 cisTopic     INFO     Getting gene activity scores
# 2021-10-22 15:24:43,042 cisTopic     INFO     Creating imputed features object

# %% [markdown]
# ### Infer the Differentially Accessible Genes (DAGs)

# %%
from pycisTopic.clust_vis import plot_imputed_features

# %%
dag_markers_dict = {}
for key in cistopic_obj_dict.keys():
    print(key)
    dag_markers_dict[key] = find_diff_features(cistopic_obj_dict[key],
                      gene_act_dict[key],
                      variable='consensus_cell_type',
                      var_features=None,
                      contrasts=None,
                      adjpval_thr=0.05,
                      log2fc_thr=np.log2(1.5),
                      n_cpu=5,
                      )
# Out:
# VIB_Hydrop_1
# 2021-10-22 15:24:45,771	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=4951) 2021-10-22 15:24:48,641 cisTopic     INFO     Computing p-value for CD4+ T cell
# (pid=4948) 2021-10-22 15:24:48,743 cisTopic     INFO     Computing p-value for Cytotoxic T cell
# (pid=4950) 2021-10-22 15:24:48,694 cisTopic     INFO     Computing p-value for B cell
# (pid=4949) 2021-10-22 15:24:48,695 cisTopic     INFO     Computing p-value for CD14+ monocyte
# (pid=4951) 2021-10-22 15:24:56,453 cisTopic     INFO     Computing log2FC for CD4+ T cell
# (pid=4950) 2021-10-22 15:24:56,517 cisTopic     INFO     Computing log2FC for B cell
# (pid=4949) 2021-10-22 15:24:56,581 cisTopic     INFO     Computing log2FC for CD14+ monocyte
# (pid=4948) 2021-10-22 15:24:56,617 cisTopic     INFO     Computing log2FC for Cytotoxic T cell
# (pid=4951) 2021-10-22 15:24:59,395 cisTopic     INFO     CD4+ T cell done!
# (pid=4950) 2021-10-22 15:24:59,473 cisTopic     INFO     B cell done!
# (pid=4948) 2021-10-22 15:24:59,608 cisTopic     INFO     Cytotoxic T cell done!
# (pid=4949) 2021-10-22 15:24:59,736 cisTopic     INFO     CD14+ monocyte done!
# VIB_Hydrop_2
# 2021-10-22 15:25:02,963	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=5415) 2021-10-22 15:25:05,858 cisTopic     INFO     Computing p-value for CD14+ monocyte
# (pid=5416) 2021-10-22 15:25:05,825 cisTopic     INFO     Computing p-value for CD4+ T cell
# (pid=5413) 2021-10-22 15:25:05,914 cisTopic     INFO     Computing p-value for Cytotoxic T cell
# (pid=5414) 2021-10-22 15:25:05,900 cisTopic     INFO     Computing p-value for B cell
# (pid=5415) 2021-10-22 15:25:14,640 cisTopic     INFO     Computing log2FC for CD14+ monocyte
# (pid=5416) 2021-10-22 15:25:14,644 cisTopic     INFO     Computing log2FC for CD4+ T cell
# (pid=5413) 2021-10-22 15:25:14,624 cisTopic     INFO     Computing log2FC for Cytotoxic T cell
# (pid=5414) 2021-10-22 15:25:14,650 cisTopic     INFO     Computing log2FC for B cell
# (pid=5413) 2021-10-22 15:25:18,018 cisTopic     INFO     Cytotoxic T cell done!
# (pid=5416) 2021-10-22 15:25:18,211 cisTopic     INFO     CD4+ T cell done!
# (pid=5414) 2021-10-22 15:25:18,192 cisTopic     INFO     B cell done!

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    plot_imputed_features(cistopic_obj_dict[key],
                    reduction_name='UMAP',
                    imputed_data=gene_act,
                    features=['CD34', 'THY1', # CD34+
                              'NCAM1', 'FCGR3A', # NK
                              'CD14', 'CD68', # Monocytes
                              'MS4A1', 'CD79A', # B cells
                              'CD8A', 'CD8B', # Cytotoxic CD8 cells
                              'CD4', # CD4 T
                              'CD3D', # T
                              'IL3RA', 'CD1C', 'BATF3', # Dendritic
                             ],
                    scale=True,
                    num_columns=5,
                    )
# Out:
# VIB_Hydrop_1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/venv/lib/python3.8/site-packages/pycisTopic/diff_features.py in subset(self, cells, features, copy)
#      78             try:
# ---> 79                 cells_index = get_position_index(cells, self.cell_names)
#      80             except BaseException:
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/utils.py in get_position_index(query_list, target_list)
#      29     index = (d[k] for k in query_list)
# ---> 30     return list(index)
#      31
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/utils.py in <genexpr>(.0)
#      28     d = {k: v for v, k in enumerate(target_list)}
# ---> 29     index = (d[k] for k in query_list)
#      30     return list(index)
#
# KeyError: 'CTCCTCACTACTTGGAATTC-12-VIB_Hydrop_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /opt/venv/lib/python3.8/site-packages/pycisTopic/diff_features.py in subset(self, cells, features, copy)
#      81                 try:
# ---> 82                     cells_index = get_position_index(
#      83                         cells, prepare_tag_cells(self.cell_names))
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/utils.py in get_position_index(query_list, target_list)
#      29     index = (d[k] for k in query_list)
# ---> 30     return list(index)
#      31
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/utils.py in <genexpr>(.0)
#      28     d = {k: v for v, k in enumerate(target_list)}
# ---> 29     index = (d[k] for k in query_list)
#      30     return list(index)
#
# KeyError: 'CTCCTCACTACTTGGAATTC-12-VIB_Hydrop_1'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /local_scratch/tmp-vsc33042/ipykernel_22290/1707539123.py in <module>
#       1 for key in cistopic_obj_dict.keys():
#       2     print(key)
# ----> 3     plot_imputed_features(cistopic_obj_dict[key],
#       4                     reduction_name='UMAP',
#       5                     imputed_data=gene_act,
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/clust_vis.py in plot_imputed_features(cistopic_obj, reduction_name, imputed_data, features, scale, cmap, dot_size, alpha, selected_cells, figsize, num_columns, save)
#     741         if selected_cells is not None:
#     742             embedding = embedding.loc[selected_cells]
# --> 743         feature_data = imputed_data.subset(cells=embedding.index.tolist(), features=[feature], copy=True).mtx
#     744         if scale:
#     745             try:
#
# /opt/venv/lib/python3.8/site-packages/pycisTopic/diff_features.py in subset(self, cells, features, copy)
#      83                         cells, prepare_tag_cells(self.cell_names))
#      84                 except BaseException:
# ---> 85                     log.error(
#      86                         'None of the given cells is contained in this cisTopic object!')
#      87             mtx = mtx[:, cells_index]
#
# NameError: name 'log' is not defined

# %% [markdown]
# ## Export to loom

# %%
# cistopic_obj_dict # ok
# imputed_acc_obj_dict # ok
# region_bin_topics #(region_bin_topics_dict) ok
# binarized_cell_topic # ok
# DARs_dict #(markers_dict_dict) ok

# %%
f_region_loom_dir = os.path.join(f_final_dir, 'region_acc_loom')
if not os.path.exists(f_region_loom_dir):
    os.makedirs(f_region_loom_dir)
    
f_gene_loom_dir = os.path.join(f_final_dir, 'gene_act_loom')
if not os.path.exists(f_gene_loom_dir):
    os.makedirs(f_gene_loom_dir)

# %% [markdown]
# ### Region accessibility

# %%
from pycisTopic.loom import (
    export_region_accessibility_to_loom,
    export_gene_activity_to_loom
)

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    s = 'merged' if key=='merged' else sample_annot.loc[key,'Sample']
    f_out = os.path.join(f_region_loom_dir, s + '__libDS_region_accessibility.loom')
    if os.path.exists(f_out):
        print(f"Skipping {f_out}: already exists.")
        continue
    # Subset regions, we will use only regions in topics and DARs here to make it faster
    regions_in_topics = list(set(sum([region_bin_topics_dict[key][i].index.tolist() for i in region_bin_topics_dict[key].keys()],[])))
    regions_in_DARs = list(set(sum([markers_dict_dict[key][i].index.tolist() for i in markers_dict_dict[key].keys()],[])))
    # make sure we only take regions that actually exist in the accessibility matrix:
    selected_regions = list(set(regions_in_topics + regions_in_DARs).intersection(set(imputed_acc_obj_dict[key].feature_names)))

    # Export to loom
    export_region_accessibility_to_loom(
        accessibility_matrix = imputed_acc_obj_dict[key],
        cistopic_obj = cistopic_obj_dict[key], 
        binarized_topic_region = region_bin_topics_dict[key],
        binarized_cell_topic = binarized_cell_topic_dict[key],
        out_fname = f_out,
        selected_regions = selected_regions ,
        selected_cells = [ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ], # this leaves a cell barcode of the format type 'TGCATGTCGCCGTTCCAAGA-21'
        # selected_cells = cistopic_obj_dict[key].projections['cell']['UMAP'].index.tolist(), # cflerin original
        cluster_annotation = ['consensus_cell_type'],
        cluster_markers = {'consensus_cell_type': markers_dict_dict[key]},
        tree_structure = ('scATAC-seq_Benchmark', 'ATAC_library_downsampled', 'Region_accessibility'),
        title = s + ' - Region accessibility all',
        nomenclature = "hg38"
    )
# Out:
# VIB_Hydrop_1
# 2021-10-22 15:52:00,868 cisTopic     INFO     Creating minimal loom
# Regulon name does not seem to be compatible with SCOPE. It should include a space to allow selection of the TF.
# Please run:
#  regulons = [r.rename(r.name.replace('(+)',' ('+str(len(r))+'g)')) for r in regulons]
# or:
#  regulons = [r.rename(r.name.replace('(',' (')) for r in regulons]
# 2021-10-22 16:02:59,451 cisTopic     INFO     Adding annotations
# 2021-10-22 16:03:06,553 cisTopic     INFO     Adding clusterings
# 2021-10-22 16:03:06,569 cisTopic     INFO     Adding markers
# 2021-10-22 16:03:07,387 cisTopic     INFO     Exporting
# VIB_Hydrop_2
# 2021-10-22 16:03:50,315 cisTopic     INFO     Creating minimal loom
# Regulon name does not seem to be compatible with SCOPE. It should include a space to allow selection of the TF.
# Please run:
#  regulons = [r.rename(r.name.replace('(+)',' ('+str(len(r))+'g)')) for r in regulons]
# or:
#  regulons = [r.rename(r.name.replace('(',' (')) for r in regulons]
# 2021-10-22 16:10:53,491 cisTopic     INFO     Adding annotations
# 2021-10-22 16:11:01,120 cisTopic     INFO     Adding clusterings
# 2021-10-22 16:11:01,137 cisTopic     INFO     Adding markers
# 2021-10-22 16:11:01,933 cisTopic     INFO     Exporting

# %%
len([ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ])
# Out:
# 2531

# %% [markdown]
# ### Gene activity

# %%
from ctxcore.genesig import Regulon

# generate a dummy regulon (required for export_gene_activity_to_loom):
phreg = Regulon(
        name='placeholder regulon',
        gene2weight={'phreg': 1.0},
        transcription_factor="phreg",
        gene2occurrence={"phreg": 1},
    )

# %%
for key in cistopic_obj_dict.keys():
    print(key)
    s = 'merged' if key=='merged' else sample_annot.loc[key,'Sample']
    f_out = os.path.join(f_gene_loom_dir, s + '__libDS_gene_activity.loom')
    if os.path.exists(f_out):
        print(f"Skipping {f_out}: already exists.")
        continue
    export_gene_activity_to_loom(
        gene_activity_matrix = gene_act_dict[key],
        cistopic_obj = cistopic_obj_dict[key], 
        regulons = [phreg],
        selected_cells = [ x.split('-')[0] + '-' + x.split('-')[1]  for x in cistopic_obj_dict[key].cell_names ], # this leaves a cell barcode of the format type 'TGCATGTCGCCGTTCCAAGA-21'
        # selected_cells = cistopic_obj_dict[key].projections['cell']['UMAP'].index.tolist(), # cflerin original        out_fname = f_out,
        cluster_annotation = ['consensus_cell_type'],
        cluster_markers = {'consensus_cell_type': markers_dict_dict[key]},
        tree_structure = ('scATAC-seq_Benchmark', 'ATAC_library_downsampled', 'Gene_activity'),
        title = s + ' - Gene activity',
        nomenclature = "hg38"
    )

# %% [markdown]
# ## Signature enrichment
