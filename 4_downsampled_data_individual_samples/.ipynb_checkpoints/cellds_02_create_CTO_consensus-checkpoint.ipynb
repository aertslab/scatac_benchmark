# %% [markdown]
# # pycisTopic analysis
#
# Cell downsampled dataset, using consensus peak regions.

# %%
import pycisTopic
pycisTopic.__version__
# Out:
# '0.1.dev295+gbd4bf4d.d20210830'

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import pickle
import pandas as pd

# %%
import os
wdir = '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/'
os.chdir( wdir )

# %% [markdown]
# ---

# %%
fragments_dict = {
'Broad_1':      '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Broad_1.sinto.fragments.tsv.gz',
'Broad_2':      '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Broad_2.sinto.fragments.tsv.gz',
'Broad_mito_1': '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Broad_mito_1.sinto.fragments.tsv.gz',
'Broad_mito_2': '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Broad_mito_2.sinto.fragments.tsv.gz',
'CNAG_1':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/CNAG_1.sinto.fragments.tsv.gz',
'CNAG_2':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/CNAG_2.sinto.fragments.tsv.gz',
's3atac':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/s3atac.sinto.fragments.tsv.gz',
'Sanger_1':     '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Sanger_1.sinto.fragments.tsv.gz',
'Sanger_2':     '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Sanger_2.sinto.fragments.tsv.gz',
'Stanford_1':   '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Stanford_1.sinto.fragments.tsv.gz',
'Stanford_2':   '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/Stanford_2.sinto.fragments.tsv.gz',
'VIB_1':        '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/VIB_1.sinto.fragments.tsv.gz',
'VIB_2':        '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/fragments/VIB_2.sinto.fragments.tsv.gz',
}

# %%
consensus_peaks_dict = {
'Broad_1':      '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Broad_1/Broad_1__consensus_regions.bed',
'Broad_2':      '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Broad_2/Broad_2__consensus_regions.bed',
'Broad_mito_1': '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Broad_mito_1/Broad_mito_1__consensus_regions.bed',
'Broad_mito_2': '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Broad_mito_2/Broad_mito_2__consensus_regions.bed',
'CNAG_1':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/CNAG_1/CNAG_1__consensus_regions.bed',
'CNAG_2':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/CNAG_2/CNAG_2__consensus_regions.bed',
'merged':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/merged/merged__consensus_regions.bed',
's3atac':       '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/s3atac/s3atac__consensus_regions.bed',
'Sanger_1':     '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Sanger_1/Sanger_1__consensus_regions.bed',
'Sanger_2':     '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Sanger_2/Sanger_2__consensus_regions.bed',
'Stanford_1':   '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Stanford_1/Stanford_1__consensus_regions.bed',
'Stanford_2':   '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/Stanford_2/Stanford_2__consensus_regions.bed',
'VIB_1':        '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/VIB_1/VIB_1__consensus_regions.bed',
'VIB_2':        '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/consensus_peak_calling/VIB_2/VIB_2__consensus_regions.bed',    
}

# %% [markdown]
# ## Library QC metrics

# %%
from pycisTopic.qc import compute_qc_stats

# %%
f_biomart = '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021/atac_qc_multiplet_merged/jupyter/biomart_annot.pickle'
with open(f_biomart, 'rb') as f:
    annot = pickle.load(f)
annot
# Out:
#        Chromosome     Start  Strand   Gene Transcript_type
# 8986         chrY   9337464       1  TSPY4  protein_coding
# 8987         chrY   9337510       1  TSPY4  protein_coding
# 9024         chrY  22490397       1    PRY  protein_coding
# 9100         chrY  14056227       1  VCY1B  protein_coding
# 9136         chrY  12662368       1  USP9Y  protein_coding
# ...           ...       ...     ...    ...             ...
# 236024       chr1  36479519      -1  CSF3R  protein_coding
# 236025       chr1  36471474      -1  CSF3R  protein_coding
# 236033       chr1  36482051      -1  CSF3R  protein_coding
# 236034       chr1  36323645      -1  EVA1B  protein_coding
# 236035       chr1  36324154      -1  EVA1B  protein_coding
#
# [77249 rows x 5 columns]

# %%
metadata_bc_dict, profile_data_dict = compute_qc_stats(
        fragments_dict=fragments_dict,
        tss_annotation=annot,
        stats=['barcode_rank_plot', 'duplicate_rate', 'insert_size_distribution', 'profile_tss', 'frip'],
        label_list=None,
        path_to_regions=consensus_peaks_dict,
        n_cpu=5,
        valid_bc=None,
        n_frag=100,
        n_bc=None,
        tss_flank_window=2000,
        tss_window=50,
        tss_minimum_signal_window=100,
        tss_rolling_window=10,
        min_norm=0.1,
        remove_duplicates = True,
        )
# Out:
# 2021-09-14 15:36:54,014	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# (pid=4301) 2021-09-14 15:36:56,933 cisTopic     INFO     Reading Broad_1
# (pid=4298) 2021-09-14 15:36:56,842 cisTopic     INFO     Reading Broad_2
# (pid=4300) 2021-09-14 15:36:56,842 cisTopic     INFO     Reading Broad_mito_1
# (pid=4299) 2021-09-14 15:36:56,932 cisTopic     INFO     Reading CNAG_1
# (pid=4297) 2021-09-14 15:36:56,834 cisTopic     INFO     Reading Broad_mito_2
# (pid=4299) 2021-09-14 15:37:09,620 cisTopic     INFO     Computing barcode rank plot for CNAG_1
# (pid=4299) 2021-09-14 15:37:09,620 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:37:10,188 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4299) 2021-09-14 15:37:10,211 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=4299) 2021-09-14 15:37:10,212 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:37:10,212 cisTopic     INFO     Returning valid barcodes
# (pid=4299) 2021-09-14 15:37:11,047 cisTopic     INFO     Computing duplicate rate plot for CNAG_1
# (pid=4299) 2021-09-14 15:37:11,910 cisTopic     INFO     Return plot data
# (pid=4299) 2021-09-14 15:37:11,993 cisTopic     INFO     Computing insert size distribution for CNAG_1
# (pid=4299) 2021-09-14 15:37:11,993 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:37:12,357 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:37:12,366 cisTopic     INFO     Computing barcode rank plot for Broad_mito_2
# (pid=4297) 2021-09-14 15:37:12,366 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:37:13,056 cisTopic     INFO     Computing barcode rank plot for Broad_mito_1
# (pid=4300) 2021-09-14 15:37:13,056 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:37:13,040 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4297) 2021-09-14 15:37:13,045 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=4297) 2021-09-14 15:37:13,045 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:37:13,046 cisTopic     INFO     Returning valid barcodes
# (pid=4300) 2021-09-14 15:37:13,769 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4300) 2021-09-14 15:37:13,773 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=4300) 2021-09-14 15:37:13,774 cisTopic     INFO     Returning plot data
# (pid=4300) 2021-09-14 15:37:13,774 cisTopic     INFO     Returning valid barcodes
# (pid=4297) 2021-09-14 15:37:14,001 cisTopic     INFO     Computing duplicate rate plot for Broad_mito_2
# (pid=4300) 2021-09-14 15:37:14,795 cisTopic     INFO     Computing duplicate rate plot for Broad_mito_1
# (pid=4297) 2021-09-14 15:37:14,847 cisTopic     INFO     Return plot data
# (pid=4297) 2021-09-14 15:37:14,921 cisTopic     INFO     Computing insert size distribution for Broad_mito_2
# (pid=4297) 2021-09-14 15:37:14,921 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:37:15,344 cisTopic     INFO     Returning plot data
# (pid=4300) 2021-09-14 15:37:15,700 cisTopic     INFO     Return plot data
# (pid=4300) 2021-09-14 15:37:15,781 cisTopic     INFO     Computing insert size distribution for Broad_mito_1
# (pid=4300) 2021-09-14 15:37:15,781 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:37:16,228 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:37:16,790 cisTopic     INFO     Computing TSS profile for CNAG_1
# (pid=4299) 2021-09-14 15:37:17,532 cisTopic     INFO     Formatting annnotation
# (pid=4299) 2021-09-14 15:37:17,618 cisTopic     INFO     Creating coverage matrix
# (pid=4297) 2021-09-14 15:37:20,625 cisTopic     INFO     Computing TSS profile for Broad_mito_2
# (pid=4297) 2021-09-14 15:37:21,478 cisTopic     INFO     Formatting annnotation
# (pid=4297) 2021-09-14 15:37:21,562 cisTopic     INFO     Creating coverage matrix
# (pid=4300) 2021-09-14 15:37:21,774 cisTopic     INFO     Computing TSS profile for Broad_mito_1
# (pid=4300) 2021-09-14 15:37:22,646 cisTopic     INFO     Formatting annnotation
# (pid=4300) 2021-09-14 15:37:22,722 cisTopic     INFO     Creating coverage matrix
# (pid=4298) 2021-09-14 15:37:24,197 cisTopic     INFO     Computing barcode rank plot for Broad_2
# (pid=4298) 2021-09-14 15:37:24,197 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:37:25,048 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4298) 2021-09-14 15:37:25,058 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=4298) 2021-09-14 15:37:25,060 cisTopic     INFO     Returning plot data
# (pid=4298) 2021-09-14 15:37:25,060 cisTopic     INFO     Returning valid barcodes
# (pid=4298) 2021-09-14 15:37:26,354 cisTopic     INFO     Computing duplicate rate plot for Broad_2
# (pid=4301) 2021-09-14 15:37:26,476 cisTopic     INFO     Computing barcode rank plot for Broad_1
# (pid=4301) 2021-09-14 15:37:26,476 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:37:27,353 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4301) 2021-09-14 15:37:27,357 numexpr.utils INFO     Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# (pid=4301) 2021-09-14 15:37:27,358 cisTopic     INFO     Returning plot data
# (pid=4301) 2021-09-14 15:37:27,359 cisTopic     INFO     Returning valid barcodes
# (pid=4298) 2021-09-14 15:37:27,664 cisTopic     INFO     Return plot data
# (pid=4298) 2021-09-14 15:37:27,780 cisTopic     INFO     Computing insert size distribution for Broad_2
# (pid=4298) 2021-09-14 15:37:27,780 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:37:28,401 cisTopic     INFO     Returning plot data
# (pid=4301) 2021-09-14 15:37:28,605 cisTopic     INFO     Computing duplicate rate plot for Broad_1
# (pid=4301) 2021-09-14 15:37:29,922 cisTopic     INFO     Return plot data
# (pid=4301) 2021-09-14 15:37:30,031 cisTopic     INFO     Computing insert size distribution for Broad_1
# (pid=4301) 2021-09-14 15:37:30,031 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:37:30,607 cisTopic     INFO     Returning plot data
# (pid=4298) 2021-09-14 15:37:35,334 cisTopic     INFO     Computing TSS profile for Broad_2
# (pid=4298) 2021-09-14 15:37:36,482 cisTopic     INFO     Formatting annnotation
# (pid=4298) 2021-09-14 15:37:36,565 cisTopic     INFO     Creating coverage matrix
# (pid=4301) 2021-09-14 15:37:37,396 cisTopic     INFO     Computing TSS profile for Broad_1
# (pid=4301) 2021-09-14 15:37:38,624 cisTopic     INFO     Formatting annnotation
# (pid=4301) 2021-09-14 15:37:38,703 cisTopic     INFO     Creating coverage matrix
# (pid=4299) 2021-09-14 15:37:42,756 cisTopic     INFO     Coverage matrix done
# (pid=4299) 2021-09-14 15:37:44,421 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4299) 2021-09-14 15:37:45,755 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4299) 2021-09-14 15:37:45,949 cisTopic     INFO     Computing FRIP profile for CNAG_1
# (pid=4299) 2021-09-14 15:37:46,404 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:37:47,460 cisTopic     INFO     Intersecting fragments with regions
# (pid=4297) 2021-09-14 15:37:49,966 cisTopic     INFO     Coverage matrix done
# (pid=4299) 2021-09-14 15:37:51,856 cisTopic     INFO     Sample CNAG_1 done!
# (pid=4299) 2021-09-14 15:37:51,924 cisTopic     INFO     Reading CNAG_2
# (pid=4297) 2021-09-14 15:37:52,115 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4297) 2021-09-14 15:37:53,671 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4297) 2021-09-14 15:37:53,754 cisTopic     INFO     Computing FRIP profile for Broad_mito_2
# (pid=4300) 2021-09-14 15:37:54,035 cisTopic     INFO     Coverage matrix done
# (pid=4297) 2021-09-14 15:37:54,234 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:37:55,506 cisTopic     INFO     Intersecting fragments with regions
# (pid=4300) 2021-09-14 15:37:56,268 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4300) 2021-09-14 15:37:57,858 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4300) 2021-09-14 15:37:57,952 cisTopic     INFO     Computing FRIP profile for Broad_mito_1
# (pid=4300) 2021-09-14 15:37:58,449 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:37:59,788 cisTopic     INFO     Intersecting fragments with regions
# (pid=4297) 2021-09-14 15:38:00,388 cisTopic     INFO     Sample Broad_mito_2 done!
# (pid=4297) 2021-09-14 15:38:00,446 cisTopic     INFO     Reading s3atac
# (pid=4299) 2021-09-14 15:38:05,134 cisTopic     INFO     Computing barcode rank plot for CNAG_2
# (pid=4299) 2021-09-14 15:38:05,135 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:38:05,180 cisTopic     INFO     Sample Broad_mito_1 done!
# (pid=4300) 2021-09-14 15:38:05,242 cisTopic     INFO     Reading Sanger_1
# (pid=4299) 2021-09-14 15:38:05,714 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4299) 2021-09-14 15:38:05,715 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:38:05,715 cisTopic     INFO     Returning valid barcodes
# (pid=4299) 2021-09-14 15:38:06,587 cisTopic     INFO     Computing duplicate rate plot for CNAG_2
# (pid=4299) 2021-09-14 15:38:07,462 cisTopic     INFO     Return plot data
# (pid=4299) 2021-09-14 15:38:07,539 cisTopic     INFO     Computing insert size distribution for CNAG_2
# (pid=4299) 2021-09-14 15:38:07,539 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:38:07,904 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:38:12,434 cisTopic     INFO     Computing TSS profile for CNAG_2
# (pid=4299) 2021-09-14 15:38:13,119 cisTopic     INFO     Formatting annnotation
# (pid=4299) 2021-09-14 15:38:13,194 cisTopic     INFO     Creating coverage matrix
# (pid=4297) 2021-09-14 15:38:20,645 cisTopic     INFO     Computing barcode rank plot for s3atac
# (pid=4297) 2021-09-14 15:38:20,645 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:38:21,470 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4297) 2021-09-14 15:38:21,471 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:38:21,471 cisTopic     INFO     Returning valid barcodes
# (pid=4297) 2021-09-14 15:38:22,639 cisTopic     INFO     Computing duplicate rate plot for s3atac
# (pid=4297) 2021-09-14 15:38:23,676 cisTopic     INFO     Return plot data
# (pid=4297) 2021-09-14 15:38:23,754 cisTopic     INFO     Computing insert size distribution for s3atac
# (pid=4297) 2021-09-14 15:38:23,754 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:38:24,219 cisTopic     INFO     Returning plot data
# (pid=4298) 2021-09-14 15:38:24,436 cisTopic     INFO     Coverage matrix done
# (pid=4300) 2021-09-14 15:38:25,575 cisTopic     INFO     Computing barcode rank plot for Sanger_1
# (pid=4300) 2021-09-14 15:38:25,576 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:38:26,402 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4300) 2021-09-14 15:38:26,403 cisTopic     INFO     Returning plot data
# (pid=4300) 2021-09-14 15:38:26,403 cisTopic     INFO     Returning valid barcodes
# (pid=4298) 2021-09-14 15:38:27,167 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4300) 2021-09-14 15:38:27,718 cisTopic     INFO     Computing duplicate rate plot for Sanger_1
# (pid=4301) 2021-09-14 15:38:28,062 cisTopic     INFO     Coverage matrix done
# (pid=4300) 2021-09-14 15:38:28,845 cisTopic     INFO     Return plot data
# (pid=4300) 2021-09-14 15:38:28,928 cisTopic     INFO     Computing insert size distribution for Sanger_1
# (pid=4300) 2021-09-14 15:38:28,928 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:38:29,109 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4298) 2021-09-14 15:38:29,192 cisTopic     INFO     Computing FRIP profile for Broad_2
# (pid=4300) 2021-09-14 15:38:29,452 cisTopic     INFO     Returning plot data
# (pid=4298) 2021-09-14 15:38:29,620 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:38:30,533 cisTopic     INFO     Computing TSS profile for s3atac
# (pid=4301) 2021-09-14 15:38:30,740 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4298) 2021-09-14 15:38:31,229 cisTopic     INFO     Intersecting fragments with regions
# (pid=4297) 2021-09-14 15:38:31,510 cisTopic     INFO     Formatting annnotation
# (pid=4297) 2021-09-14 15:38:31,585 cisTopic     INFO     Creating coverage matrix
# (pid=4301) 2021-09-14 15:38:32,700 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4301) 2021-09-14 15:38:32,788 cisTopic     INFO     Computing FRIP profile for Broad_1
# (pid=4301) 2021-09-14 15:38:33,226 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:38:34,918 cisTopic     INFO     Intersecting fragments with regions
# (pid=4300) 2021-09-14 15:38:36,673 cisTopic     INFO     Computing TSS profile for Sanger_1
# (pid=4298) 2021-09-14 15:38:37,661 cisTopic     INFO     Sample Broad_2 done!
# (pid=4298) 2021-09-14 15:38:37,724 cisTopic     INFO     Reading Sanger_2
# (pid=4300) 2021-09-14 15:38:37,735 cisTopic     INFO     Formatting annnotation
# (pid=4300) 2021-09-14 15:38:37,817 cisTopic     INFO     Creating coverage matrix
# (pid=4299) 2021-09-14 15:38:39,252 cisTopic     INFO     Coverage matrix done
# (pid=4299) 2021-09-14 15:38:40,936 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4301) 2021-09-14 15:38:41,643 cisTopic     INFO     Sample Broad_1 done!
# (pid=4301) 2021-09-14 15:38:41,709 cisTopic     INFO     Reading Stanford_1
# (pid=4299) 2021-09-14 15:38:42,087 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4299) 2021-09-14 15:38:42,173 cisTopic     INFO     Computing FRIP profile for CNAG_2
# (pid=4299) 2021-09-14 15:38:42,659 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:38:43,790 cisTopic     INFO     Intersecting fragments with regions
# (pid=4301) 2021-09-14 15:38:47,067 cisTopic     INFO     Computing barcode rank plot for Stanford_1
# (pid=4301) 2021-09-14 15:38:47,067 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:38:47,257 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4301) 2021-09-14 15:38:47,257 cisTopic     INFO     Returning plot data
# (pid=4301) 2021-09-14 15:38:47,257 cisTopic     INFO     Returning valid barcodes
# (pid=4301) 2021-09-14 15:38:47,580 cisTopic     INFO     Computing duplicate rate plot for Stanford_1
# (pid=4301) 2021-09-14 15:38:47,864 cisTopic     INFO     Return plot data
# (pid=4301) 2021-09-14 15:38:47,940 cisTopic     INFO     Computing insert size distribution for Stanford_1
# (pid=4301) 2021-09-14 15:38:47,940 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:38:48,056 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:38:48,304 cisTopic     INFO     Sample CNAG_2 done!
# (pid=4299) 2021-09-14 15:38:48,353 cisTopic     INFO     Reading Stanford_2
# (pid=4297) 2021-09-14 15:38:49,119 cisTopic     INFO     Coverage matrix done
# (pid=4301) 2021-09-14 15:38:49,736 cisTopic     INFO     Computing TSS profile for Stanford_1
# (pid=4301) 2021-09-14 15:38:49,980 cisTopic     INFO     Formatting annnotation
# (pid=4301) 2021-09-14 15:38:50,051 cisTopic     INFO     Creating coverage matrix
# (pid=4297) 2021-09-14 15:38:51,128 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4297) 2021-09-14 15:38:52,593 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4297) 2021-09-14 15:38:52,674 cisTopic     INFO     Computing FRIP profile for s3atac
# (pid=4297) 2021-09-14 15:38:53,035 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:38:54,526 cisTopic     INFO     Intersecting fragments with regions
# (pid=4299) 2021-09-14 15:38:56,267 cisTopic     INFO     Computing barcode rank plot for Stanford_2
# (pid=4299) 2021-09-14 15:38:56,267 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:38:56,556 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4299) 2021-09-14 15:38:56,557 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:38:56,558 cisTopic     INFO     Returning valid barcodes
# (pid=4301) 2021-09-14 15:38:57,082 cisTopic     INFO     Coverage matrix done
# (pid=4299) 2021-09-14 15:38:57,119 cisTopic     INFO     Computing duplicate rate plot for Stanford_2
# (pid=4297) 2021-09-14 15:38:57,092 cisTopic     INFO     Sample s3atac done!
# (pid=4297) 2021-09-14 15:38:57,145 cisTopic     INFO     Reading VIB_1
# (pid=4301) 2021-09-14 15:38:57,598 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4299) 2021-09-14 15:38:57,567 cisTopic     INFO     Return plot data
# (pid=4299) 2021-09-14 15:38:57,643 cisTopic     INFO     Computing insert size distribution for Stanford_2
# (pid=4299) 2021-09-14 15:38:57,643 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:38:57,821 cisTopic     INFO     Returning plot data
# (pid=4301) 2021-09-14 15:38:57,937 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4301) 2021-09-14 15:38:58,013 cisTopic     INFO     Computing FRIP profile for Stanford_1
# (pid=4301) 2021-09-14 15:38:58,341 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:38:58,682 cisTopic     INFO     Intersecting fragments with regions
# (pid=4301) 2021-09-14 15:39:00,099 cisTopic     INFO     Sample Stanford_1 done!
# (pid=4301) 2021-09-14 15:39:00,127 cisTopic     INFO     Reading VIB_2
# (pid=4299) 2021-09-14 15:39:00,597 cisTopic     INFO     Computing TSS profile for Stanford_2
# (pid=4299) 2021-09-14 15:39:00,973 cisTopic     INFO     Formatting annnotation
# (pid=4299) 2021-09-14 15:39:01,048 cisTopic     INFO     Creating coverage matrix
# (pid=4298) 2021-09-14 15:39:02,273 cisTopic     INFO     Computing barcode rank plot for Sanger_2
# (pid=4298) 2021-09-14 15:39:02,274 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:39:03,253 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4298) 2021-09-14 15:39:03,254 cisTopic     INFO     Returning plot data
# (pid=4298) 2021-09-14 15:39:03,254 cisTopic     INFO     Returning valid barcodes
# (pid=4298) 2021-09-14 15:39:04,742 cisTopic     INFO     Computing duplicate rate plot for Sanger_2
# (pid=4298) 2021-09-14 15:39:06,039 cisTopic     INFO     Return plot data
# (pid=4298) 2021-09-14 15:39:06,153 cisTopic     INFO     Computing insert size distribution for Sanger_2
# (pid=4298) 2021-09-14 15:39:06,153 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:39:06,779 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:39:12,853 cisTopic     INFO     Computing barcode rank plot for VIB_1
# (pid=4297) 2021-09-14 15:39:12,854 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:39:13,472 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4297) 2021-09-14 15:39:13,473 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:39:13,474 cisTopic     INFO     Returning valid barcodes
# (pid=4299) 2021-09-14 15:39:13,755 cisTopic     INFO     Coverage matrix done
# (pid=4297) 2021-09-14 15:39:14,413 cisTopic     INFO     Computing duplicate rate plot for VIB_1
# (pid=4299) 2021-09-14 15:39:14,680 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4299) 2021-09-14 15:39:15,283 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4297) 2021-09-14 15:39:15,272 cisTopic     INFO     Return plot data
# (pid=4297) 2021-09-14 15:39:15,346 cisTopic     INFO     Computing insert size distribution for VIB_1
# (pid=4297) 2021-09-14 15:39:15,346 cisTopic     INFO     Counting fragments
# (pid=4299) 2021-09-14 15:39:15,402 cisTopic     INFO     Computing FRIP profile for Stanford_2
# (pid=4297) 2021-09-14 15:39:15,754 cisTopic     INFO     Returning plot data
# (pid=4299) 2021-09-14 15:39:15,859 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:39:15,935 cisTopic     INFO     Computing TSS profile for Sanger_2
# (pid=4299) 2021-09-14 15:39:16,537 cisTopic     INFO     Intersecting fragments with regions
# (pid=4298) 2021-09-14 15:39:17,222 cisTopic     INFO     Formatting annnotation
# (pid=4298) 2021-09-14 15:39:17,309 cisTopic     INFO     Creating coverage matrix
# (pid=4299) 2021-09-14 15:39:19,077 cisTopic     INFO     Sample Stanford_2 done!
# (pid=4300) 2021-09-14 15:39:20,308 cisTopic     INFO     Coverage matrix done
# (pid=4297) 2021-09-14 15:39:21,345 cisTopic     INFO     Computing TSS profile for VIB_1
# (pid=4297) 2021-09-14 15:39:22,130 cisTopic     INFO     Formatting annnotation
# (pid=4297) 2021-09-14 15:39:22,203 cisTopic     INFO     Creating coverage matrix
# (pid=4300) 2021-09-14 15:39:22,299 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4300) 2021-09-14 15:39:23,797 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4300) 2021-09-14 15:39:23,880 cisTopic     INFO     Computing FRIP profile for Sanger_1
# (pid=4300) 2021-09-14 15:39:24,441 cisTopic     INFO     Counting fragments
# (pid=4300) 2021-09-14 15:39:26,107 cisTopic     INFO     Intersecting fragments with regions
# (pid=4300) 2021-09-14 15:39:32,671 cisTopic     INFO     Sample Sanger_1 done!
# (pid=4301) 2021-09-14 15:39:42,930 cisTopic     INFO     Computing barcode rank plot for VIB_2
# (pid=4301) 2021-09-14 15:39:42,930 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:39:44,731 cisTopic     INFO     Marking barcodes with more than 100
# (pid=4301) 2021-09-14 15:39:44,733 cisTopic     INFO     Returning plot data
# (pid=4301) 2021-09-14 15:39:44,733 cisTopic     INFO     Returning valid barcodes
# (pid=4301) 2021-09-14 15:39:47,304 cisTopic     INFO     Computing duplicate rate plot for VIB_2
# (pid=4301) 2021-09-14 15:39:50,060 cisTopic     INFO     Return plot data
# (pid=4301) 2021-09-14 15:39:50,143 cisTopic     INFO     Computing insert size distribution for VIB_2
# (pid=4301) 2021-09-14 15:39:50,144 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:39:51,312 cisTopic     INFO     Returning plot data
# (pid=4297) 2021-09-14 15:39:58,544 cisTopic     INFO     Coverage matrix done
# (pid=4297) 2021-09-14 15:40:00,299 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4297) 2021-09-14 15:40:01,497 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4297) 2021-09-14 15:40:01,573 cisTopic     INFO     Computing FRIP profile for VIB_1
# (pid=4297) 2021-09-14 15:40:02,034 cisTopic     INFO     Counting fragments
# (pid=4297) 2021-09-14 15:40:03,380 cisTopic     INFO     Intersecting fragments with regions
# (pid=4298) 2021-09-14 15:40:06,090 cisTopic     INFO     Coverage matrix done
# (pid=4301) 2021-09-14 15:40:07,144 cisTopic     INFO     Computing TSS profile for VIB_2
# (pid=4298) 2021-09-14 15:40:08,565 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4297) 2021-09-14 15:40:09,035 cisTopic     INFO     Sample VIB_1 done!
# (pid=4301) 2021-09-14 15:40:09,350 cisTopic     INFO     Formatting annnotation
# (pid=4301) 2021-09-14 15:40:09,431 cisTopic     INFO     Creating coverage matrix
# (pid=4298) 2021-09-14 15:40:10,359 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4298) 2021-09-14 15:40:10,429 cisTopic     INFO     Computing FRIP profile for Sanger_2
# (pid=4298) 2021-09-14 15:40:11,048 cisTopic     INFO     Counting fragments
# (pid=4298) 2021-09-14 15:40:13,036 cisTopic     INFO     Intersecting fragments with regions
# (pid=4298) 2021-09-14 15:40:20,516 cisTopic     INFO     Sample Sanger_2 done!
# (pid=4301) 2021-09-14 15:41:20,785 cisTopic     INFO     Coverage matrix done
# (pid=4301) 2021-09-14 15:41:24,768 cisTopic     INFO     Returning normalized TSS coverage matrix per barcode
# (pid=4301) 2021-09-14 15:41:27,580 cisTopic     INFO     Returning normalized sample TSS enrichment data
# (pid=4301) 2021-09-14 15:41:27,695 cisTopic     INFO     Computing FRIP profile for VIB_2
# (pid=4301) 2021-09-14 15:41:28,212 cisTopic     INFO     Counting fragments
# (pid=4301) 2021-09-14 15:41:31,534 cisTopic     INFO     Intersecting fragments with regions
# (pid=4301) 2021-09-14 15:41:43,807 cisTopic     INFO     Sample VIB_2 done!

# %%
f_qc_dir = 'qc__consensus_peaks'
if not os.path.exists(os.path.join(wdir, f_qc_dir)):
    os.makedirs(os.path.join(wdir, f_qc_dir))
    
with open(os.path.join(wdir, f_qc_dir, 'metadata.pickle'), 'wb') as f:
    pickle.dump(metadata_bc_dict, f)

with open(os.path.join(wdir, f_qc_dir, 'profile_data.pickle'), 'wb') as f:
    pickle.dump(profile_data_dict, f)

# %% [markdown]
# ## Create the cisTopic objects for each sample

# %%
# Valid barcodes
with open(wdir + 'barcodes_passing_filters2.pkl', 'rb') as f:
    bc_passing_filters = pickle.load(f)

# %%
from pycisTopic.cistopic_class import create_cistopic_object_from_fragments

# %%
#path_to_regions = '/staging/leuven/stg_00002/lcb/cbravo/SCREEN_ENCODE3/V2.hg38-rDHS-Unfiltered.blacklisted.bed'
path_to_blacklist = '/staging/leuven/stg_00002/lcb/cflerin/testruns/pycisTopic/pycisTopic/blacklist/hg38-blacklist.v2.bed'

# %%
f_cto_dir = 'cistopic_objs__consensus_peaks'
if not os.path.exists(os.path.join(wdir, f_cto_dir)):
    os.makedirs(os.path.join(wdir, f_cto_dir))

# %%
#Create all objects

for key in bc_passing_filters.keys():
    f_out = os.path.join(wdir, f_cto_dir, key + '__cistopic_obj.pkl')
    if os.path.isfile(f_out):
        print(f"Skipping {key}")
        continue
        
    tmp_cto = create_cistopic_object_from_fragments(path_to_fragments=fragments_dict[key],
                                                    path_to_regions=consensus_peaks_dict[key],
                                                    path_to_blacklist=path_to_blacklist,
                                                    #metrics=metadata_bc_dict[key],
                                                    valid_bc=bc_passing_filters[key],
                                                    n_cpu=1,
                                                    partition=20,
                                                    project=key)
    
    with open(f_out, 'wb') as f:
        pickle.dump(tmp_cto, f)
    
    print(f"DONE {key}")
# Out:
# Skipping Broad_1
# Skipping Broad_2
# Skipping Broad_mito_1
# Skipping Broad_mito_2
# Skipping CNAG_1
# Skipping CNAG_2
# Skipping s3atac
# Skipping Sanger_1
# Skipping Sanger_2
# Skipping Stanford_1
# Skipping Stanford_2
# Skipping VIB_1
# Skipping VIB_2

# %% [markdown]
# ## Create a merged object
#
# Here, use a common set of peaks for each sample, then merge them

# %%
f_cto_merged_dir = 'cistopic_objs__consensus_peaks_merged'
if not os.path.exists(os.path.join(wdir, f_cto_merged_dir)):
    os.makedirs(os.path.join(wdir, f_cto_merged_dir))

# %%
#Create all objects

for key in bc_passing_filters.keys():
    f_out = os.path.join(wdir, f_cto_merged_dir, key + '__cistopic_obj.pkl')
    if os.path.isfile(f_out):
        print(f"Skipping {key}")
        continue
        
    tmp_cto = create_cistopic_object_from_fragments(path_to_fragments=fragments_dict[key],
                                                    path_to_regions=consensus_peaks_dict['merged'],
                                                    path_to_blacklist=path_to_blacklist,
                                                    #metrics=metadata_bc_dict[key],
                                                    valid_bc=bc_passing_filters[key],
                                                    n_cpu=1,
                                                    partition=20,
                                                    project=key)
    
    with open(f_out, 'wb') as f:
        pickle.dump(tmp_cto, f)
    
    print(f"DONE {key}")
# Out:
# Skipping Broad_1
# Skipping Broad_2
# Skipping Broad_mito_1
# Skipping Broad_mito_2
# Skipping CNAG_1
# Skipping CNAG_2
# Skipping s3atac
# Skipping Sanger_1
# Skipping Sanger_2
# Skipping Stanford_1
# Skipping Stanford_2
# Skipping VIB_1
# Skipping VIB_2

# %%
# load objects into dict:
cistopic_obj_dict = {}
for key in bc_passing_filters.keys():
    f_out = os.path.join(wdir, f_cto_merged_dir, key + '__cistopic_obj.pkl')
    with open(f_out, 'rb') as f:
        cistopic_obj_dict[key] = pickle.load(f)
    print(f"Loaded {key}")
# Out:
# Loaded Broad_1
# Loaded Broad_2
# Loaded Broad_mito_1
# Loaded Broad_mito_2
# Loaded CNAG_1
# Loaded CNAG_2
# Loaded s3atac
# Loaded Sanger_1
# Loaded Sanger_2
# Loaded Stanford_1
# Loaded Stanford_2
# Loaded VIB_1
# Loaded VIB_2

# %%
import copy

# %%
f_out = os.path.join(wdir, f_cto_merged_dir, 'cellds_merged__cistopic_obj.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        cistopic_obj_dict['merged'] = pickle.load(f)
else:
    # merge:
    ct_keys = list(cistopic_obj_dict.keys())
    cto_merged = copy.copy(cistopic_obj_dict[ct_keys[0]])
    cto_merged.merge([ cistopic_obj_dict[k] for k in ct_keys[1:] ], project='scATAC-seq_benchmark')
    with open(f_out, 'wb') as f:
        pickle.dump(cto_merged, f)
# Out:
# 2021-09-15 11:49:43,074 cisTopic     INFO     cisTopic object 1 merged
# 2021-09-15 11:49:48,865 cisTopic     INFO     cisTopic object 2 merged
# 2021-09-15 11:49:55,561 cisTopic     INFO     cisTopic object 3 merged
# 2021-09-15 11:50:03,457 cisTopic     INFO     cisTopic object 4 merged
# 2021-09-15 11:50:11,848 cisTopic     INFO     cisTopic object 5 merged
# 2021-09-15 11:50:20,721 cisTopic     INFO     cisTopic object 6 merged
# 2021-09-15 11:50:30,925 cisTopic     INFO     cisTopic object 7 merged
# 2021-09-15 11:50:42,607 cisTopic     INFO     cisTopic object 8 merged
# 2021-09-15 11:50:54,504 cisTopic     INFO     cisTopic object 9 merged
# 2021-09-15 11:51:06,880 cisTopic     INFO     cisTopic object 10 merged
# 2021-09-15 11:51:20,550 cisTopic     INFO     cisTopic object 11 merged
# 2021-09-15 11:51:36,110 cisTopic     INFO     cisTopic object 12 merged

# %% [markdown]
# ## Create a set of cisTopic objects for downstream analysis
#
# Include each sample individually (using the sample-specific consensus peaks), plus the merged sample (using the merged consensus peaks).

# %%
del cistopic_obj_dict

cistopic_obj_dict = {}
# load sample objects into dict:
for key in bc_passing_filters.keys():
    f_out = os.path.join(wdir, f_cto_dir, key + '__cistopic_obj.pkl')
    with open(f_out, 'rb') as f:
        cistopic_obj_dict[key] = pickle.load(f)
    print(f"Loaded {key}")

# add the merged object:
f_out = os.path.join(wdir, f_cto_merged_dir, 'cellds_merged__cistopic_obj.pkl')
if os.path.isfile(f_out):
    print(f"Loading {f_out}")
    with open(f_out, 'rb') as f:
        cistopic_obj_dict['merged'] = pickle.load(f)
# Out:
# Loaded Broad_1
# Loaded Broad_2
# Loaded Broad_mito_1
# Loaded Broad_mito_2
# Loaded CNAG_1
# Loaded CNAG_2
# Loaded s3atac
# Loaded Sanger_1
# Loaded Sanger_2
# Loaded Stanford_1
# Loaded Stanford_2
# Loaded VIB_1
# Loaded VIB_2
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/cistopic_objs__consensus_peaks_merged/cellds_merged__cistopic_obj.pkl

# %% [markdown]
# ## Add cell annotations

# %%
cellannot = pd.read_csv(
    '/staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/cellds_filtered_cell_data.tsv',
    sep='\t', index_col=0)
cellannot
# Out:
#                                                     Doublet_scores_fragments  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                  0.127469
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                  0.354582
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                  0.235127
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                  0.284768
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                  0.508197
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                              0.117647
# GTCCATCAGTACCTCA-VIB_2                                              0.131222
# TTGTTCACAACTCGAT-VIB_2                                              0.278075
# CTTCCAGTCAGTGTGT-VIB_2                                              0.165775
# GGAGAACAGTTACACC-VIB_2                                              0.102302
#
#                                                     Total_nr_frag_in_regions  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                      6949
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                      7652
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                      7275
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                      8422
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                      6925
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                  5697
# GTCCATCAGTACCTCA-VIB_2                                                  5164
# TTGTTCACAACTCGAT-VIB_2                                                  5062
# CTTCCAGTCAGTGTGT-VIB_2                                                  6068
# GGAGAACAGTTACACC-VIB_2                                                  3807
#
#                                                     pycisTopic_leiden_10_1.2  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                         8
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         2
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         0
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                         0
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                         8
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                    21
# GTCCATCAGTACCTCA-VIB_2                                                     1
# TTGTTCACAACTCGAT-VIB_2                                                    21
# CTTCCAGTCAGTGTGT-VIB_2                                                     1
# GGAGAACAGTTACACC-VIB_2                                                     1
#
#                                                     Dupl_nr_frag  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...          3440
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...          3538
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...          4158
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...          4752
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...          3824
# ...                                                          ...
# CTTCCAGCAAGGTCGA-VIB_2                                      1166
# GTCCATCAGTACCTCA-VIB_2                                      1389
# TTGTTCACAACTCGAT-VIB_2                                      2031
# CTTCCAGTCAGTGTGT-VIB_2                                      1931
# GGAGAACAGTTACACC-VIB_2                                       824
#
#                                                                                               barcode  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...  TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_AT...
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...  GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CG...
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...  TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TG...
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...  ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GA...
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...  TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TA...
# ...                                                                                               ...
# CTTCCAGCAAGGTCGA-VIB_2                                                               CTTCCAGCAAGGTCGA
# GTCCATCAGTACCTCA-VIB_2                                                               GTCCATCAGTACCTCA
# TTGTTCACAACTCGAT-VIB_2                                                               TTGTTCACAACTCGAT
# CTTCCAGTCAGTGTGT-VIB_2                                                               CTTCCAGTCAGTGTGT
# GGAGAACAGTTACACC-VIB_2                                                               GGAGAACAGTTACACC
#
#                                                     seurat_cell_type_pred_score  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                     0.682683
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                     0.516413
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                     0.612734
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                     0.783805
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                     0.616381
# ...                                                                         ...
# CTTCCAGCAAGGTCGA-VIB_2                                                 0.961163
# GTCCATCAGTACCTCA-VIB_2                                                 0.979147
# TTGTTCACAACTCGAT-VIB_2                                                 0.782794
# CTTCCAGTCAGTGTGT-VIB_2                                                 0.859730
# GGAGAACAGTTACACC-VIB_2                                                 0.864884
#
#                                                     pycisTopic_leiden_10_1.0  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                         8
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         2
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         1
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                        18
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                         8
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                    16
# GTCCATCAGTACCTCA-VIB_2                                                     0
# TTGTTCACAACTCGAT-VIB_2                                                    16
# CTTCCAGTCAGTGTGT-VIB_2                                                     0
# GGAGAACAGTTACACC-VIB_2                                                     0
#
#                                                     pycisTopic_leiden_10_0.6  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                        10
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         3
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         1
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                         1
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                        10
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                     0
# GTCCATCAGTACCTCA-VIB_2                                                     0
# TTGTTCACAACTCGAT-VIB_2                                                     0
# CTTCCAGTCAGTGTGT-VIB_2                                                     0
# GGAGAACAGTTACACC-VIB_2                                                     0
#
#                                                     Unique_nr_frag_in_regions  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                       4268
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                       4554
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                       3891
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                       4193
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                       3700
# ...                                                                       ...
# CTTCCAGCAAGGTCGA-VIB_2                                                   4843
# GTCCATCAGTACCTCA-VIB_2                                                   4177
# TTGTTCACAACTCGAT-VIB_2                                                   3726
# CTTCCAGTCAGTGTGT-VIB_2                                                   4579
# GGAGAACAGTTACACC-VIB_2                                                   3298
#
#                                                     Predicted_doublets_fragments  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                         False
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         False
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         False
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                         False
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                         False
# ...                                                                          ...
# CTTCCAGCAAGGTCGA-VIB_2                                                     False
# GTCCATCAGTACCTCA-VIB_2                                                     False
# TTGTTCACAACTCGAT-VIB_2                                                     False
# CTTCCAGTCAGTGTGT-VIB_2                                                     False
# GGAGAACAGTTACACC-VIB_2                                                     False
#
#                                                     ... Dupl_rate  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...  ...  0.370650
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...  ...  0.391026
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...  ...  0.443615
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...  ...  0.480631
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...  ...  0.440705
# ...                                                 ...       ...
# CTTCCAGCAAGGTCGA-VIB_2                              ...  0.133425
# GTCCATCAGTACCTCA-VIB_2                              ...  0.159216
# TTGTTCACAACTCGAT-VIB_2                              ...  0.225441
# CTTCCAGTCAGTGTGT-VIB_2                              ...  0.201230
# GGAGAACAGTTACACC-VIB_2                              ...  0.091892
#
#                                                     pycisTopic_leiden_10_0.8  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                        10
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         2
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         0
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                         0
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                        10
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                    20
# GTCCATCAGTACCTCA-VIB_2                                                     1
# TTGTTCACAACTCGAT-VIB_2                                                    20
# CTTCCAGTCAGTGTGT-VIB_2                                                     1
# GGAGAACAGTTACACC-VIB_2                                                     1
#
#                                                     Log_total_nr_frag  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...           3.967595
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...           3.956553
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...           3.971879
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...           3.995065
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...           3.938370
# ...                                                               ...
# CTTCCAGCAAGGTCGA-VIB_2                                       3.941462
# GTCCATCAGTACCTCA-VIB_2                                       3.940716
# TTGTTCACAACTCGAT-VIB_2                                       3.954677
# CTTCCAGTCAGTGTGT-VIB_2                                       3.982090
# GGAGAACAGTTACACC-VIB_2                                       3.952647
#
#                                                    Total_nr_frag  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...          9281
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...          9048
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...          9373
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...          9887
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...          8677
# ...                                                          ...
# CTTCCAGCAAGGTCGA-VIB_2                                      8739
# GTCCATCAGTACCTCA-VIB_2                                      8724
# TTGTTCACAACTCGAT-VIB_2                                      9009
# CTTCCAGTCAGTGTGT-VIB_2                                      9596
# GGAGAACAGTTACACC-VIB_2                                      8967
#
#                                                    cisTopic_nr_frag  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...             6019
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...             5884
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...             5470
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...             5322
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...             4584
# ...                                                             ...
# CTTCCAGCAAGGTCGA-VIB_2                                         6498
# GTCCATCAGTACCTCA-VIB_2                                         5883
# TTGTTCACAACTCGAT-VIB_2                                         5464
# CTTCCAGTCAGTGTGT-VIB_2                                         6208
# GGAGAACAGTTACACC-VIB_2                                         5396
#
#                                                     Unique_nr_frag  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...            5841
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...            5510
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...            5215
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...            5135
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...            4853
# ...                                                            ...
# CTTCCAGCAAGGTCGA-VIB_2                                        7573
# GTCCATCAGTACCTCA-VIB_2                                        7335
# TTGTTCACAACTCGAT-VIB_2                                        6978
# CTTCCAGTCAGTGTGT-VIB_2                                        7665
# GGAGAACAGTTACACC-VIB_2                                        8143
#
#                                                     pycisTopic_leiden_10_1.4  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                         7
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         4
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         0
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                        10
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                         7
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                    14
# GTCCATCAGTACCTCA-VIB_2                                                     3
# TTGTTCACAACTCGAT-VIB_2                                                    14
# CTTCCAGTCAGTGTGT-VIB_2                                                    14
# GGAGAACAGTTACACC-VIB_2                                                     3
#
#                                                     pycisTopic_leiden_10_1.6  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                        25
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                         6
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                         0
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                         7
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                        25
# ...                                                                      ...
# CTTCCAGCAAGGTCGA-VIB_2                                                    14
# GTCCATCAGTACCTCA-VIB_2                                                     2
# TTGTTCACAACTCGAT-VIB_2                                                    14
# CTTCCAGTCAGTGTGT-VIB_2                                                     2
# GGAGAACAGTTACACC-VIB_2                                                     2
#
#                                                    pycisTopic_leiden_10_1.8  \
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...                       26
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...                        7
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...                        5
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...                        6
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...                       26
# ...                                                                     ...
# CTTCCAGCAAGGTCGA-VIB_2                                                   13
# GTCCATCAGTACCTCA-VIB_2                                                    2
# TTGTTCACAACTCGAT-VIB_2                                                   13
# CTTCCAGTCAGTGTGT-VIB_2                                                   13
# GGAGAACAGTTACACC-VIB_2                                                    2
#
#                                                     consensus_cell_type
# TTCCTCTATGGTGTTTATCAT_GCGTAGACACGCCACTTCATC_ATA...       CD14+ monocyte
# GCGACTCAGACCATTTATCAT_CGACACTTCGCGCATTCCTCT_CGC...     Cytotoxic T cell
# TACCGAATGACCGCATTCGTT_CTCATTTACTCAATAGCAACG_TGT...          CD4+ T cell
# ACGTTGGGAACCGTCCTCCTT_AACTCTTGGTTAGTCTCTTGC_GAT...          CD4+ T cell
# TCATACACCAAGCTCATGTAT_AGGATACCCGCGATATGTTCC_TAA...       CD14+ monocyte
# ...                                                                 ...
# CTTCCAGCAAGGTCGA-VIB_2                                   CD14+ monocyte
# GTCCATCAGTACCTCA-VIB_2                                   CD14+ monocyte
# TTGTTCACAACTCGAT-VIB_2                                   CD14+ monocyte
# CTTCCAGTCAGTGTGT-VIB_2                                   CD14+ monocyte
# GGAGAACAGTTACACC-VIB_2                                   CD14+ monocyte
#
# [39580 rows x 30 columns]

# %%
for key in cistopic_obj_dict.keys():
    cistopic_obj_dict[key].add_cell_data(
        cellannot[['consensus_cell_type']]
    )

# %% [markdown]
# ### Run models for quick visualize/clustering

# %%
from pycisTopic.lda_models import run_cgs_models_mallet

# %% [markdown]
# #### mallet models

# %%
# set the memory limit for mallet (1GB default is not enough)
os.environ['MALLET_MEMORY'] = '100G'

# %%
f_mod_dir = 'models__consensus__mallet'
if not os.path.exists(os.path.join(wdir, f_mod_dir)):
    os.makedirs(os.path.join(wdir, f_mod_dir))

f_mod_tmpdir = '/scratch/leuven/325/vsc32528/tmp/mallet_cellds'
if not os.path.exists(f_mod_tmpdir):
    os.makedirs(f_mod_tmpdir)

n_topics = [2, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
n_topics_merged = [2, 5, 10, 20, 30, 35, 40, 45, 50, 60, 70, 80, 90, 100]
n_iter = 500

# %%
# mallet implementation
models_dict = {}
for key in cistopic_obj_dict.keys():
    f_mod = os.path.join(wdir, f_mod_dir, key + '__models_' + str(n_iter) + '_iter.pkl')
    if os.path.isfile(f_mod):
        print(f"Loading {f_mod}")
        with open(f_mod, 'rb') as f:
            models_dict[key] = pickle.load(f)
    else:
        print(f"Running {key}")
        model = run_cgs_models_mallet(
                            'mallet',
                            cistopic_obj_dict[key],
                            n_topics=n_topics_merged if key=='merged' else n_topics ,
                            n_cpu=16,
                            n_iter=n_iter,
                            random_state=555,
                            alpha=50,
                            alpha_by_topic=True,
                            eta=0.1,
                            eta_by_topic=False,
                            tmp_path=os.path.join(f_mod_tmpdir, key + '_')
                            )
        # Save
        with open(f_mod, 'wb') as f:
            pickle.dump(model, f)
        print(f"Finished {key}")
        models_dict[key] = model
# Out:
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Broad_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Broad_2__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Broad_mito_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Broad_mito_2__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/CNAG_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/CNAG_2__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/s3atac__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Sanger_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Sanger_2__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Stanford_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/Stanford_2__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/VIB_1__models_500_iter.pkl
# Loading /staging/leuven/stg_00002/lcb/cflerin/analysis/pbmc_atac/analysis2/data_freeze_Jun2021_cell_downsampled/atac_qc/jupyter/models__consensus__mallet/VIB_2__models_500_iter.pkl
# Running merged
# 2021-09-15 11:56:19,199 cisTopic     INFO     Formatting input to corpus
# 2021-09-15 11:56:25,962 gensim.corpora.dictionary INFO     adding document #0 to Dictionary(0 unique tokens: [])
# 2021-09-15 11:56:58,272 gensim.corpora.dictionary INFO     adding document #10000 to Dictionary(0 unique tokens: [])
# 2021-09-15 11:57:29,291 gensim.corpora.dictionary INFO     adding document #20000 to Dictionary(0 unique tokens: [])
# 2021-09-15 11:58:07,062 gensim.corpora.dictionary INFO     adding document #30000 to Dictionary(0 unique tokens: [])
# 2021-09-15 11:58:45,839 gensim.corpora.dictionary INFO     built Dictionary(298464 unique tokens: ['0', '1', '2', '3', '4']...) from 39580 documents (total 155187486 corpus positions)
# 2021-09-15 11:58:45,840 cisTopic     INFO     Running model with 2 topics
# 2021-09-15 11:58:45,849 LDAMalletWrapper INFO     Serializing temporary corpus to /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.txt
# 2021-09-15 12:05:01,700 LDAMalletWrapper INFO     Converting temporary corpus to MALLET format with mallet import-file --preserve-case --keep-sequence --remove-stopwords --token-regex "\S+" --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.txt --output /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 2021-09-15 12:06:31,003 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 2  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_44b1e6_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_44b1e6_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_44b1e6_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_44b1e6_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 12:47:50,158 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_44b1e6_state.mallet.gz
# 2021-09-15 12:53:44,245 cisTopic     INFO     Model with 2 topics done!
# 2021-09-15 12:53:44,247 cisTopic     INFO     Running model with 5 topics
# 2021-09-15 12:53:44,260 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 12:53:44,261 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 5  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_efb50a_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_efb50a_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_efb50a_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_efb50a_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 13:49:20,620 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_efb50a_state.mallet.gz
# 2021-09-15 13:56:22,223 cisTopic     INFO     Model with 5 topics done!
# 2021-09-15 13:56:22,224 cisTopic     INFO     Running model with 10 topics
# 2021-09-15 13:56:22,236 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 13:56:22,236 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 10  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_e4e49b_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_e4e49b_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_e4e49b_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_e4e49b_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 14:46:49,874 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_e4e49b_state.mallet.gz
# 2021-09-15 14:53:54,590 cisTopic     INFO     Model with 10 topics done!
# 2021-09-15 14:53:54,592 cisTopic     INFO     Running model with 20 topics
# 2021-09-15 14:53:54,607 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 14:53:54,607 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 20  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_b32e24_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_b32e24_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_b32e24_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_b32e24_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 15:48:30,993 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_b32e24_state.mallet.gz
# 2021-09-15 15:55:47,116 cisTopic     INFO     Model with 20 topics done!
# 2021-09-15 15:55:47,122 cisTopic     INFO     Running model with 30 topics
# 2021-09-15 15:55:47,136 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 15:55:47,137 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 30  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_65e0fa_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_65e0fa_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_65e0fa_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_65e0fa_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 16:56:38,414 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_65e0fa_state.mallet.gz
# 2021-09-15 17:04:01,964 cisTopic     INFO     Model with 30 topics done!
# 2021-09-15 17:04:01,986 cisTopic     INFO     Running model with 35 topics
# 2021-09-15 17:04:02,001 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 17:04:02,002 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 35  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_2cce61_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_2cce61_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_2cce61_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_2cce61_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
# 2021-09-15 18:18:51,162 LDAMalletWrapper INFO     loading assigned topics from /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_2cce61_state.mallet.gz
# 2021-09-15 18:26:11,687 cisTopic     INFO     Model with 35 topics done!
# 2021-09-15 18:26:11,709 cisTopic     INFO     Running model with 40 topics
# 2021-09-15 18:26:11,724 LDAMalletWrapper INFO     MALLET corpus already exists, training model
# 2021-09-15 18:26:11,725 LDAMalletWrapper INFO     Training MALLET LDA with mallet train-topics --input /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_corpus.mallet --num-topics 40  --alpha 50 --beta 0.1 --optimize-interval 0 --num-threads 16 --output-state /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_4888e7_state.mallet.gz --output-doc-topics /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_4888e7_doctopics.txt --output-topic-keys /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_4888e7_topickeys.txt --num-iterations 500 --inferencer-filename /scratch/leuven/325/vsc32528/tmp/mallet_cellds/merged_4888e7_inferencer.mallet --doc-topics-threshold 0.0  --random-seed 555
